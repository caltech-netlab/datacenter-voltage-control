# %% [markdown]
# <a href="https://colab.research.google.com/github/caltech-netlab/datacenter-voltage-control/blob/master/Optimizing_K_t0_001_Microsoft_n8_250901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/250805 data center
# Out:
# /content/drive/MyDrive/Colab Notebooks/250805 data center

# %%
import scipy.io
import random
import math
import scipy.io as sio
import h5py
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# !pip install mat4py
# Out:
# Collecting mat4py
#   Downloading mat4py-0.6.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading mat4py-0.6.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: mat4py
# Successfully installed mat4py-0.6.0

# %%
# A RNN-based Reinforcement Learning Framework for Frequency Control Problem with Stability Guarantee
import collections
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import gym
import tensorflow as tf
import os
import random
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.layers import RNN
import tensorflow.keras.backend as K
import sys
from gym import spaces
from gym.utils import seeding
import copy
from mat4py import loadmat
from tensorflow.keras import layers
from tensorflow import keras
import time
import cvxpy as cp
import pickle
from numpy import linalg as LA
from mat4py import loadmat

# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:151: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:151: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Load data for time-varying voltage

# %%
# from scipy.io import loadmat
# filepath = '/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen_t0.001.mat'

# data = loadmat(filepath)
# print(data.keys())  # Show variable names in the file

# # Access a specific variable
# record_trajectory = data['record_trajectory']
# record_trajectory = np.array(record_trajectory)

# %%
# f = open("/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen_t0.001.pckl", 'wb')
# pickle.dump([record_trajectory], f)
# f.close()

f = open("/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen_t0.001.pckl", 'rb')
[record_fault_trajectory] = pickle.load(f)
f.close()

# %%
# randomly print 10 cases
plt.ion()
# fig = plt.figure(figsize=(5,4), dpi=100)

for test_idx in range(5):
    fig = plt.figure(figsize=(18,4), dpi=100)

    voltage = record_fault_trajectory[test_idx,0,:,:]
    time = 0.001*np.arange(0,np.shape(voltage)[-1])
    plt.subplot(1,3,1)
    plt.plot(time, record_fault_trajectory[test_idx,0,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('Voltage(p.u.)')

    # freq = record_fault_trajectory[test_idx,2,:,:]
    plt.subplot(1,3,2)
    plt.plot(time, record_fault_trajectory[test_idx,1,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('omega(Hz)')

    plt.subplot(1,3,3)
    plt.plot(time, record_fault_trajectory[test_idx,2,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('Power(p.u.)')


    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()
    plt.pause(0.01)
    plt.clf()

# %% [markdown]
# # Environment Setup

# %% [markdown]
# ## Vulcan Data Extraction

# %%
import networkx as nx
import random
import matplotlib.pyplot as plt
import os


def to_edge_list(edges, data=False):
    """
    :param edges: dict, key: edge name, value: edge attributes
    :param data: bool, whether to include edge attributes
    :return: list of tuple of str (src, tgt) where src/tgt are source/target node names
    """
    if type(edges) is dict:
        if data:
            return {(e["source"], e["target"]): name for name, e in edges.items()}
        else:
            return [(e["source"], e["target"]) for name, e in edges.items()]
    else:
        assert not data
        return [(e["source"], e["target"]) for e in edges]


def plot_nx_graph(G, outpath=None, show=True, edge_info=None, node_info=None, figsize=(12,12)):
    try:
        pos = nx.nx_agraph.graphviz_layout(G, prog="dot", args="")
    except:
        print("graphviz not installed or error. Using spring layout.")
        pos = nx.spring_layout(G)
    pos = {k: (v[0], v[1] + (random.random() - 0.5) * 40) for k, v in pos.items()}
    fig = plt.figure(figsize=figsize)
    if edge_info:
        nx.draw_networkx_edge_labels(G, pos, edge_labels={k: edge_info[k] for k in G.edges}, font_color="red")
    if node_info:
        pos_ = {k: (v[0] + 5, v[1] + 5) for k, v in pos.items()}
        nx.draw_networkx_labels(G, pos_, labels=node_info, font_color="red", font_size=figsize[0], font_weight='bold')
    nx.draw(G, pos, with_labels=True)
    fig.tight_layout()
    if outpath:
        os.makedirs(os.path.dirname(outpath), exist_ok=True)
        plt.savefig(outpath)
    if show:
        plt.show()
    else:
        plt.close()

# %%
import numpy as np
import pandas as pd
import scipy as sp
import networkx as nx

# import utils


def single_phase_lindistflow(circuit_data, node_list=None):
    """
    An implementation of the single-phase LinDistFlow is provided for reference.
    Note that the R, X values are averaged (not summed) across the three phases.
    :param circuit_data: dict, edge list, e.g.
        [
            {
                'element_name': 'line_1',
                'source': 'bus_1',
                'target': 'bus_2',
                'series_impedance': complex,
            },
            ...
        ]
    :param per_unit: bool, if True, convert all quantities to per-unit
        Only p.u. is supported for now.
    :param s_base: float, base power for per-unit conversion
    return: R_matrix, X_matrix, C_matrix, node_list
        R_matrix: np.array, shape=(N, N)
        X_matrix: np.array, shape=(N, N)
        C_matrix: np.array, shape=(N+1, N)
        node_list: list of str, node names
        Usage:
            nodal_voltages = v0 + 2 * (R_matrix @ p_inj[1:] + X_matrix @ q_inj[1:])
            branch_power = np.linalg.inv(C_matrix[1:, :]) @ (p + 1j * q)
    """
    edge_list = utils.to_edge_list(circuit_data)
    graph = nx.DiGraph(edge_list)
    root_node = [n for n in graph.nodes if graph.in_degree(n) == 0]
    assert len(root_node) == 1, f"There should be only one root node: {root_node}"
    assert nx.is_directed_acyclic_graph(graph), "Graph contains a cycle. Only radial networks are supported."
    N = len(graph.nodes) - 1    # Excluding the root node
    assert len(graph.edges) == N, len(graph.edges)
    # Build node_list and assign node id
    node_list = node_list or list(nx.bfs_tree(graph, root_node[0]).nodes())
    assert node_list[0] == root_node[0], f"Root node {node_list[0]} does not match {root_node[0]}"
    node2idx = {node: k for k, node in enumerate(node_list)}
    # Replace node names with integer indicies
    edge_list = [(node2idx[e[0]], node2idx[e[1]]) for e in edge_list]
    graph = nx.DiGraph(edge_list)
    # Check that the node_list is in BFS or DFS order
    for i in range(1, N+1):
        assert not (set(graph.predecessors(i)) - set(range(i))), \
            str('\n'.join([n.split('|')[0] for n in node_list]) + '\n' + str(set(graph.predecessors(i))) + ' ' + str(i))

    # Careful! The graph needs to be in the down orientation.
    # networkx incidence_matrix has the opposite sign convention
    C_matrix = -nx.incidence_matrix(graph, oriented=True, nodelist=list(range(N+1))).toarray()
    ge = list(graph.edges)
    permutation = [ge.index((i, j)) for i, j in edge_list]
    C_matrix = C_matrix[:, permutation]
    C_inv = np.linalg.inv(C_matrix[1:])
    utils.plot_nx_graph(
        graph,
        node_info={i: n.split('|')[0] for i, n in enumerate(node_list)},
        outpath='temp/network.png',
        edge_info={e: circuit_data[i]['series_impedance'] for i, e in enumerate(edge_list)},
    )

    resistances, reactances = np.zeros(N), np.zeros(N)
    for edge in circuit_data:
        e = edge_list.index((node2idx[edge['source']], node2idx[edge['target']]))
        resistances[e] = edge['series_impedance'].real
        reactances[e] = edge['series_impedance'].imag
    R_matrix = C_inv.T @ np.diag(resistances) @ C_inv
    X_matrix = C_inv.T @ np.diag(reactances) @ C_inv
    return R_matrix, X_matrix, C_matrix, node_list, edge_list


def load_compute_power(file, t0, t1, keys):
    """
    :param file: str, path to the csv file
    :param t0: str, start time in 'YYYY/MM/DD HH:MM:SS.sss'
    :param t1: str, end time in 'YYYY/MM/DD HH:MM:SS.sss'
    :param keys: dict, e.g. {'t': 'timestamp', 'p': 'power.draw [W]'}
    :return: dict with keys 't' (float seconds) and 'power_factor' (per-unit power)
    """
    # Read CSV with timestamp parsing
    df = pd.read_csv(file, parse_dates=[keys['t']])
    # Convert t0, t1 to datetime
    t0_dt = pd.to_datetime(t0)
    t1_dt = pd.to_datetime(t1)
    # Filter by time range
    mask = (df[keys['t']] >= t0_dt) & (df[keys['t']] <= t1_dt)
    df = df.loc[mask, [keys['t'], keys['p']]].copy()
    # Rename columns to standardized names
    df.rename(columns={keys['t']: 't', keys['p']: 'power'}, inplace=True)
    # Compute per-unit power
    max_p = df['power'].max()
    df['power_factor'] = df['power'] / max_p
    # Reset time to start from zero (in seconds)
    df['t'] = (df['t'] - df['t'].iloc[0]).dt.total_seconds()
    # Return dictionary of arrays
    return {'t': df['t'].to_numpy(), 'compute_power_factor': df['power_factor'].to_numpy()}


def load_v0(file, keys, dt):
    """
    :param file: str, path to the csv file
    :param t0: str, start time in 'YYYY/MM/DD HH:MM:SS.sss'
    :param t1: str, end time in 'YYYY/MM/DD HH:MM:SS.sss'
    :param keys: dict, e.g. {'t': 'timestamp', 'v0': 'voltage [V]'}
    :return: dict with keys 't' (float seconds) and 'v0' (voltage)
    """
    # Read CSV with timestamp parsing
    if file.endswith('.csv'):
        df = pd.read_csv(file, parse_dates=[keys['t']])
    elif file.endswith('.mat'):
        df = sp.io.loadmat(file)
        df = pd.DataFrame({'v0': df[keys['v0']][3, 0, 3]})

    # Create time column
    df['t'] = dt * np.arange(0, len(df['v0']))

    # Return dictionary of arrays
    return {'t': df['t'].to_numpy(), 'v0': df['v0'].to_numpy()}


def align_data(data, dt):
    """
    Align multiple datasets by a common time base using linear interpolation.
    :param data: dict of named dicts, each with keys 't' and one other data array
    :param resample_interval: float, time step in seconds for interpolation
    :return: None (data is modified in place)
    """
    aligned_data = {}
    # Determine intersection of time ranges
    starts = []
    ends = []
    for entry in data.values():
        t_arr = np.array(entry['t'], dtype=float)
        starts.append(t_arr[0])
        ends.append(t_arr[-1])
    t_start = max(starts)
    t_end = min(ends)
    # Create new common time vector
    aligned_data['t'] = np.arange(t_start, t_end, dt)
    # Interpolate each series onto new time base
    for name, entry in data.items():
        # Identify data field (exclude 't')
        for k, v in entry.items():
            if k == 't':
                continue
            # Linear interpolation
            aligned_data[k] = np.interp(aligned_data['t'], entry['t'], v)
    return aligned_data


# if __name__ == "__main__":
#     R_matrix, X_matrix, C_matrix, node_list, edge_list = single_phase_lindistflow(vulcan_circuit_data)
#     print("R_matrix:", R_matrix.shape)
#     print("X_matrix:", X_matrix.shape)
#     print("C_matrix:", C_matrix.shape)
#     print("Edge list:", len(edge_list))
#     print("Node list:", len(node_list))

#     file = 'data/compute-power-readings/llama_b16_i512_o128_tp4/nvidiasmi_monitor.csv'
#     t0, t1 = '2023/10/18 17:41:36.473', '2023/10/18 17:42:22.703'
#     keys = {'t': 'timestamp', 'p': 'power.draw [W]'}
#     compute_power = load_compute_power(file, t0, t1, keys)

#     file = 'data/record_trajectory_LossGen.mat'
#     keys = {'v0': 'record_trajectory'}
#     dt = 1e-2  # Resample interval in seconds
#     v0 = load_v0(file, keys, dt)

#     data = {'compute_power': compute_power, 'v0': v0}
#     resample_dt = 1e-2
#     aligned_data = align_data(data, resample_dt)
#     for k, v in aligned_data.items():
#         print(f"{k}: {v.shape}")

# %%
def load_compute_power_ms(file, t0, t1, keys):
    """
    :param file: str, path to the csv file
    :param t0: str, start time in 'YYYY/MM/DD HH:MM:SS.sss'
    :param t1: str, end time in 'YYYY/MM/DD HH:MM:SS.sss'
    :param keys: dict, e.g. {'t': 'timestamp', 'p': 'power.draw [W]'}
    :return: dict with keys 't' (float seconds) and 'power_factor' (per-unit power)
    """
    # Read CSV with timestamp parsing
    df = pd.read_csv(file)

    t0 = 35
    t1 = 50

    # Filter by numeric time range
    mask = (df['time_s'] >= t0) & (df['time_s'] <= t1)
    df = df.loc[mask, ['time_s', 'gpu_power_norm']].copy()

    if df.empty:
        result = {'t': np.array([]), 'compute_power_factor': np.array([])}
    else:
        # Rename columns
        df.rename(columns={'time_s': 't', 'gpu_power_norm': 'power'}, inplace=True)

        # Reset time to start from zero
        df['t'] = df['t'] - df['t'].iloc[0]

        # Compute per-unit power
        max_p = df['power'].max()
        df['power_factor'] = df['power'] / max_p if max_p != 0 else 0

        return {
            't': df['t'].to_numpy(),
            'compute_power_factor': df['power_factor'].to_numpy()
        }

# %%
import pandas as pd
import numpy as np

file = 'data/compute-power-readings/gpu_compute_power_Choukse_power_stabilization.csv'
df = pd.read_csv(file)

t0 = 35
t1 = 45

# Filter by numeric time range
mask = (df['time_s'] >= t0) & (df['time_s'] <= t1)
df = df.loc[mask, ['time_s', 'gpu_power_norm']].copy()

if df.empty:
    result = {'t': np.array([]), 'compute_power_factor': np.array([])}
else:
    # Rename columns
    df.rename(columns={'time_s': 't', 'gpu_power_norm': 'power'}, inplace=True)

    # Reset time to start from zero
    df['t'] = df['t'] - df['t'].iloc[0]

    # Compute per-unit power
    max_p = df['power'].max()
    df['power_factor'] = df['power'] / max_p if max_p != 0 else 0

    result = {
        't': df['t'].to_numpy(),
        'compute_power_factor': df['power_factor'].to_numpy()
    }

# result

# %%
plt.plot(df['t'],df['power_factor'])
plt.xlabel('time(s)')
plt.ylabel(' P')
# Out:
# Text(0, 0.5, ' P')

# %%
vulcan_circuit_data = [
    {
        'element_name': 'line_grid_utility_a_pri',
        'source': 'interconnection_a',
        'target': 'utility_a_pri',
        'series_impedance': 0.000571+0.006432j,           # 345kV line, 10 mile, in p.u.
    },
    {
        'element_name': 'tr_utility_a_mv',
        'source': 'utility_a_pri',
        'target': 'mv_distribution_bus',
        'series_impedance': 9.14e-06+0.000163975j,      # 400MVA rating, in p.u.
    },
    {
        'element_name': 'tr_mv_bat_1',
        'source': 'mv_distribution_bus',
        'target': 'batt_1_sec',
        'series_impedance': 5e-05+0.001663j,           # 100MVA rating
    },
    {
        'element_name': 'tr_mv_bat_2',
        'source': 'mv_distribution_bus',
        'target': 'batt_2_sec',
        'series_impedance': 5e-05+0.001663j,        # 20MVA rating
    },
    {
        'element_name': 'tr_mv_cooling_1',
        'source': 'mv_distribution_bus',
        'target': 'cooling_1_sec',
        'series_impedance': 6.235e-05+0.00207875j,        # 20MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_1',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_1_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_2',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_2_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_3',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_3_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_4',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_4_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_5',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_5_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_6',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_6_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_7',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_7_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
    {
        'element_name': 'tr_mv_datacenter_8',
        'source': 'mv_distribution_bus',
        'target': 'datacenter_8_sec',
        'series_impedance': 0.0001995+0.006652j,        # 25MVA rating
    },
]

vulcan_bus_data = {
    'interconnection_a': {'qmin': 0, 'qmax': 0, 'type': 'grid'},
    'utility_a_pri': {'qmin': 0, 'qmax': 0, 'type': 'internal'},
    'mv_distribution_bus': {'qmin': 0, 'qmax': 0, 'type': 'internal'},
    'batt_1_sec': {'qmin': -100, 'qmax': 100, 'p_rating': 100, 'type': 'battery'},
    'batt_2_sec': {'qmin': -100, 'qmax': 100, 'p_rating': 100, 'type': 'battery'},
    'cooling_1_sec': {'qmin': 0, 'qmax': 0, 'p_rating': 80, 'type': 'cooling'},
    'datacenter_1_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
    'datacenter_2_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
    'datacenter_3_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
    'datacenter_4_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
    'datacenter_5_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
    'datacenter_6_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
    'datacenter_7_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
    'datacenter_8_sec': {'qmin': -4, 'qmax': 4, 'p_rating': 5, 'type': 'compute'},
}

# %%
# def decentralized_K(X):
#     # First, find the K matrix.
#     N = X.shape[0]
#     beta = np.ones(N)

#     # Variables
#     k = cp.Variable(N)

#     # Objective: maximize sum(beta_i * log(k_i))
#     objective = cp.Maximize(cp.sum(cp.multiply(beta, cp.log(k))))

#     # Constraints: 0 < k_i < 2^(X-1)
#     constraints = [
#         k >= 1e-6,  # strictly positive (use small epsilon)
#         cp.diag(k) <= 2 * np.linalg.inv(X)
#     ]

#     # Problem definition
#     prob = cp.Problem(objective, constraints)
#     prob.solve()

#     print("Optimal k:", k.value)
#     return k.value


# def controller_decentralized(v, K, q_t):
#     """
#     Decentralized safe reinforcement learning for inverter-based voltage control
#     """
#     q = q_t - K * v
#     return q


def controller_centralized_optimization(v, X, q_min, q_max, ctrl_cost=1e-9, v_cost=1,):
    # Compute the optimal control action
    q = cp.Variable(len(v))
    objective = cp.Minimize(
        # ctrl_cost * cp.sum_squares(q) +
        cp.quad_form(v + 2 * X @ q - 1, np.diag(np.ones(len(v)) * v_cost))
    )
    constraints = [
        q >= q_min,
        q <= q_max
    ]
    prob = cp.Problem(objective, constraints)
    prob.solve()
    assert prob.status == 'optimal'
    # todo: add active power support
    return 0, q.value


def run_simulation(CENTRALIZED__CTRL_DELAY_STEPS=2):
    """
    Run the simulation with either decentralized or centralized control.
    :param v: voltage vector
    :param R: resistance matrix
    :param X: reactance matrix
    :param K: control gain
    :param centralized: bool, whether to use centralized control
    :return: None
    """
    # Load data
    R_matrix, X_matrix, C_matrix, node_list, edge_list = \
        load_data.single_phase_lindistflow(vulcan_circuit_data)
    N = len(node_list) - 1

    # file = 'data/compute-power-readings/llama_b16_i512_o128_tp4/nvidiasmi_monitor.csv'
    file = 'data/compute-power-readings/gpu_compute_power_Choukse_power_stabilization.csv'
    t0, t1 = '2023/10/18 17:41:36.473', '2023/10/18 17:42:22.703'
    keys = {'t': 'timestamp', 'p': 'power.draw [W]'}
    compute_power = load_data.load_compute_power_ms(file, t0, t1, keys)

    file = 'data/record_trajectory_LossGen_t0.001.mat'
    keys = {'v0': 'record_trajectory'}
    dt = 1e-3  # Resample interval in seconds
    v0 = load_data.load_v0(file, keys, dt)

    data = {'compute_power': compute_power, 'v0': v0}
    resample_dt = 1e-3
    aligned_data = load_data.align_data(data, resample_dt)
    T = len(aligned_data['t'])
    print(f"Loaded data with {C_matrix.shape} nodes and edges and {T} time steps.")

    # Simulation parameters
    q_min, q_max = np.zeros(N), np.zeros(N)
    p_inj = np.zeros((T, N))


    for n, node in enumerate(node_list[1:]):
        q_min[n] = vulcan_bus_data[node]['qmin']
        q_max[n] = vulcan_bus_data[node]['qmax']
        if vulcan_bus_data[node]['type'] == 'compute':
            p_inj[:, n] = -vulcan_bus_data[node]['p_rating'] * aligned_data['compute_power_factor']
        elif vulcan_bus_data[node]['type'] == 'cooling':
            p_inj[:, n] = -vulcan_bus_data[node]['p_rating'] * np.mean(aligned_data['compute_power_factor'])


    v_solution = {
        't': aligned_data['t'],
        'v0': aligned_data['v0'],
        'compute_power_factor': aligned_data['compute_power_factor'],
        'no_control': np.zeros((T, N)),
        'centralized': np.zeros((T, N)),
        'decentralized': np.zeros((T, N)),
    }


    p_ctrl_cen, q_ctrl_cen = np.zeros((T + CENTRALIZED__CTRL_DELAY_STEPS, N)), np.zeros((T + CENTRALIZED__CTRL_DELAY_STEPS, N))
    for t in range(T):
        p = p_inj[t]
        v0 = aligned_data['v0'][t]
        # Compute voltage without control
        v = v0 + 2 * R_matrix @ p
        v_solution['no_control'][t, :] = v
        # Apply centralized control
        p_t, q_t = controller_centralized_optimization(v, X_matrix, q_min, q_max)
        p_ctrl_cen[t + CENTRALIZED__CTRL_DELAY_STEPS] = p_t
        q_ctrl_cen[t + CENTRALIZED__CTRL_DELAY_STEPS] = q_t
        v = v0 + 2 * (R_matrix @ (p + p_ctrl_cen[t]) + X_matrix @ q_ctrl_cen[t])
        v_solution['centralized'][t, :] = v
        # # Apply decentralized control
        # q = controller_decentralized(v, K, q_t)
        # v = v0 + 2 * (R_matrix @ p + X_matrix @ q)
        # v_solution['decentralized'][t, :] = v
    v_solution['p_ctrl_centralized'] = p_ctrl_cen[:T]
    v_solution['q_ctrl_centralized'] = q_ctrl_cen[:T]
    return v_solution


def plot_simulation(t, V, P, Q, title, nodes_to_plot=None, out_path='temp', ext='png', figsize=(12, 3)):
    N = V.shape[1]
    if not nodes_to_plot:
        nodes_to_plot = list(range(min(10, N)))

    fig, axes = plt.subplots(1, 3, figsize=figsize, constrained_layout=False)
    fig.suptitle(title)

    # Voltages
    for i in nodes_to_plot:
        axes[0].plot(t, V[:, i], label=f"Node {i+1}")
    axes[0].set_xlabel("time(s)")
    axes[0].set_ylabel("V (p.u.)")
    axes[0].grid(True, alpha=0.3)

    # Action P
    for i in nodes_to_plot:
        axes[1].plot(t, P[:, i], label=f"Node {i+1}")
    axes[1].set_xlabel("time(s)")
    axes[1].set_ylabel("Action P")
    axes[1].grid(True, alpha=0.3)

    # Action Q
    for i in nodes_to_plot:
        axes[2].plot(t, Q[:, i], label=f"Node {i+1}")
    axes[2].set_xlabel("time(s)")
    axes[2].set_ylabel("Action Q")
    axes[2].grid(True, alpha=0.3)

    plt.legend()
    plt.tight_layout()
    os.makedirs(out_path, exist_ok=True)
    plt.savefig(os.path.join(out_path, f"{title}.{ext}"))

# %%
import utils

# %%
    """
    Run the simulation with either decentralized or centralized control.
    :param v: voltage vector
    :param R: resistance matrix
    :param X: reactance matrix
    :param K: control gain
    :param centralized: bool, whether to use centralized control
    :return: None
    """
    CENTRALIZED__CTRL_DELAY_STEPS=2
    # Load data
    R_matrix, X_matrix, C_matrix, node_list, edge_list = \
        single_phase_lindistflow(vulcan_circuit_data)
    N = len(node_list) - 1

    # file = 'data/compute-power-readings/llama_b16_i512_o128_tp4/nvidiasmi_monitor.csv'
    file = 'data/compute-power-readings/gpu_compute_power_Choukse_power_stabilization.csv'

    t0, t1 = '2023/10/18 17:41:36.473', '2023/10/18 17:42:22.703'
    keys = {'t': 'timestamp', 'p': 'power.draw [W]'}
    compute_power = load_compute_power_ms(file, t0, t1, keys)

    file = 'data/record_trajectory_LossGen_t0.001.mat'
    keys = {'v0': 'record_trajectory'}
    dt = 1e-3  # Resample interval in seconds
    v0 = load_v0(file, keys, dt)

    data = {'compute_power': compute_power, 'v0': v0}
    resample_dt = 1e-3
    aligned_data = align_data(data, resample_dt)
    T = len(aligned_data['t'])
    print(f"Loaded data with {C_matrix.shape} nodes and edges and {T} time steps.")

    # Simulation parameters
    q_min, q_max = np.zeros(N), np.zeros(N)
    p_inj = np.zeros((T, N))
    for n, node in enumerate(node_list[1:]):
        q_min[n] = vulcan_bus_data[node]['qmin']
        q_max[n] = vulcan_bus_data[node]['qmax']
        if vulcan_bus_data[node]['type'] == 'compute':
            p_inj[:, n] = -vulcan_bus_data[node]['p_rating'] * aligned_data['compute_power_factor']
        elif vulcan_bus_data[node]['type'] == 'cooling':
            p_inj[:, n] = -vulcan_bus_data[node]['p_rating'] * np.mean(aligned_data['compute_power_factor'])
    v0_move = 0
    p_inj = 2*p_inj

    Q_ref = -1*(LA.inv(X_matrix))@R_matrix@np.mean(p_inj[0:100],axis=0)

    v_solution = {
        't': aligned_data['t'],
        'v0': aligned_data['v0'],
        'compute_power_factor': aligned_data['compute_power_factor'],
        'no_control': np.zeros((T-v0_move, N)),
        'centralized': np.zeros((T-v0_move, N)),
        'decentralized': np.zeros((T-v0_move, N)),
    }
    p_ctrl_cen, q_ctrl_cen = np.zeros((T + CENTRALIZED__CTRL_DELAY_STEPS- v0_move, N)), np.zeros((T + CENTRALIZED__CTRL_DELAY_STEPS- v0_move, N))
    for t in range(T- v0_move):
        p = p_inj[t]
        v0 = aligned_data['v0'][v0_move+t]
        # Compute voltage without control
        v = v0 + 2 * R_matrix @ p + 2 * X_matrix @ Q_ref
        v_solution['no_control'][t, :] = v
        # Apply centralized control
        p_t, q_t = controller_centralized_optimization(v, X_matrix, q_min, q_max)
        p_ctrl_cen[t + CENTRALIZED__CTRL_DELAY_STEPS] = p_t
        q_ctrl_cen[t + CENTRALIZED__CTRL_DELAY_STEPS] = q_t
        v = v0 + 2 * (R_matrix @ (p + p_ctrl_cen[t]) + X_matrix @ (Q_ref+q_ctrl_cen[t]))
        v_solution['centralized'][t, :] = v
        # # Apply decentralized control
        # q = controller_decentralized(v, K, q_t)
        # v = v0 + 2 * (R_matrix @ p + X_matrix @ q)
        # v_solution['decentralized'][t, :] = v
    v_solution['p_ctrl_centralized'] = p_ctrl_cen[:T- v0_move]
    v_solution['q_ctrl_centralized'] = q_ctrl_cen[:T- v0_move]
    # return v_solution
# Out:
# graphviz not installed or error. Using spring layout.
# Loaded data with (14, 13) nodes and edges and 9999 time steps.

# %%
aligned_data['v0'][T- v0_move:]

# %%
plt.plot(aligned_data['v0'])

# %%
plot_simulation(v_solution['t'][:T- v0_move], v_solution['centralized'][:T- v0_move], v_solution['p_ctrl_centralized'][:T- v0_move], v_solution['q_ctrl_centralized'][:T- v0_move], "With Centralized Controller")
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/exp_Centralized_MS_F4.png', bbox_inches='tight', dpi=600)

plot_simulation(v_solution['t'][:T- v0_move], v_solution['no_control'][:T- v0_move], np.zeros_like(v_solution['no_control'][:T- v0_move]), np.zeros_like(v_solution['no_control'][:T- v0_move]), "Without control")

# %%
# plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/Decentralized.png', bbox_inches='tight', dpi=600)

# %% [markdown]
# ## initialize the variables and system matrices

# %%
# Frequency Control Porblem Environment
class Voltage(gym.Env):
    def  __init__(self, Matrix_X,Matrix_R, max_action,dim_action,Penalty_action):
        self.param_gamma=1
        self.Matrix_X = Matrix_X.astype(np.float32)
        self.Matrix_R = Matrix_R.astype(np.float32)
        self.inv_Matrix_X = LA.inv(Matrix_X).astype(np.float32)
        self.lambda_max = np.max(LA.eigvals(Matrix_X))
        self.max_action = max_action.astype(np.float32)
        self.dim_action=dim_action
        self.delta_t = 1
        self.state=[]
        self.Penalty_action=Penalty_action


    def step(self, action):
        # action=K.dot(self.Multiply_V_ref-K.dot(prev_output, self.select_V),tf.linalg.diag(Vector_A))
        # integrate the state transition dynamics

        self.state=(self.state-action@(self.Matrix_X.T)).copy()
        # loss = self.param_gamma*np.sum(abs(self.V_ref.T-self.state@self.select_V))
        return self.state

    def step_varyingP(self, action, Pt):


        self.state=(self.state-action@(self.Matrix_X.T)+Pt@(self.Matrix_R.T)).copy()
        return self.state

    def set_state(self, state_input):
        self.state=state_input


    def reset(self):
        self.state = np.random.uniform(-1,1,(1,self.dim_action)).astype(np.float32)

        return self.state

# %%
# Simulation data load from IEEE 39-bus system
# data = loadmat('/content/drive/MyDrive/Colab Notebooks/voltage control/TestCase33.mat')
# filename='TestCase'
Matrix_R=2*R_matrix

Matrix_X=2*X_matrix
dim_action=np.shape(Matrix_X)[0]
V_ref=np.ones((dim_action,1))

# Q_ref=np.array([[ 3.75633894e-06],
#        [ 3.89703169e-06],
#        [-3.50238264e-01],
#        [-1.17711040e-01],
#        [ 7.29899859e-06],
#        [ 3.01891400e-01],
#        [ 3.01891400e-01]])

P_ref=np.mean(p_inj[0:100],axis=0)

X = Matrix_X

# %%
P_ref
# Out:
# array([   0.        ,    0.        ,    0.        ,    0.        ,
#        -113.95652572,   -8.10348735,   -8.10348735,   -8.10348735,
#          -8.10348735,   -8.10348735,   -8.10348735,   -8.10348735,
#          -8.10348735])

# %%
Penalty_action=0.1
max_action= q_max
# np.random.uniform(low=0.01, high=0.05, size=(1,dim_action))
# V_ref=Matrix_R@P_ref+Matrix_X@Q_ref+np.ones((dim_action,1))
Q_ref = -1*(LA.inv(Matrix_X))@Matrix_R@P_ref
env = Voltage(Matrix_X,Matrix_R, max_action,dim_action,Penalty_action)

# %%
q_max
# Out:
# array([  0.,   0., 100., 100.,   0.,   4.,   4.,   4.,   4.,   4.,   4.,
#          4.,   4.])

# %%
Q_ref
# Out:
# array([ 5.90608470e+00,  4.60321760e+00, -1.09184521e-15, -1.09184521e-15,
#         3.41801053e+00,  2.43031528e-01,  2.43031528e-01,  2.43031528e-01,
#         2.43031528e-01,  2.43031528e-01,  2.43031528e-01,  2.43031528e-01,
#         2.43031528e-01])

# %%
lambda_max = np.max(LA.eigvals(Matrix_X))
print(LA.eigvals(Matrix_X))
2/lambda_max
# Out:
# [1.80096015e-01 6.69497008e-03 1.43672092e-04 1.16085058e-03
#  3.85939226e-03 1.33040000e-02 3.32600000e-03 1.33040000e-02
#  1.33040000e-02 1.33040000e-02 1.33040000e-02 1.33040000e-02
#  1.33040000e-02]
# np.float64(11.10518742007339)

# %% [markdown]
# # CVX

# %% [markdown]
# ## Bounds for linear coefficients

# %%
Matrix_X_inv=np.linalg.inv(Matrix_X)

# %%
# weight_bound = np.ones(dim_action)

# K_bound=cp.Variable(dim_action,nonneg =True)
# objective = cp.Maximize(cp.sum(weight_bound*cp.log(K_bound)))
# diag_K_bound = cp.diag(K_bound)
# constraints = [(diag_K_bound -2*Matrix_X_inv)<<0,diag_K_bound>>0]

# prob = cp.Problem(objective, constraints)
# result = prob.solve()
# print('status',prob.status)
# K_bound=np.array(K_bound.value)

# %%
Matrix_X_inv=np.linalg.inv(Matrix_X)
Matrix_R_inv=np.linalg.inv(Matrix_R)

# %%
ratio_q = 0.5
K_bound=cp.Variable(dim_action,nonneg =True)
objective = cp.Maximize(cp.sum(cp.log(K_bound)))
diag_K_bound = cp.diag(K_bound)
constraints = [(diag_K_bound -ratio_q*2*Matrix_X_inv)<<0,diag_K_bound>>0]

prob = cp.Problem(objective, constraints)
result = prob.solve()
print('status',prob.status)
K_bound_q=np.array(K_bound.value)

ratio_p = 1 - ratio_q
K_bound=cp.Variable(dim_action,nonneg =True)
objective = cp.Maximize(cp.sum(cp.log(K_bound)))
diag_K_bound = cp.diag(K_bound)
constraints = [(diag_K_bound -ratio_p*2*Matrix_R_inv)<<0,diag_K_bound>>0]

prob = cp.Problem(objective, constraints)
result = prob.solve()
print('status',prob.status)
K_bound_p=np.array(K_bound.value)

print('K_bound_p', K_bound_p)
print('K_bound_q', K_bound_q)
# Out:
# status optimal
# status optimal
# K_bound_p [69.48057394 67.47710163 66.58160031 66.58160032 66.36478804 64.07117701
#  64.07117698 64.07117701 64.071177   64.071177   64.07117703 64.07117702
#  64.07117701]
# K_bound_q [6.41753262 6.12753833 5.88982827 5.88982827 5.83391239 5.29469227
#  5.29469227 5.29469227 5.29469227 5.29469227 5.29469227 5.29469227
#  5.29469227]

# %% [markdown]
# ## LQR results for comparison

# %%
from scipy import linalg

# %%
def dlqr(A,B,Q,R):
    """Solve the discrete time lqr controller.


    x[k+1] = A x[k] + B u[k]

    cost = sum x[k].T*Q*x[k] + u[k].T*R*u[k]

    cite: http://www.kostasalexis.com/lqr-control.html
    """
    #ref Bertsekas, p.151

    #first, try to solve the ricatti equation
    X_ = np.matrix(linalg.solve_discrete_are(A, B, Q, R))

    #compute the LQR gain
    K_ = -np.matrix(linalg.inv(B.T@X_@B+R)*(B.T@X_@A))

    eigVals, eigVecs = linalg.eig(A+B@K_)

    return -K_, X_, eigVals

# %%
A_m = np.eye(dim_action)
B_m = np.hstack((Matrix_X, Matrix_R))
Q = np.eye(dim_action)
R = 1*np.eye(dim_action*2)
K_, X_, eigVals = dlqr(A_m,B_m,Q,R)

# %%
np.diag(K_)
# Out:
# array([0.98356325, 0.98856614, 0.99157896, 0.99157896, 0.99116984,
#        0.98664946, 0.98664946, 0.98664946, 0.98664946, 0.98664946,
#        0.98664946, 0.98664946, 0.98664946])

# %% [markdown]
# # Init Simulation

# %%
#linear droop control
def Action_linear(state,linear_coff):
    action_nonconstrain = state*linear_coff
    action=action_nonconstrain
    # env.max_action-tf.nn.relu(env.max_action-action_nonconstrain)+tf.nn.relu(-env.max_action-action_nonconstrain)
    return action

# def Action_constraints(action_nonconstrain, action_max, action_min):
#     action=
#     # env.max_action-K.relu(env.max_action-action_nonconstrain)+K.relu(-env.max_action-action_nonconstrain)
#     return action
# def Action_constraints(action_nonconstrain):
#     action=env.max_action-K.relu(env.max_action-action_nonconstrain)+K.relu(-env.max_action-action_nonconstrain)
#     return action

# %%
linear_coffp= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
linear_coffq= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
# linear_coffp= K_[0:dim_action].reshape((1,-1))
# linear_coffq= K_[dim_action:].reshape((1,-1))
action_units=dim_action

# %%
p_inj_diff = np.diff(p_inj, axis=0)

# %%
TimeRecord=np.arange(0,p_inj.shape[0])

plt.plot(TimeRecord,p_inj[:,5])
plt.xlabel('time(s)')
plt.ylabel(' P')
# Out:
# Text(0, 0.5, ' P')

# %%
p_inj.shape
# Out:
# (9999, 13)

# %%
# TimeRecord=np.arange(0,p_inj_diff.shape[0])

# plt.plot(TimeRecord,p_inj_diff)
# plt.xlabel('time(s)')
# plt.ylabel(' P')

# %% [markdown]
# ### With V0 after fault, time-varying p

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = p_inj[0]
# P_ref
record_v0 = record_fault_trajectory[3,0,3,0:]

s_concate=P@Matrix_R.T+Q@Matrix_X.T+ record_v0[0]
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=9000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Record_up_Linear.append(np.zeros(dim_action))
Record_uq_Linear.append(np.zeros(dim_action) )
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
for i in range(1,SimulationLength):
    up=0*np.squeeze(Action_linear(s-1,linear_coffp))
    uq=np.squeeze(Action_linear(s-1,linear_coffq))
    p = Record_up_Linear[-1]- up
    q = Record_uq_Linear[-1]- uq
    q = np.minimum(np.maximum(q, q_min), q_max)
    next_s= (Q_ref+q)@Matrix_X + p@Matrix_R + record_v0[i]+ (p_inj[i])@Matrix_R
    # s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(p.copy())
    Record_uq_Linear.append(q.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [0.99833549 0.99835366 0.99835366 0.99835366 0.99835366 0.99840325
#  0.99840325 0.99840325 0.99840325 0.99840325 0.99840325 0.99840325
#  0.99840325]

# %% [markdown]
# ### With V0 after fault, constant p

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref

s_concate=P@Matrix_R.T+Q@Matrix_X.T+ record_v0[0]
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Record_up_Linear.append(np.zeros(dim_action))
Record_uq_Linear.append(np.zeros(dim_action))
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
for i in range(1,SimulationLength):
    up=0*np.squeeze(Action_linear(s-1,linear_coffp))
    uq=np.squeeze(Action_linear(s-1,linear_coffq))
    p = Record_up_Linear[-1]- up
    q = Record_uq_Linear[-1]- uq
    q = np.minimum(np.maximum(q, q_min), q_max)
    next_s= (Q_ref+q)@Matrix_X + p@Matrix_R + record_v0[i]+ (P_ref)@Matrix_R
    # s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(p.copy())
    Record_uq_Linear.append(q.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [0.9972 0.9972 0.9972 0.9972 0.9972 0.9972 0.9972 0.9972 0.9972 0.9972
#  0.9972 0.9972 0.9972]

# %% [markdown]
# ### Without control

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = p_inj[0]
# P_ref
record_v0 = record_fault_trajectory[3,0,3,0:]

s_concate=P@Matrix_R.T+Q@Matrix_X.T+ record_v0[0]
init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Record_up_Linear.append(np.zeros(dim_action))
Record_uq_Linear.append(np.zeros(dim_action) )
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
for i in range(1,SimulationLength):
    up=0*np.squeeze(Action_linear(s-1,linear_coffp))
    uq=0*np.squeeze(Action_linear(s-1,linear_coffq))
    p = Record_up_Linear[-1]- up
    q = Record_uq_Linear[-1]- uq
    q = np.minimum(np.maximum(q, q_min), q_max)
    next_s= (Q_ref+q)@Matrix_X + p@Matrix_R + record_v0[i]+ (p_inj[i])@Matrix_R
    # s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(p.copy())
    Record_uq_Linear.append(q.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [0.99833549 0.99835366 0.99835366 0.99835366 0.99835366 0.99840325
#  0.99840325 0.99840325 0.99840325 0.99840325 0.99840325 0.99840325
#  0.99840325]

# %%
plt.plot(p_inj[:,5])

# %% [markdown]
# # Init Simulation Diff

# %%
#linear droop control
def Action_linear(state,linear_coff):
    action_nonconstrain = state*linear_coff
    action=action_nonconstrain
    # env.max_action-tf.nn.relu(env.max_action-action_nonconstrain)+tf.nn.relu(-env.max_action-action_nonconstrain)
    return action
def Action_constraints(action_nonconstrain):
    action=env.max_action-K.relu(env.max_action-action_nonconstrain)+K.relu(-env.max_action-action_nonconstrain)
    return action

# %%
linear_coffp= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
linear_coffq= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
# linear_coffp= K_[0:dim_action].reshape((1,-1))
# linear_coffq= K_[dim_action:].reshape((1,-1))
action_units=dim_action

# %%
p_inj_diff = np.diff(p_inj, axis=0)

# %%
TimeRecord=np.arange(0,p_inj.shape[0])

plt.plot(TimeRecord,p_inj)
plt.xlabel('time(s)')
plt.ylabel(' P')
# Out:
# Text(0, 0.5, ' P')

# %%
TimeRecord=np.arange(0,p_inj_diff.shape[0])

plt.plot(TimeRecord,p_inj_diff)
plt.xlabel('time(s)')
plt.ylabel(' P')
# Out:
# Text(0, 0.5, ' P')

# %% [markdown]
# ### With V0 after fault, time-varying p

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Record_up_Linear.append(P.copy())
Record_uq_Linear.append(Q.copy() )
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = record_fault_trajectory[3,0,3,0:]
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    p = Record_up_Linear[-1]- up
    q = Record_uq_Linear[-1]- uq
    next_s= q@Matrix_X + p@Matrix_R + record_v0[i]+ p_inj[i]@Matrix_R
    # s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1870884003.py in <cell line: 0>()
#      48 TimeRecord=delta_t*TimeRecord
#      49 plt.subplot(1,3,2)
# ---> 50 plt.plot(TimeRecord,Record_up_Linear)
#      51 plt.xlabel('time(s)')
#      52 plt.ylabel('Action P')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295                 this += args[0],
#     296                 args = args[1:]
# --> 297             yield from self._plot_args(
#     298                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299                 return_kwargs=return_kwargs
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     492
#     493         if x.shape[0] != y.shape[0]:
# --> 494             raise ValueError(f"x and y must have same first dimension, but "
#     495                              f"have shapes {x.shape} and {y.shape}")
#     496         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (6000,) and (6001, 13)

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[3,0,3,0:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    p = Record_up_Linear[-1]- up
    q = Record_uq_Linear[-1]- uq
    next_s= q@Matrix_X + p@Matrix_R
    # s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %%
record_v0[1001]
# Out:
# np.float64(-0.00023096493934904316)

# %%
TimeRecord=np.arange(0,SimulationLength)

plt.plot(TimeRecord,p_inj[:SimulationLength,:])
plt.xlabel('time(s)')
plt.ylabel(' P')
# Out:
# Text(0, 0.5, ' P')

# %% [markdown]
# ### With V0 after fault, constant p

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
# Q_init_ratio = 0.7
# P_init_ratio = 0.7
# Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

# s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
# record_v0 = np.diff(record_fault_trajectory[1,0,0,1:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %% [markdown]
# ### Without control

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
# Q_init_ratio = 0.7
# P_init_ratio = 0.7
# Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

# s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=2000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
# record_v0 = np.diff(record_fault_trajectory[3,0,3,1100:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))*0
    uq=np.squeeze(Action_linear(s,linear_coffq))*0
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %% [markdown]
# ### With constant

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
# Q_init_ratio = 0.7
# P_init_ratio = 0.7
# delta_t = 1
# Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

# s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=1000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
# record_v0 =0* np.diff(record_fault_trajectory[0,0,0,1100:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %% [markdown]
# # Training -q

# %%
class RNNModel(tf.keras.Model):
    def __init__(self, cell):
        super().__init__()
        self.rnn = tf.keras.layers.RNN(cell, return_sequences=True, stateful=True)

    def call(self, inputs, initial_state=None):
        return self.rnn(inputs, initial_state=initial_state)

# %%
# RNN Cell to integrate state transition dynamics
class MinimalRNNCellLinear0(keras.layers.Layer):

    def __init__(self, units,action_units,internal_units,env,batchsize,K_boundq, K_boundp,**kwargs):
        self.units = units
        self.action_units = action_units
        self.state_size = units
        self.internal_units = internal_units
        self.batchsize=batchsize
        self.Matrix_X=tf.constant(env.Matrix_X,dtype=tf.float32)
        self.Matrix_R=tf.constant(env.Matrix_R,dtype=tf.float32)
        self.inv_Matrix_X = tf.constant(env.inv_Matrix_X,dtype=tf.float32)
        self.lambda_max = tf.constant(env.lambda_max,dtype=tf.float32)
        self.max_action=tf.constant(env.max_action,dtype=tf.float32)
        self.bound_slopq = tf.constant(K_boundq.reshape((1,-1)),dtype=tf.float32)
        self.bound_slopp = tf.constant(K_boundp.reshape((1,-1)),dtype=tf.float32)
        self.norm_q=1
        super(MinimalRNNCellLinear0, self).__init__(**kwargs)

    def build(self, input_shape):


        self.linear_Kq= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kq')
        self.built = True

    def call(self, inputs_concate, states):
        # stacked ReLU structure to represent control network
        prev_state = states[0]
        prev_state_x = prev_state[:,0:self.action_units]
        prev_state_q =  prev_state[:,self.action_units:2*self.action_units]
        inputs_p = inputs_concate[:,0:self.action_units]
        inputs_v0 = inputs_concate[:,self.action_units:self.action_units+1]


        linear_Kq_=tf.math.minimum(self.linear_Kq, self.bound_slopq )
        action_q= K.sum(tf.linalg.diag(prev_state_x-1)*linear_Kq_,axis=2)
        action_nonconstrain = prev_state_q - action_q
        new_state_q=self.max_action-K.relu(self.max_action-action_nonconstrain)+K.relu(-self.max_action-action_nonconstrain)

        new_state_x=K.dot(new_state_q, tf.transpose(self.Matrix_X))+ K.dot(inputs_p, tf.transpose(self.Matrix_R)) + K.dot(inputs_v0, tf.ones((1,self.action_units)))

        next_state =  tf.concat([new_state_x, new_state_q], axis = 1)


        return [new_state_x,action_q, new_state_q], [next_state]

# %%
p_inj_diff = np.diff(p_inj, axis=0)

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*2 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

Length_pred_dataset = p_inj_diff.shape[0]-100
column1_idx = np.arange(0,dim_action)
PrintUpdate = 1
for i in range(0,episodes):
    initial_state_q = np.zeros((Batch_num,action_units))
    # (1- np.random.uniform(-Q_init_ratio,Q_init_ratio,(Batch_num,action_units)))*(Q_ref.T)
    # initial_state_p = (1- np.random.uniform(-P_init_ratio,P_init_ratio,(Batch_num,action_units)))*(P_ref.T)
    initial_state=np.ones((Batch_num,action_units))

    Input_config = np.zeros((Batch_num,T,dim_action+1))
    for j in range(Batch_num):
       #### time varying p
       t_init_Pm = np.random.randint(0, Length_pred_dataset-T-1)
       Input_config[j,:,:dim_action]=(p_inj[t_init_Pm:t_init_Pm+T,:]-p_inj[0,:])
       ###### v0
       rand_fault_idx = np.random.randint(0,np.shape(record_fault_trajectory)[0])
       rand_time_idx = np.random.randint(1050,1150)
       rand_bus_idx = np.random.randint(0,np.shape(record_fault_trajectory)[2])
       Input_config[j,:,dim_action] = record_fault_trajectory[rand_fault_idx,0,rand_bus_idx,rand_time_idx:rand_time_idx+T]


    with tf.GradientTape(persistent=True) as tape:
        [voltage,action_q,record_q]=modelLinear0(Input_config, np.hstack((initial_state, initial_state_q)))
        loss_voltage=K.sum(K.sum(K.abs(voltage)))/Batch_num/T/dim_action
        loss_action=0.0001*(env.Penalty_action*K.sum(abs(record_q)))/Batch_num/T/dim_action
        loss=loss_voltage+loss_action
    grads = tape.gradient(loss, modelLinear0.variables)
    optimizer.apply_gradients(zip(grads, modelLinear0.variables))
    Loss_record.append(loss)



    if i % (PrintUpdate) == 0:
        print('episode',i, 'Loss',loss)
        print('         Loss_Voltage',loss_voltage, '  loss_action', loss_action)
# Out:
# episode 0 Loss tf.Tensor(1.0035794, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.003578, shape=(), dtype=float32)   loss_action tf.Tensor(1.3807386e-06, shape=(), dtype=float32)
# episode 1 Loss tf.Tensor(1.0042769, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0042754, shape=(), dtype=float32)   loss_action tf.Tensor(1.4357413e-06, shape=(), dtype=float32)
# episode 2 Loss tf.Tensor(1.0044832, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0044818, shape=(), dtype=float32)   loss_action tf.Tensor(1.4550606e-06, shape=(), dtype=float32)
# episode 3 Loss tf.Tensor(1.0033331, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0033317, shape=(), dtype=float32)   loss_action tf.Tensor(1.4439182e-06, shape=(), dtype=float32)
# episode 4 Loss tf.Tensor(1.0039202, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0039186, shape=(), dtype=float32)   loss_action tf.Tensor(1.5121045e-06, shape=(), dtype=float32)
# episode 5 Loss tf.Tensor(1.003134, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0031326, shape=(), dtype=float32)   loss_action tf.Tensor(1.4713149e-06, shape=(), dtype=float32)
# episode 6 Loss tf.Tensor(1.0028859, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0028845, shape=(), dtype=float32)   loss_action tf.Tensor(1.433479e-06, shape=(), dtype=float32)
# episode 7 Loss tf.Tensor(1.0031247, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0031232, shape=(), dtype=float32)   loss_action tf.Tensor(1.494498e-06, shape=(), dtype=float32)
# episode 8 Loss tf.Tensor(1.0035138, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0035123, shape=(), dtype=float32)   loss_action tf.Tensor(1.5497443e-06, shape=(), dtype=float32)
# episode 9 Loss tf.Tensor(1.003247, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0032455, shape=(), dtype=float32)   loss_action tf.Tensor(1.5410266e-06, shape=(), dtype=float32)
# episode 10 Loss tf.Tensor(1.0026401, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0026386, shape=(), dtype=float32)   loss_action tf.Tensor(1.4915111e-06, shape=(), dtype=float32)
# episode 11 Loss tf.Tensor(1.0025629, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0025613, shape=(), dtype=float32)   loss_action tf.Tensor(1.5211959e-06, shape=(), dtype=float32)
# episode 12 Loss tf.Tensor(1.003117, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0031154, shape=(), dtype=float32)   loss_action tf.Tensor(1.5962601e-06, shape=(), dtype=float32)
# episode 13 Loss tf.Tensor(1.0028739, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0028723, shape=(), dtype=float32)   loss_action tf.Tensor(1.5871694e-06, shape=(), dtype=float32)
# episode 14 Loss tf.Tensor(1.0027807, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0027791, shape=(), dtype=float32)   loss_action tf.Tensor(1.5463787e-06, shape=(), dtype=float32)
# episode 15 Loss tf.Tensor(1.0027844, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0027828, shape=(), dtype=float32)   loss_action tf.Tensor(1.5724653e-06, shape=(), dtype=float32)
# episode 16 Loss tf.Tensor(1.0028329, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0028313, shape=(), dtype=float32)   loss_action tf.Tensor(1.5999726e-06, shape=(), dtype=float32)
# episode 17 Loss tf.Tensor(1.002836, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0028343, shape=(), dtype=float32)   loss_action tf.Tensor(1.6782259e-06, shape=(), dtype=float32)
# episode 18 Loss tf.Tensor(1.0020589, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0020573, shape=(), dtype=float32)   loss_action tf.Tensor(1.5890529e-06, shape=(), dtype=float32)
# episode 19 Loss tf.Tensor(1.0028771, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0028754, shape=(), dtype=float32)   loss_action tf.Tensor(1.6895956e-06, shape=(), dtype=float32)
# episode 20 Loss tf.Tensor(1.0011393, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011379, shape=(), dtype=float32)   loss_action tf.Tensor(1.4897772e-06, shape=(), dtype=float32)
# episode 21 Loss tf.Tensor(1.002624, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0026224, shape=(), dtype=float32)   loss_action tf.Tensor(1.6210016e-06, shape=(), dtype=float32)
# episode 22 Loss tf.Tensor(1.0020506, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.002049, shape=(), dtype=float32)   loss_action tf.Tensor(1.702454e-06, shape=(), dtype=float32)
# episode 23 Loss tf.Tensor(1.0024657, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.002464, shape=(), dtype=float32)   loss_action tf.Tensor(1.617448e-06, shape=(), dtype=float32)
# episode 24 Loss tf.Tensor(1.0020703, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0020686, shape=(), dtype=float32)   loss_action tf.Tensor(1.6876794e-06, shape=(), dtype=float32)
# episode 25 Loss tf.Tensor(1.0014002, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013987, shape=(), dtype=float32)   loss_action tf.Tensor(1.5164635e-06, shape=(), dtype=float32)
# episode 26 Loss tf.Tensor(1.0019346, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001933, shape=(), dtype=float32)   loss_action tf.Tensor(1.643907e-06, shape=(), dtype=float32)
# episode 27 Loss tf.Tensor(1.0021191, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0021174, shape=(), dtype=float32)   loss_action tf.Tensor(1.7009309e-06, shape=(), dtype=float32)
# episode 28 Loss tf.Tensor(1.0015595, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0015578, shape=(), dtype=float32)   loss_action tf.Tensor(1.6567685e-06, shape=(), dtype=float32)
# episode 29 Loss tf.Tensor(1.0019759, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0019742, shape=(), dtype=float32)   loss_action tf.Tensor(1.648943e-06, shape=(), dtype=float32)
# episode 30 Loss tf.Tensor(1.0025618, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0025601, shape=(), dtype=float32)   loss_action tf.Tensor(1.7187571e-06, shape=(), dtype=float32)
# episode 31 Loss tf.Tensor(1.0025344, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0025326, shape=(), dtype=float32)   loss_action tf.Tensor(1.7432873e-06, shape=(), dtype=float32)
# episode 32 Loss tf.Tensor(1.0019282, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0019265, shape=(), dtype=float32)   loss_action tf.Tensor(1.6852872e-06, shape=(), dtype=float32)
# episode 33 Loss tf.Tensor(1.0013001, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012984, shape=(), dtype=float32)   loss_action tf.Tensor(1.635483e-06, shape=(), dtype=float32)
# episode 34 Loss tf.Tensor(1.0022838, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0022821, shape=(), dtype=float32)   loss_action tf.Tensor(1.6420072e-06, shape=(), dtype=float32)
# episode 35 Loss tf.Tensor(1.0020118, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0020101, shape=(), dtype=float32)   loss_action tf.Tensor(1.7134943e-06, shape=(), dtype=float32)
# episode 36 Loss tf.Tensor(1.0016038, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016023, shape=(), dtype=float32)   loss_action tf.Tensor(1.5872724e-06, shape=(), dtype=float32)
# episode 37 Loss tf.Tensor(1.0020409, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0020392, shape=(), dtype=float32)   loss_action tf.Tensor(1.7060047e-06, shape=(), dtype=float32)
# episode 38 Loss tf.Tensor(1.0015368, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0015352, shape=(), dtype=float32)   loss_action tf.Tensor(1.656468e-06, shape=(), dtype=float32)
# episode 39 Loss tf.Tensor(1.0017905, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0017889, shape=(), dtype=float32)   loss_action tf.Tensor(1.6997897e-06, shape=(), dtype=float32)
# episode 40 Loss tf.Tensor(1.0018756, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001874, shape=(), dtype=float32)   loss_action tf.Tensor(1.7027148e-06, shape=(), dtype=float32)
# episode 41 Loss tf.Tensor(1.0016953, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016936, shape=(), dtype=float32)   loss_action tf.Tensor(1.6242063e-06, shape=(), dtype=float32)
# episode 42 Loss tf.Tensor(1.0016949, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016932, shape=(), dtype=float32)   loss_action tf.Tensor(1.6744932e-06, shape=(), dtype=float32)
# episode 43 Loss tf.Tensor(1.0019019, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0019002, shape=(), dtype=float32)   loss_action tf.Tensor(1.7060299e-06, shape=(), dtype=float32)
# episode 44 Loss tf.Tensor(1.0016378, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016361, shape=(), dtype=float32)   loss_action tf.Tensor(1.6717302e-06, shape=(), dtype=float32)
# episode 45 Loss tf.Tensor(1.0016913, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016897, shape=(), dtype=float32)   loss_action tf.Tensor(1.7101278e-06, shape=(), dtype=float32)
# episode 46 Loss tf.Tensor(1.0018709, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0018692, shape=(), dtype=float32)   loss_action tf.Tensor(1.7016883e-06, shape=(), dtype=float32)
# episode 47 Loss tf.Tensor(1.0015526, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0015509, shape=(), dtype=float32)   loss_action tf.Tensor(1.6984412e-06, shape=(), dtype=float32)
# episode 48 Loss tf.Tensor(1.0018072, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0018054, shape=(), dtype=float32)   loss_action tf.Tensor(1.757459e-06, shape=(), dtype=float32)
# episode 49 Loss tf.Tensor(1.0019689, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0019672, shape=(), dtype=float32)   loss_action tf.Tensor(1.69769e-06, shape=(), dtype=float32)
# episode 50 Loss tf.Tensor(1.0017376, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0017359, shape=(), dtype=float32)   loss_action tf.Tensor(1.7022177e-06, shape=(), dtype=float32)
# episode 51 Loss tf.Tensor(1.001977, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0019752, shape=(), dtype=float32)   loss_action tf.Tensor(1.8329412e-06, shape=(), dtype=float32)
# episode 52 Loss tf.Tensor(1.0016203, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016186, shape=(), dtype=float32)   loss_action tf.Tensor(1.7033456e-06, shape=(), dtype=float32)
# episode 53 Loss tf.Tensor(1.001248, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012463, shape=(), dtype=float32)   loss_action tf.Tensor(1.6506146e-06, shape=(), dtype=float32)
# episode 54 Loss tf.Tensor(1.0018698, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0018681, shape=(), dtype=float32)   loss_action tf.Tensor(1.7063683e-06, shape=(), dtype=float32)
# episode 55 Loss tf.Tensor(1.001814, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0018122, shape=(), dtype=float32)   loss_action tf.Tensor(1.7740324e-06, shape=(), dtype=float32)
# episode 56 Loss tf.Tensor(1.0016644, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016627, shape=(), dtype=float32)   loss_action tf.Tensor(1.7212255e-06, shape=(), dtype=float32)
# episode 57 Loss tf.Tensor(1.0015923, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0015906, shape=(), dtype=float32)   loss_action tf.Tensor(1.685399e-06, shape=(), dtype=float32)
# episode 58 Loss tf.Tensor(1.0016471, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016453, shape=(), dtype=float32)   loss_action tf.Tensor(1.7629073e-06, shape=(), dtype=float32)
# episode 59 Loss tf.Tensor(1.001813, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0018113, shape=(), dtype=float32)   loss_action tf.Tensor(1.7655701e-06, shape=(), dtype=float32)
# episode 60 Loss tf.Tensor(1.0013089, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013072, shape=(), dtype=float32)   loss_action tf.Tensor(1.7043824e-06, shape=(), dtype=float32)
# episode 61 Loss tf.Tensor(1.0014967, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001495, shape=(), dtype=float32)   loss_action tf.Tensor(1.7092522e-06, shape=(), dtype=float32)
# episode 62 Loss tf.Tensor(1.0013756, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013739, shape=(), dtype=float32)   loss_action tf.Tensor(1.6843538e-06, shape=(), dtype=float32)
# episode 63 Loss tf.Tensor(1.0017179, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0017161, shape=(), dtype=float32)   loss_action tf.Tensor(1.75444e-06, shape=(), dtype=float32)
# episode 64 Loss tf.Tensor(1.0016847, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016829, shape=(), dtype=float32)   loss_action tf.Tensor(1.7515348e-06, shape=(), dtype=float32)
# episode 65 Loss tf.Tensor(1.0013278, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013261, shape=(), dtype=float32)   loss_action tf.Tensor(1.6409908e-06, shape=(), dtype=float32)
# episode 66 Loss tf.Tensor(1.0012462, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012444, shape=(), dtype=float32)   loss_action tf.Tensor(1.7791966e-06, shape=(), dtype=float32)
# episode 67 Loss tf.Tensor(1.0015047, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0015029, shape=(), dtype=float32)   loss_action tf.Tensor(1.7654106e-06, shape=(), dtype=float32)
# episode 68 Loss tf.Tensor(1.0014136, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014119, shape=(), dtype=float32)   loss_action tf.Tensor(1.7196045e-06, shape=(), dtype=float32)
# episode 69 Loss tf.Tensor(1.001285, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012832, shape=(), dtype=float32)   loss_action tf.Tensor(1.7889663e-06, shape=(), dtype=float32)
# episode 70 Loss tf.Tensor(1.0014327, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001431, shape=(), dtype=float32)   loss_action tf.Tensor(1.7090222e-06, shape=(), dtype=float32)
# episode 71 Loss tf.Tensor(1.0013114, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013096, shape=(), dtype=float32)   loss_action tf.Tensor(1.7604045e-06, shape=(), dtype=float32)
# episode 72 Loss tf.Tensor(1.0013555, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013539, shape=(), dtype=float32)   loss_action tf.Tensor(1.6873466e-06, shape=(), dtype=float32)
# episode 73 Loss tf.Tensor(1.001638, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016363, shape=(), dtype=float32)   loss_action tf.Tensor(1.8280732e-06, shape=(), dtype=float32)
# episode 74 Loss tf.Tensor(1.0015216, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0015199, shape=(), dtype=float32)   loss_action tf.Tensor(1.7133381e-06, shape=(), dtype=float32)
# episode 75 Loss tf.Tensor(1.0011138, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001112, shape=(), dtype=float32)   loss_action tf.Tensor(1.7587022e-06, shape=(), dtype=float32)
# episode 76 Loss tf.Tensor(1.0016016, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0015998, shape=(), dtype=float32)   loss_action tf.Tensor(1.8161971e-06, shape=(), dtype=float32)
# episode 77 Loss tf.Tensor(1.0013742, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013726, shape=(), dtype=float32)   loss_action tf.Tensor(1.6808007e-06, shape=(), dtype=float32)
# episode 78 Loss tf.Tensor(1.0013996, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013978, shape=(), dtype=float32)   loss_action tf.Tensor(1.7594987e-06, shape=(), dtype=float32)
# episode 79 Loss tf.Tensor(1.0011301, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011284, shape=(), dtype=float32)   loss_action tf.Tensor(1.693841e-06, shape=(), dtype=float32)
# episode 80 Loss tf.Tensor(1.0019146, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0019128, shape=(), dtype=float32)   loss_action tf.Tensor(1.8215178e-06, shape=(), dtype=float32)
# episode 81 Loss tf.Tensor(1.0014082, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014064, shape=(), dtype=float32)   loss_action tf.Tensor(1.7694284e-06, shape=(), dtype=float32)
# episode 82 Loss tf.Tensor(1.0011436, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011418, shape=(), dtype=float32)   loss_action tf.Tensor(1.7793777e-06, shape=(), dtype=float32)
# episode 83 Loss tf.Tensor(1.0010858, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001084, shape=(), dtype=float32)   loss_action tf.Tensor(1.7472156e-06, shape=(), dtype=float32)
# episode 84 Loss tf.Tensor(1.0014454, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014437, shape=(), dtype=float32)   loss_action tf.Tensor(1.6924018e-06, shape=(), dtype=float32)
# episode 85 Loss tf.Tensor(1.0010686, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010669, shape=(), dtype=float32)   loss_action tf.Tensor(1.6972642e-06, shape=(), dtype=float32)
# episode 86 Loss tf.Tensor(1.0013444, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013427, shape=(), dtype=float32)   loss_action tf.Tensor(1.7465841e-06, shape=(), dtype=float32)
# episode 87 Loss tf.Tensor(1.0013559, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013541, shape=(), dtype=float32)   loss_action tf.Tensor(1.7435766e-06, shape=(), dtype=float32)
# episode 88 Loss tf.Tensor(1.0012043, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012025, shape=(), dtype=float32)   loss_action tf.Tensor(1.7546758e-06, shape=(), dtype=float32)
# episode 89 Loss tf.Tensor(1.001291, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012894, shape=(), dtype=float32)   loss_action tf.Tensor(1.7189114e-06, shape=(), dtype=float32)
# episode 90 Loss tf.Tensor(1.0012497, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012479, shape=(), dtype=float32)   loss_action tf.Tensor(1.7854867e-06, shape=(), dtype=float32)
# episode 91 Loss tf.Tensor(1.0013567, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013549, shape=(), dtype=float32)   loss_action tf.Tensor(1.7915887e-06, shape=(), dtype=float32)
# episode 92 Loss tf.Tensor(1.00112, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011183, shape=(), dtype=float32)   loss_action tf.Tensor(1.6798272e-06, shape=(), dtype=float32)
# episode 93 Loss tf.Tensor(1.001241, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012392, shape=(), dtype=float32)   loss_action tf.Tensor(1.7409731e-06, shape=(), dtype=float32)
# episode 94 Loss tf.Tensor(1.0009618, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009601, shape=(), dtype=float32)   loss_action tf.Tensor(1.6706113e-06, shape=(), dtype=float32)
# episode 95 Loss tf.Tensor(1.0012726, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012708, shape=(), dtype=float32)   loss_action tf.Tensor(1.7621137e-06, shape=(), dtype=float32)
# episode 96 Loss tf.Tensor(1.0013788, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013771, shape=(), dtype=float32)   loss_action tf.Tensor(1.6792133e-06, shape=(), dtype=float32)
# episode 97 Loss tf.Tensor(1.0011576, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001156, shape=(), dtype=float32)   loss_action tf.Tensor(1.7121022e-06, shape=(), dtype=float32)
# episode 98 Loss tf.Tensor(1.0016223, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0016204, shape=(), dtype=float32)   loss_action tf.Tensor(1.8766199e-06, shape=(), dtype=float32)
# episode 99 Loss tf.Tensor(1.0012578, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012561, shape=(), dtype=float32)   loss_action tf.Tensor(1.6222112e-06, shape=(), dtype=float32)
# episode 100 Loss tf.Tensor(1.0010526, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010508, shape=(), dtype=float32)   loss_action tf.Tensor(1.774845e-06, shape=(), dtype=float32)
# episode 101 Loss tf.Tensor(1.0014311, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014293, shape=(), dtype=float32)   loss_action tf.Tensor(1.798635e-06, shape=(), dtype=float32)
# episode 102 Loss tf.Tensor(1.0011727, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001171, shape=(), dtype=float32)   loss_action tf.Tensor(1.6985467e-06, shape=(), dtype=float32)
# episode 103 Loss tf.Tensor(1.0013243, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013226, shape=(), dtype=float32)   loss_action tf.Tensor(1.6117774e-06, shape=(), dtype=float32)
# episode 104 Loss tf.Tensor(1.001257, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012552, shape=(), dtype=float32)   loss_action tf.Tensor(1.8045341e-06, shape=(), dtype=float32)
# episode 105 Loss tf.Tensor(1.0009657, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009639, shape=(), dtype=float32)   loss_action tf.Tensor(1.7426307e-06, shape=(), dtype=float32)
# episode 106 Loss tf.Tensor(1.0010678, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010661, shape=(), dtype=float32)   loss_action tf.Tensor(1.7003506e-06, shape=(), dtype=float32)
# episode 107 Loss tf.Tensor(1.0014033, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014015, shape=(), dtype=float32)   loss_action tf.Tensor(1.812826e-06, shape=(), dtype=float32)
# episode 108 Loss tf.Tensor(1.0011405, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011388, shape=(), dtype=float32)   loss_action tf.Tensor(1.7230713e-06, shape=(), dtype=float32)
# episode 109 Loss tf.Tensor(1.0014606, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014589, shape=(), dtype=float32)   loss_action tf.Tensor(1.7157889e-06, shape=(), dtype=float32)
# episode 110 Loss tf.Tensor(1.0011665, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011647, shape=(), dtype=float32)   loss_action tf.Tensor(1.7386368e-06, shape=(), dtype=float32)
# episode 111 Loss tf.Tensor(1.0007795, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007777, shape=(), dtype=float32)   loss_action tf.Tensor(1.73666e-06, shape=(), dtype=float32)
# episode 112 Loss tf.Tensor(1.0012033, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012015, shape=(), dtype=float32)   loss_action tf.Tensor(1.7367167e-06, shape=(), dtype=float32)
# episode 113 Loss tf.Tensor(1.0010669, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010651, shape=(), dtype=float32)   loss_action tf.Tensor(1.7950659e-06, shape=(), dtype=float32)
# episode 114 Loss tf.Tensor(1.0010662, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010644, shape=(), dtype=float32)   loss_action tf.Tensor(1.7516529e-06, shape=(), dtype=float32)
# episode 115 Loss tf.Tensor(1.0012037, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012019, shape=(), dtype=float32)   loss_action tf.Tensor(1.7357659e-06, shape=(), dtype=float32)
# episode 116 Loss tf.Tensor(1.0010343, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010326, shape=(), dtype=float32)   loss_action tf.Tensor(1.7142254e-06, shape=(), dtype=float32)
# episode 117 Loss tf.Tensor(1.0012547, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012529, shape=(), dtype=float32)   loss_action tf.Tensor(1.7838114e-06, shape=(), dtype=float32)
# episode 118 Loss tf.Tensor(1.001059, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010573, shape=(), dtype=float32)   loss_action tf.Tensor(1.7348883e-06, shape=(), dtype=float32)
# episode 119 Loss tf.Tensor(1.001439, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014371, shape=(), dtype=float32)   loss_action tf.Tensor(1.8711878e-06, shape=(), dtype=float32)
# episode 120 Loss tf.Tensor(1.0012828, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001281, shape=(), dtype=float32)   loss_action tf.Tensor(1.8469449e-06, shape=(), dtype=float32)
# episode 121 Loss tf.Tensor(1.0011845, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011827, shape=(), dtype=float32)   loss_action tf.Tensor(1.836903e-06, shape=(), dtype=float32)
# episode 122 Loss tf.Tensor(1.0014718, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014699, shape=(), dtype=float32)   loss_action tf.Tensor(1.8491379e-06, shape=(), dtype=float32)
# episode 123 Loss tf.Tensor(1.0013467, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013449, shape=(), dtype=float32)   loss_action tf.Tensor(1.8300008e-06, shape=(), dtype=float32)
# episode 124 Loss tf.Tensor(1.0011992, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011976, shape=(), dtype=float32)   loss_action tf.Tensor(1.7226341e-06, shape=(), dtype=float32)
# episode 125 Loss tf.Tensor(1.0010632, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010616, shape=(), dtype=float32)   loss_action tf.Tensor(1.7268381e-06, shape=(), dtype=float32)
# episode 126 Loss tf.Tensor(1.0014199, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0014181, shape=(), dtype=float32)   loss_action tf.Tensor(1.7742518e-06, shape=(), dtype=float32)
# episode 127 Loss tf.Tensor(1.0012711, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012693, shape=(), dtype=float32)   loss_action tf.Tensor(1.8346229e-06, shape=(), dtype=float32)
# episode 128 Loss tf.Tensor(1.0010145, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010127, shape=(), dtype=float32)   loss_action tf.Tensor(1.7971579e-06, shape=(), dtype=float32)
# episode 129 Loss tf.Tensor(1.0010712, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010694, shape=(), dtype=float32)   loss_action tf.Tensor(1.7332743e-06, shape=(), dtype=float32)
# episode 130 Loss tf.Tensor(1.0010797, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010779, shape=(), dtype=float32)   loss_action tf.Tensor(1.7708516e-06, shape=(), dtype=float32)
# episode 131 Loss tf.Tensor(1.0010873, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010855, shape=(), dtype=float32)   loss_action tf.Tensor(1.7387882e-06, shape=(), dtype=float32)
# episode 132 Loss tf.Tensor(1.0009918, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.00099, shape=(), dtype=float32)   loss_action tf.Tensor(1.7353365e-06, shape=(), dtype=float32)
# episode 133 Loss tf.Tensor(1.0007937, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000792, shape=(), dtype=float32)   loss_action tf.Tensor(1.6242271e-06, shape=(), dtype=float32)
# episode 134 Loss tf.Tensor(1.0013679, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013661, shape=(), dtype=float32)   loss_action tf.Tensor(1.8315252e-06, shape=(), dtype=float32)
# episode 135 Loss tf.Tensor(1.0010722, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010704, shape=(), dtype=float32)   loss_action tf.Tensor(1.7650947e-06, shape=(), dtype=float32)
# episode 136 Loss tf.Tensor(1.0010356, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010339, shape=(), dtype=float32)   loss_action tf.Tensor(1.6756766e-06, shape=(), dtype=float32)
# episode 137 Loss tf.Tensor(1.0010825, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010808, shape=(), dtype=float32)   loss_action tf.Tensor(1.8076038e-06, shape=(), dtype=float32)
# episode 138 Loss tf.Tensor(1.0013214, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013196, shape=(), dtype=float32)   loss_action tf.Tensor(1.816278e-06, shape=(), dtype=float32)
# episode 139 Loss tf.Tensor(1.0008847, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008829, shape=(), dtype=float32)   loss_action tf.Tensor(1.773932e-06, shape=(), dtype=float32)
# episode 140 Loss tf.Tensor(1.001079, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010772, shape=(), dtype=float32)   loss_action tf.Tensor(1.7678575e-06, shape=(), dtype=float32)
# episode 141 Loss tf.Tensor(1.0009719, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009702, shape=(), dtype=float32)   loss_action tf.Tensor(1.6825331e-06, shape=(), dtype=float32)
# episode 142 Loss tf.Tensor(1.0012884, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012866, shape=(), dtype=float32)   loss_action tf.Tensor(1.813487e-06, shape=(), dtype=float32)
# episode 143 Loss tf.Tensor(1.0011562, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011544, shape=(), dtype=float32)   loss_action tf.Tensor(1.7538791e-06, shape=(), dtype=float32)
# episode 144 Loss tf.Tensor(1.0008112, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008094, shape=(), dtype=float32)   loss_action tf.Tensor(1.7741726e-06, shape=(), dtype=float32)
# episode 145 Loss tf.Tensor(1.0009334, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009317, shape=(), dtype=float32)   loss_action tf.Tensor(1.7245604e-06, shape=(), dtype=float32)
# episode 146 Loss tf.Tensor(1.0012008, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011989, shape=(), dtype=float32)   loss_action tf.Tensor(1.8527894e-06, shape=(), dtype=float32)
# episode 147 Loss tf.Tensor(1.0007727, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007709, shape=(), dtype=float32)   loss_action tf.Tensor(1.8157555e-06, shape=(), dtype=float32)
# episode 148 Loss tf.Tensor(1.0009102, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009085, shape=(), dtype=float32)   loss_action tf.Tensor(1.7163665e-06, shape=(), dtype=float32)
# episode 149 Loss tf.Tensor(1.0010009, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009992, shape=(), dtype=float32)   loss_action tf.Tensor(1.7214079e-06, shape=(), dtype=float32)
# episode 150 Loss tf.Tensor(1.0012733, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012715, shape=(), dtype=float32)   loss_action tf.Tensor(1.8414581e-06, shape=(), dtype=float32)
# episode 151 Loss tf.Tensor(1.0011126, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011109, shape=(), dtype=float32)   loss_action tf.Tensor(1.6391949e-06, shape=(), dtype=float32)
# episode 152 Loss tf.Tensor(1.0010891, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010873, shape=(), dtype=float32)   loss_action tf.Tensor(1.8023221e-06, shape=(), dtype=float32)
# episode 153 Loss tf.Tensor(1.0011309, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011293, shape=(), dtype=float32)   loss_action tf.Tensor(1.7153956e-06, shape=(), dtype=float32)
# episode 154 Loss tf.Tensor(1.0010215, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010197, shape=(), dtype=float32)   loss_action tf.Tensor(1.810529e-06, shape=(), dtype=float32)
# episode 155 Loss tf.Tensor(1.0010834, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010816, shape=(), dtype=float32)   loss_action tf.Tensor(1.7871286e-06, shape=(), dtype=float32)
# episode 156 Loss tf.Tensor(1.0012312, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012294, shape=(), dtype=float32)   loss_action tf.Tensor(1.7942583e-06, shape=(), dtype=float32)
# episode 157 Loss tf.Tensor(1.0010878, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010861, shape=(), dtype=float32)   loss_action tf.Tensor(1.7253834e-06, shape=(), dtype=float32)
# episode 158 Loss tf.Tensor(1.0008574, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008556, shape=(), dtype=float32)   loss_action tf.Tensor(1.7693084e-06, shape=(), dtype=float32)
# episode 159 Loss tf.Tensor(1.0008738, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008721, shape=(), dtype=float32)   loss_action tf.Tensor(1.6922954e-06, shape=(), dtype=float32)
# episode 160 Loss tf.Tensor(1.0008433, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008415, shape=(), dtype=float32)   loss_action tf.Tensor(1.8065996e-06, shape=(), dtype=float32)
# episode 161 Loss tf.Tensor(1.0009702, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009685, shape=(), dtype=float32)   loss_action tf.Tensor(1.8099493e-06, shape=(), dtype=float32)
# episode 162 Loss tf.Tensor(1.0008291, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008273, shape=(), dtype=float32)   loss_action tf.Tensor(1.7562639e-06, shape=(), dtype=float32)
# episode 163 Loss tf.Tensor(1.0009428, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000941, shape=(), dtype=float32)   loss_action tf.Tensor(1.7812364e-06, shape=(), dtype=float32)
# episode 164 Loss tf.Tensor(1.0011388, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001137, shape=(), dtype=float32)   loss_action tf.Tensor(1.8385575e-06, shape=(), dtype=float32)
# episode 165 Loss tf.Tensor(1.0008587, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008569, shape=(), dtype=float32)   loss_action tf.Tensor(1.7900487e-06, shape=(), dtype=float32)
# episode 166 Loss tf.Tensor(1.0012529, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001251, shape=(), dtype=float32)   loss_action tf.Tensor(1.8630365e-06, shape=(), dtype=float32)
# episode 167 Loss tf.Tensor(1.0010427, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001041, shape=(), dtype=float32)   loss_action tf.Tensor(1.6821315e-06, shape=(), dtype=float32)
# episode 168 Loss tf.Tensor(1.0011406, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011388, shape=(), dtype=float32)   loss_action tf.Tensor(1.7925765e-06, shape=(), dtype=float32)
# episode 169 Loss tf.Tensor(1.0011237, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011219, shape=(), dtype=float32)   loss_action tf.Tensor(1.8224049e-06, shape=(), dtype=float32)
# episode 170 Loss tf.Tensor(1.0011263, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011245, shape=(), dtype=float32)   loss_action tf.Tensor(1.7735383e-06, shape=(), dtype=float32)
# episode 171 Loss tf.Tensor(1.0010036, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010018, shape=(), dtype=float32)   loss_action tf.Tensor(1.7347423e-06, shape=(), dtype=float32)
# episode 172 Loss tf.Tensor(1.0010301, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010283, shape=(), dtype=float32)   loss_action tf.Tensor(1.8100715e-06, shape=(), dtype=float32)
# episode 173 Loss tf.Tensor(1.0007473, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007455, shape=(), dtype=float32)   loss_action tf.Tensor(1.7656912e-06, shape=(), dtype=float32)
# episode 174 Loss tf.Tensor(1.0010773, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010755, shape=(), dtype=float32)   loss_action tf.Tensor(1.8060473e-06, shape=(), dtype=float32)
# episode 175 Loss tf.Tensor(1.0013411, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0013393, shape=(), dtype=float32)   loss_action tf.Tensor(1.7980203e-06, shape=(), dtype=float32)
# episode 176 Loss tf.Tensor(1.0009129, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009111, shape=(), dtype=float32)   loss_action tf.Tensor(1.7616029e-06, shape=(), dtype=float32)
# episode 177 Loss tf.Tensor(1.0009718, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.00097, shape=(), dtype=float32)   loss_action tf.Tensor(1.7343556e-06, shape=(), dtype=float32)
# episode 178 Loss tf.Tensor(1.0008345, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008327, shape=(), dtype=float32)   loss_action tf.Tensor(1.7849675e-06, shape=(), dtype=float32)
# episode 179 Loss tf.Tensor(1.0009474, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009456, shape=(), dtype=float32)   loss_action tf.Tensor(1.8155256e-06, shape=(), dtype=float32)
# episode 180 Loss tf.Tensor(1.0008826, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000881, shape=(), dtype=float32)   loss_action tf.Tensor(1.7095863e-06, shape=(), dtype=float32)
# episode 181 Loss tf.Tensor(1.0010548, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001053, shape=(), dtype=float32)   loss_action tf.Tensor(1.821846e-06, shape=(), dtype=float32)
# episode 182 Loss tf.Tensor(1.0007278, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007261, shape=(), dtype=float32)   loss_action tf.Tensor(1.6988573e-06, shape=(), dtype=float32)
# episode 183 Loss tf.Tensor(1.0012095, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012077, shape=(), dtype=float32)   loss_action tf.Tensor(1.8384463e-06, shape=(), dtype=float32)
# episode 184 Loss tf.Tensor(1.0009823, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009806, shape=(), dtype=float32)   loss_action tf.Tensor(1.7204763e-06, shape=(), dtype=float32)
# episode 185 Loss tf.Tensor(1.0008723, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008706, shape=(), dtype=float32)   loss_action tf.Tensor(1.6878778e-06, shape=(), dtype=float32)
# episode 186 Loss tf.Tensor(1.0007179, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007161, shape=(), dtype=float32)   loss_action tf.Tensor(1.759005e-06, shape=(), dtype=float32)
# episode 187 Loss tf.Tensor(1.0009756, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009738, shape=(), dtype=float32)   loss_action tf.Tensor(1.7838506e-06, shape=(), dtype=float32)
# episode 188 Loss tf.Tensor(1.0008845, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008827, shape=(), dtype=float32)   loss_action tf.Tensor(1.785257e-06, shape=(), dtype=float32)
# episode 189 Loss tf.Tensor(1.001152, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011503, shape=(), dtype=float32)   loss_action tf.Tensor(1.8359509e-06, shape=(), dtype=float32)
# episode 190 Loss tf.Tensor(1.0009669, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009651, shape=(), dtype=float32)   loss_action tf.Tensor(1.774005e-06, shape=(), dtype=float32)
# episode 191 Loss tf.Tensor(1.0010784, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010766, shape=(), dtype=float32)   loss_action tf.Tensor(1.7969645e-06, shape=(), dtype=float32)
# episode 192 Loss tf.Tensor(1.0011206, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011188, shape=(), dtype=float32)   loss_action tf.Tensor(1.8074362e-06, shape=(), dtype=float32)
# episode 193 Loss tf.Tensor(1.0009643, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009625, shape=(), dtype=float32)   loss_action tf.Tensor(1.7655063e-06, shape=(), dtype=float32)
# episode 194 Loss tf.Tensor(1.0010395, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010377, shape=(), dtype=float32)   loss_action tf.Tensor(1.8254984e-06, shape=(), dtype=float32)
# episode 195 Loss tf.Tensor(1.001136, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011342, shape=(), dtype=float32)   loss_action tf.Tensor(1.8403886e-06, shape=(), dtype=float32)
# episode 196 Loss tf.Tensor(1.0007792, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007774, shape=(), dtype=float32)   loss_action tf.Tensor(1.7396645e-06, shape=(), dtype=float32)
# episode 197 Loss tf.Tensor(1.0011333, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011315, shape=(), dtype=float32)   loss_action tf.Tensor(1.8249349e-06, shape=(), dtype=float32)
# episode 198 Loss tf.Tensor(1.000908, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009062, shape=(), dtype=float32)   loss_action tf.Tensor(1.8363818e-06, shape=(), dtype=float32)
# episode 199 Loss tf.Tensor(1.000931, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009292, shape=(), dtype=float32)   loss_action tf.Tensor(1.7493227e-06, shape=(), dtype=float32)
# episode 200 Loss tf.Tensor(1.0008861, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008843, shape=(), dtype=float32)   loss_action tf.Tensor(1.7565545e-06, shape=(), dtype=float32)
# episode 201 Loss tf.Tensor(1.001022, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010202, shape=(), dtype=float32)   loss_action tf.Tensor(1.7390926e-06, shape=(), dtype=float32)
# episode 202 Loss tf.Tensor(1.000963, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009612, shape=(), dtype=float32)   loss_action tf.Tensor(1.8222415e-06, shape=(), dtype=float32)
# episode 203 Loss tf.Tensor(1.0007534, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007516, shape=(), dtype=float32)   loss_action tf.Tensor(1.7472455e-06, shape=(), dtype=float32)
# episode 204 Loss tf.Tensor(1.000922, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009202, shape=(), dtype=float32)   loss_action tf.Tensor(1.739822e-06, shape=(), dtype=float32)
# episode 205 Loss tf.Tensor(1.0008379, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008361, shape=(), dtype=float32)   loss_action tf.Tensor(1.7692231e-06, shape=(), dtype=float32)
# episode 206 Loss tf.Tensor(1.0010167, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.001015, shape=(), dtype=float32)   loss_action tf.Tensor(1.7359519e-06, shape=(), dtype=float32)
# episode 207 Loss tf.Tensor(1.0010246, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010228, shape=(), dtype=float32)   loss_action tf.Tensor(1.7621064e-06, shape=(), dtype=float32)
# episode 208 Loss tf.Tensor(1.0008426, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008408, shape=(), dtype=float32)   loss_action tf.Tensor(1.8420737e-06, shape=(), dtype=float32)
# episode 209 Loss tf.Tensor(1.0008023, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008005, shape=(), dtype=float32)   loss_action tf.Tensor(1.7372121e-06, shape=(), dtype=float32)
# episode 210 Loss tf.Tensor(1.0009258, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000924, shape=(), dtype=float32)   loss_action tf.Tensor(1.8001454e-06, shape=(), dtype=float32)
# episode 211 Loss tf.Tensor(1.0008347, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008329, shape=(), dtype=float32)   loss_action tf.Tensor(1.8251959e-06, shape=(), dtype=float32)
# episode 212 Loss tf.Tensor(1.0012027, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012008, shape=(), dtype=float32)   loss_action tf.Tensor(1.8628069e-06, shape=(), dtype=float32)
# episode 213 Loss tf.Tensor(1.0008639, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008621, shape=(), dtype=float32)   loss_action tf.Tensor(1.7724342e-06, shape=(), dtype=float32)
# episode 214 Loss tf.Tensor(1.0007557, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007539, shape=(), dtype=float32)   loss_action tf.Tensor(1.7443213e-06, shape=(), dtype=float32)
# episode 215 Loss tf.Tensor(1.0009402, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009384, shape=(), dtype=float32)   loss_action tf.Tensor(1.7617265e-06, shape=(), dtype=float32)
# episode 216 Loss tf.Tensor(1.0007915, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007898, shape=(), dtype=float32)   loss_action tf.Tensor(1.7473004e-06, shape=(), dtype=float32)
# episode 217 Loss tf.Tensor(1.0012277, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0012258, shape=(), dtype=float32)   loss_action tf.Tensor(1.8888198e-06, shape=(), dtype=float32)
# episode 218 Loss tf.Tensor(1.0007548, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007532, shape=(), dtype=float32)   loss_action tf.Tensor(1.7160788e-06, shape=(), dtype=float32)
# episode 219 Loss tf.Tensor(1.0009358, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000934, shape=(), dtype=float32)   loss_action tf.Tensor(1.781816e-06, shape=(), dtype=float32)
# episode 220 Loss tf.Tensor(1.0006102, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006084, shape=(), dtype=float32)   loss_action tf.Tensor(1.7812655e-06, shape=(), dtype=float32)
# episode 221 Loss tf.Tensor(1.0008023, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008005, shape=(), dtype=float32)   loss_action tf.Tensor(1.8457728e-06, shape=(), dtype=float32)
# episode 222 Loss tf.Tensor(1.0010993, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010974, shape=(), dtype=float32)   loss_action tf.Tensor(1.8850977e-06, shape=(), dtype=float32)
# episode 223 Loss tf.Tensor(1.000775, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007732, shape=(), dtype=float32)   loss_action tf.Tensor(1.7989489e-06, shape=(), dtype=float32)
# episode 224 Loss tf.Tensor(1.000598, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005963, shape=(), dtype=float32)   loss_action tf.Tensor(1.7265435e-06, shape=(), dtype=float32)
# episode 225 Loss tf.Tensor(1.0007833, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007815, shape=(), dtype=float32)   loss_action tf.Tensor(1.8333053e-06, shape=(), dtype=float32)
# episode 226 Loss tf.Tensor(1.0007552, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007535, shape=(), dtype=float32)   loss_action tf.Tensor(1.7193064e-06, shape=(), dtype=float32)
# episode 227 Loss tf.Tensor(1.0011472, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011454, shape=(), dtype=float32)   loss_action tf.Tensor(1.7928068e-06, shape=(), dtype=float32)
# episode 228 Loss tf.Tensor(1.0011818, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011802, shape=(), dtype=float32)   loss_action tf.Tensor(1.7181143e-06, shape=(), dtype=float32)
# episode 229 Loss tf.Tensor(1.0007969, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007951, shape=(), dtype=float32)   loss_action tf.Tensor(1.7592859e-06, shape=(), dtype=float32)
# episode 230 Loss tf.Tensor(1.0006815, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006799, shape=(), dtype=float32)   loss_action tf.Tensor(1.7237284e-06, shape=(), dtype=float32)
# episode 231 Loss tf.Tensor(1.0007601, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007583, shape=(), dtype=float32)   loss_action tf.Tensor(1.7446774e-06, shape=(), dtype=float32)
# episode 232 Loss tf.Tensor(1.0009545, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009527, shape=(), dtype=float32)   loss_action tf.Tensor(1.7836433e-06, shape=(), dtype=float32)
# episode 233 Loss tf.Tensor(1.0009375, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009357, shape=(), dtype=float32)   loss_action tf.Tensor(1.8069661e-06, shape=(), dtype=float32)
# episode 234 Loss tf.Tensor(1.0007671, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007653, shape=(), dtype=float32)   loss_action tf.Tensor(1.810631e-06, shape=(), dtype=float32)
# episode 235 Loss tf.Tensor(1.0008312, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008295, shape=(), dtype=float32)   loss_action tf.Tensor(1.8466556e-06, shape=(), dtype=float32)
# episode 236 Loss tf.Tensor(1.0008221, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008203, shape=(), dtype=float32)   loss_action tf.Tensor(1.748046e-06, shape=(), dtype=float32)
# episode 237 Loss tf.Tensor(1.0010362, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010343, shape=(), dtype=float32)   loss_action tf.Tensor(1.8752186e-06, shape=(), dtype=float32)
# episode 238 Loss tf.Tensor(1.0009227, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0009209, shape=(), dtype=float32)   loss_action tf.Tensor(1.795254e-06, shape=(), dtype=float32)
# episode 239 Loss tf.Tensor(1.0008862, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008844, shape=(), dtype=float32)   loss_action tf.Tensor(1.7855032e-06, shape=(), dtype=float32)
# episode 240 Loss tf.Tensor(1.0011985, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011966, shape=(), dtype=float32)   loss_action tf.Tensor(1.889161e-06, shape=(), dtype=float32)
# episode 241 Loss tf.Tensor(1.0007765, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007747, shape=(), dtype=float32)   loss_action tf.Tensor(1.7695288e-06, shape=(), dtype=float32)
# episode 242 Loss tf.Tensor(1.0008187, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000817, shape=(), dtype=float32)   loss_action tf.Tensor(1.7846334e-06, shape=(), dtype=float32)
# episode 243 Loss tf.Tensor(1.0011796, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0011777, shape=(), dtype=float32)   loss_action tf.Tensor(1.8885961e-06, shape=(), dtype=float32)
# episode 244 Loss tf.Tensor(1.0007492, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007474, shape=(), dtype=float32)   loss_action tf.Tensor(1.8270587e-06, shape=(), dtype=float32)
# episode 245 Loss tf.Tensor(1.0010372, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0010353, shape=(), dtype=float32)   loss_action tf.Tensor(1.8807406e-06, shape=(), dtype=float32)
# episode 246 Loss tf.Tensor(1.0008485, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008467, shape=(), dtype=float32)   loss_action tf.Tensor(1.7893922e-06, shape=(), dtype=float32)
# ...
# episode 918 Loss tf.Tensor(1.0006382, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006363, shape=(), dtype=float32)   loss_action tf.Tensor(1.868826e-06, shape=(), dtype=float32)
# episode 919 Loss tf.Tensor(1.0006042, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006022, shape=(), dtype=float32)   loss_action tf.Tensor(1.8924374e-06, shape=(), dtype=float32)
# episode 920 Loss tf.Tensor(1.0005593, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005574, shape=(), dtype=float32)   loss_action tf.Tensor(1.8553551e-06, shape=(), dtype=float32)
# episode 921 Loss tf.Tensor(1.0007439, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007421, shape=(), dtype=float32)   loss_action tf.Tensor(1.8161129e-06, shape=(), dtype=float32)
# episode 922 Loss tf.Tensor(1.0006006, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005987, shape=(), dtype=float32)   loss_action tf.Tensor(1.8821934e-06, shape=(), dtype=float32)
# episode 923 Loss tf.Tensor(1.0005122, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005105, shape=(), dtype=float32)   loss_action tf.Tensor(1.7965253e-06, shape=(), dtype=float32)
# episode 924 Loss tf.Tensor(1.0008216, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008197, shape=(), dtype=float32)   loss_action tf.Tensor(1.9428383e-06, shape=(), dtype=float32)
# episode 925 Loss tf.Tensor(1.0005637, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005618, shape=(), dtype=float32)   loss_action tf.Tensor(1.865285e-06, shape=(), dtype=float32)
# episode 926 Loss tf.Tensor(1.0008008, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007991, shape=(), dtype=float32)   loss_action tf.Tensor(1.8451325e-06, shape=(), dtype=float32)
# episode 927 Loss tf.Tensor(1.0007977, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007958, shape=(), dtype=float32)   loss_action tf.Tensor(1.940674e-06, shape=(), dtype=float32)
# episode 928 Loss tf.Tensor(1.0006906, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006888, shape=(), dtype=float32)   loss_action tf.Tensor(1.8166497e-06, shape=(), dtype=float32)
# episode 929 Loss tf.Tensor(1.0006485, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006467, shape=(), dtype=float32)   loss_action tf.Tensor(1.7446868e-06, shape=(), dtype=float32)
# episode 930 Loss tf.Tensor(1.0006224, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006205, shape=(), dtype=float32)   loss_action tf.Tensor(1.9036124e-06, shape=(), dtype=float32)
# episode 931 Loss tf.Tensor(1.0003952, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0003934, shape=(), dtype=float32)   loss_action tf.Tensor(1.7991468e-06, shape=(), dtype=float32)
# episode 932 Loss tf.Tensor(1.0006133, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006114, shape=(), dtype=float32)   loss_action tf.Tensor(1.88884e-06, shape=(), dtype=float32)
# episode 933 Loss tf.Tensor(1.0008577, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008558, shape=(), dtype=float32)   loss_action tf.Tensor(1.8906794e-06, shape=(), dtype=float32)
# episode 934 Loss tf.Tensor(1.0004404, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004385, shape=(), dtype=float32)   loss_action tf.Tensor(1.8668792e-06, shape=(), dtype=float32)
# episode 935 Loss tf.Tensor(1.0006868, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000685, shape=(), dtype=float32)   loss_action tf.Tensor(1.8382402e-06, shape=(), dtype=float32)
# episode 936 Loss tf.Tensor(1.0006694, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006675, shape=(), dtype=float32)   loss_action tf.Tensor(1.8860554e-06, shape=(), dtype=float32)
# episode 937 Loss tf.Tensor(1.0005727, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005708, shape=(), dtype=float32)   loss_action tf.Tensor(1.8592274e-06, shape=(), dtype=float32)
# episode 938 Loss tf.Tensor(1.0004044, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004025, shape=(), dtype=float32)   loss_action tf.Tensor(1.8943499e-06, shape=(), dtype=float32)
# episode 939 Loss tf.Tensor(1.0007831, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007812, shape=(), dtype=float32)   loss_action tf.Tensor(1.9304086e-06, shape=(), dtype=float32)
# episode 940 Loss tf.Tensor(1.000745, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007433, shape=(), dtype=float32)   loss_action tf.Tensor(1.7546827e-06, shape=(), dtype=float32)
# episode 941 Loss tf.Tensor(1.0007075, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007056, shape=(), dtype=float32)   loss_action tf.Tensor(1.9342444e-06, shape=(), dtype=float32)
# episode 942 Loss tf.Tensor(1.0005962, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005943, shape=(), dtype=float32)   loss_action tf.Tensor(1.9426898e-06, shape=(), dtype=float32)
# episode 943 Loss tf.Tensor(1.0005304, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005285, shape=(), dtype=float32)   loss_action tf.Tensor(1.8784502e-06, shape=(), dtype=float32)
# episode 944 Loss tf.Tensor(1.0005552, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005534, shape=(), dtype=float32)   loss_action tf.Tensor(1.8421019e-06, shape=(), dtype=float32)
# episode 945 Loss tf.Tensor(1.0005914, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005896, shape=(), dtype=float32)   loss_action tf.Tensor(1.8124181e-06, shape=(), dtype=float32)
# episode 946 Loss tf.Tensor(1.000432, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004302, shape=(), dtype=float32)   loss_action tf.Tensor(1.8282278e-06, shape=(), dtype=float32)
# episode 947 Loss tf.Tensor(1.0005764, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005745, shape=(), dtype=float32)   loss_action tf.Tensor(1.861067e-06, shape=(), dtype=float32)
# episode 948 Loss tf.Tensor(1.0005457, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005438, shape=(), dtype=float32)   loss_action tf.Tensor(1.856451e-06, shape=(), dtype=float32)
# episode 949 Loss tf.Tensor(1.0004746, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004728, shape=(), dtype=float32)   loss_action tf.Tensor(1.8363672e-06, shape=(), dtype=float32)
# episode 950 Loss tf.Tensor(1.0006608, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006589, shape=(), dtype=float32)   loss_action tf.Tensor(1.8886702e-06, shape=(), dtype=float32)
# episode 951 Loss tf.Tensor(1.0006425, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006406, shape=(), dtype=float32)   loss_action tf.Tensor(1.8925841e-06, shape=(), dtype=float32)
# episode 952 Loss tf.Tensor(1.0006217, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006198, shape=(), dtype=float32)   loss_action tf.Tensor(1.8626343e-06, shape=(), dtype=float32)
# episode 953 Loss tf.Tensor(1.0007275, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007256, shape=(), dtype=float32)   loss_action tf.Tensor(1.8701194e-06, shape=(), dtype=float32)
# episode 954 Loss tf.Tensor(1.000609, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006073, shape=(), dtype=float32)   loss_action tf.Tensor(1.8431366e-06, shape=(), dtype=float32)
# episode 955 Loss tf.Tensor(1.0007086, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007068, shape=(), dtype=float32)   loss_action tf.Tensor(1.8300699e-06, shape=(), dtype=float32)
# episode 956 Loss tf.Tensor(1.0005405, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005386, shape=(), dtype=float32)   loss_action tf.Tensor(1.8674758e-06, shape=(), dtype=float32)
# episode 957 Loss tf.Tensor(1.0006764, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006746, shape=(), dtype=float32)   loss_action tf.Tensor(1.8142536e-06, shape=(), dtype=float32)
# episode 958 Loss tf.Tensor(1.0006399, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006381, shape=(), dtype=float32)   loss_action tf.Tensor(1.8264212e-06, shape=(), dtype=float32)
# episode 959 Loss tf.Tensor(1.0006641, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006622, shape=(), dtype=float32)   loss_action tf.Tensor(1.8860604e-06, shape=(), dtype=float32)
# episode 960 Loss tf.Tensor(1.0006152, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006133, shape=(), dtype=float32)   loss_action tf.Tensor(1.8758735e-06, shape=(), dtype=float32)
# episode 961 Loss tf.Tensor(1.0006405, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006386, shape=(), dtype=float32)   loss_action tf.Tensor(1.904724e-06, shape=(), dtype=float32)
# episode 962 Loss tf.Tensor(1.0006347, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006328, shape=(), dtype=float32)   loss_action tf.Tensor(1.8855438e-06, shape=(), dtype=float32)
# episode 963 Loss tf.Tensor(1.0005907, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005888, shape=(), dtype=float32)   loss_action tf.Tensor(1.8513272e-06, shape=(), dtype=float32)
# episode 964 Loss tf.Tensor(1.0005385, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005367, shape=(), dtype=float32)   loss_action tf.Tensor(1.7496877e-06, shape=(), dtype=float32)
# episode 965 Loss tf.Tensor(1.0005205, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005186, shape=(), dtype=float32)   loss_action tf.Tensor(1.8833484e-06, shape=(), dtype=float32)
# episode 966 Loss tf.Tensor(1.000662, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006601, shape=(), dtype=float32)   loss_action tf.Tensor(1.8929021e-06, shape=(), dtype=float32)
# episode 967 Loss tf.Tensor(1.0006155, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006137, shape=(), dtype=float32)   loss_action tf.Tensor(1.7482766e-06, shape=(), dtype=float32)
# episode 968 Loss tf.Tensor(1.0007876, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007857, shape=(), dtype=float32)   loss_action tf.Tensor(1.9042681e-06, shape=(), dtype=float32)
# episode 969 Loss tf.Tensor(1.0005656, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005637, shape=(), dtype=float32)   loss_action tf.Tensor(1.9221638e-06, shape=(), dtype=float32)
# episode 970 Loss tf.Tensor(1.0007707, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007687, shape=(), dtype=float32)   loss_action tf.Tensor(1.9700617e-06, shape=(), dtype=float32)
# episode 971 Loss tf.Tensor(1.0005447, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005428, shape=(), dtype=float32)   loss_action tf.Tensor(1.8937995e-06, shape=(), dtype=float32)
# episode 972 Loss tf.Tensor(1.000431, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000429, shape=(), dtype=float32)   loss_action tf.Tensor(1.929739e-06, shape=(), dtype=float32)
# episode 973 Loss tf.Tensor(1.0007875, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007856, shape=(), dtype=float32)   loss_action tf.Tensor(1.8884829e-06, shape=(), dtype=float32)
# episode 974 Loss tf.Tensor(1.0006907, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006888, shape=(), dtype=float32)   loss_action tf.Tensor(1.8842113e-06, shape=(), dtype=float32)
# episode 975 Loss tf.Tensor(1.0006057, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006038, shape=(), dtype=float32)   loss_action tf.Tensor(1.8536831e-06, shape=(), dtype=float32)
# episode 976 Loss tf.Tensor(1.0008128, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008109, shape=(), dtype=float32)   loss_action tf.Tensor(1.941918e-06, shape=(), dtype=float32)
# episode 977 Loss tf.Tensor(1.0006934, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006915, shape=(), dtype=float32)   loss_action tf.Tensor(1.8625395e-06, shape=(), dtype=float32)
# episode 978 Loss tf.Tensor(1.0007253, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007234, shape=(), dtype=float32)   loss_action tf.Tensor(1.9447498e-06, shape=(), dtype=float32)
# episode 979 Loss tf.Tensor(1.0006242, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006224, shape=(), dtype=float32)   loss_action tf.Tensor(1.8296292e-06, shape=(), dtype=float32)
# episode 980 Loss tf.Tensor(1.0006465, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006446, shape=(), dtype=float32)   loss_action tf.Tensor(1.9201555e-06, shape=(), dtype=float32)
# episode 981 Loss tf.Tensor(1.0005637, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000562, shape=(), dtype=float32)   loss_action tf.Tensor(1.7644622e-06, shape=(), dtype=float32)
# episode 982 Loss tf.Tensor(1.0004381, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004363, shape=(), dtype=float32)   loss_action tf.Tensor(1.8437411e-06, shape=(), dtype=float32)
# episode 983 Loss tf.Tensor(1.0005722, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005704, shape=(), dtype=float32)   loss_action tf.Tensor(1.8428873e-06, shape=(), dtype=float32)
# episode 984 Loss tf.Tensor(1.0004585, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004566, shape=(), dtype=float32)   loss_action tf.Tensor(1.8500107e-06, shape=(), dtype=float32)
# episode 985 Loss tf.Tensor(1.0006951, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006932, shape=(), dtype=float32)   loss_action tf.Tensor(1.8803688e-06, shape=(), dtype=float32)
# episode 986 Loss tf.Tensor(1.0006293, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006275, shape=(), dtype=float32)   loss_action tf.Tensor(1.8017074e-06, shape=(), dtype=float32)
# episode 987 Loss tf.Tensor(1.0007025, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007006, shape=(), dtype=float32)   loss_action tf.Tensor(1.913739e-06, shape=(), dtype=float32)
# episode 988 Loss tf.Tensor(1.0006496, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006478, shape=(), dtype=float32)   loss_action tf.Tensor(1.7675745e-06, shape=(), dtype=float32)
# episode 989 Loss tf.Tensor(1.000812, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0008101, shape=(), dtype=float32)   loss_action tf.Tensor(1.9565423e-06, shape=(), dtype=float32)
# episode 990 Loss tf.Tensor(1.0007583, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0007564, shape=(), dtype=float32)   loss_action tf.Tensor(1.9379754e-06, shape=(), dtype=float32)
# episode 991 Loss tf.Tensor(1.0006083, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006065, shape=(), dtype=float32)   loss_action tf.Tensor(1.8288993e-06, shape=(), dtype=float32)
# episode 992 Loss tf.Tensor(1.0005065, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005047, shape=(), dtype=float32)   loss_action tf.Tensor(1.810489e-06, shape=(), dtype=float32)
# episode 993 Loss tf.Tensor(1.0007012, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006993, shape=(), dtype=float32)   loss_action tf.Tensor(1.9222812e-06, shape=(), dtype=float32)
# episode 994 Loss tf.Tensor(1.0008098, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.000808, shape=(), dtype=float32)   loss_action tf.Tensor(1.8313453e-06, shape=(), dtype=float32)
# episode 995 Loss tf.Tensor(1.0005589, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005571, shape=(), dtype=float32)   loss_action tf.Tensor(1.7798385e-06, shape=(), dtype=float32)
# episode 996 Loss tf.Tensor(1.0004747, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004729, shape=(), dtype=float32)   loss_action tf.Tensor(1.7585448e-06, shape=(), dtype=float32)
# episode 997 Loss tf.Tensor(1.0005282, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0005263, shape=(), dtype=float32)   loss_action tf.Tensor(1.8555459e-06, shape=(), dtype=float32)
# episode 998 Loss tf.Tensor(1.0004817, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0004798, shape=(), dtype=float32)   loss_action tf.Tensor(1.8760852e-06, shape=(), dtype=float32)
# episode 999 Loss tf.Tensor(1.0006216, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.0006196, shape=(), dtype=float32)   loss_action tf.Tensor(1.8785333e-06, shape=(), dtype=float32)

# %%
p_inj.shape
# Out:
# (999, 7)

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*3 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

# %%
plt.plot(Loss_record)
plt.xlabel('episoid')
plt.ylabel('Loss')
# plt.title('Non-Discounted Loss without penalty')
# Out:
# Text(0, 0.5, 'Loss')

# %%
modelLinear0.save_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_Microsoft_K_250901_n8_q_t001.weights.h5')
# modelLinear0.load_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_K_250808_t001.weights.h5')
# modelLinear0.load_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_Vulcan_K_250808_n8_t001.weights.h5')

# %% [markdown]
# ## Simulation and Comparisons

# %% [markdown]
# ### With trained controller

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
linear_coffq = tf.math.minimum(modelLinear0.variables[0], K_bound_q)

# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = p_inj[0]
# P_ref
record_v0 = record_fault_trajectory[3,0,3,0:]

s_concate=P@Matrix_R.T+Q@Matrix_X.T+ record_v0[0]
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Record_up_Linear.append(np.zeros(dim_action))
Record_uq_Linear.append(np.zeros(dim_action) )
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
for i in range(1,SimulationLength):
    up=0*np.squeeze(Action_linear(s-1,linear_coffp))
    uq=np.squeeze(Action_linear(s-1,linear_coffq))
    p = Record_up_Linear[-1]- up
    q = Record_uq_Linear[-1]- uq
    q = np.minimum(np.maximum(q, q_min), q_max)
    next_s= (Q_ref+q)@Matrix_X + p@Matrix_R + record_v0[i]+ (p_inj[i])@Matrix_R
    # s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(p.copy())
    Record_uq_Linear.append(q.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/exp_decentralized_F4_q.png', bbox_inches='tight', dpi=600)
# Out:
# s [0.96762388 0.96715045 0.96715045 0.96715045 0.96715045 0.96585876
#  0.96585876 0.96585876 0.96585876 0.96585876 0.96585876 0.96585876
#  0.96585876]

# %%
q_min
# Out:
# array([   0.,    0., -100., -100.,    0.,   -4.,   -4.,   -4.,   -4.,
#          -4.,   -4.,   -4.,   -4.])

# %%
q_max
# Out:
# array([  0.,   0., 100., 100.,   0.,   4.,   4.,   4.,   4.,   4.,   4.,
#          4.,   4.])

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
# Q_init_ratio = 0.7
# P_init_ratio = 0.7
# delta_t = 0.001
Q = Q_ref
# # 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# # P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref
linear_coffq = tf.math.minimum(modelLinear0.variables[0], K_bound_q)

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=10000-100
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Record_uq_Linear.append(Q)
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[3,0,3,0:])
for i in range(SimulationLength):
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_uq_Linear.append(Record_uq_Linear[-1]-uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear+1)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
Record_up_Linear = np.zeros((SimulationLength+1,dim_action))
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/exp_decentralized_F4_q.png', bbox_inches='tight', dpi=600)
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %%
TimeRecord=delta_t*np.arange(0,p_inj.shape[0])
fig = plt.figure(figsize=(5,3), dpi=100)

plt.plot(TimeRecord,-p_inj[:,6])
plt.xlabel('time(s)')
plt.ylabel(' Computing load (MW)')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/Computing Load.png', bbox_inches='tight', dpi=600)

# %%
p_inj.shape
# Out:
# (9999, 7)

# %% [markdown]
# ### without control

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)*0
linear_coffq = tf.math.minimum(modelLinear0.variables[0], K_bound_q)*0

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
# record_v0 = np.diff(record_fault_trajectory[0,0,0,0:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/WoControl.png', bbox_inches='tight', dpi=600)
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %%
fig = plt.figure(figsize=(9,3), dpi=100)

TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,2,2)
plt.plot(TimeRecord,Trajectory_Linear+1)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')
plt.title('Voltage inside data centers without control')
plt.subplot(1,2,1)
plt.plot(TimeRecord,record_fault_trajectory[3,0,3,0:SimulationLength+1])
plt.xlabel('time(s)')
plt.ylabel('V0')
plt.title('Root node')
fig.tight_layout()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/exp_no_control_F4.png', bbox_inches='tight', dpi=600)

# %% [markdown]
# # Training - pg-diff

# %%
class RNNModel(tf.keras.Model):
    def __init__(self, cell):
        super().__init__()
        self.rnn = tf.keras.layers.RNN(cell, return_sequences=True, stateful=True)

    def call(self, inputs, initial_state=None):
        return self.rnn(inputs, initial_state=initial_state)

# %%
# RNN Cell to integrate state transition dynamics
class MinimalRNNCellLinear0(keras.layers.Layer):

    def __init__(self, units,action_units,internal_units,env,batchsize,K_boundq, K_boundp,**kwargs):
        self.units = units
        self.action_units = action_units
        self.state_size = units
        self.internal_units = internal_units
        self.batchsize=batchsize
        self.Matrix_X=tf.constant(env.Matrix_X,dtype=tf.float32)
        self.Matrix_R=tf.constant(env.Matrix_R,dtype=tf.float32)
        self.inv_Matrix_X = tf.constant(env.inv_Matrix_X,dtype=tf.float32)
        self.lambda_max = tf.constant(env.lambda_max,dtype=tf.float32)
        self.max_action=tf.constant(env.max_action,dtype=tf.float32)
        self.bound_slopq = tf.constant(K_boundq.reshape((1,-1)),dtype=tf.float32)
        self.bound_slopp = tf.constant(K_boundp.reshape((1,-1)),dtype=tf.float32)
        self.norm_q=1
        super(MinimalRNNCellLinear0, self).__init__(**kwargs)

    def build(self, input_shape):
        self.linear_Kp= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kp')

        self.linear_Kq= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kq')
        self.built = True

    def call(self, inputs_concate, states):
        # stacked ReLU structure to represent control network
        prev_state = states[0]
        prev_state_x = prev_state[:,0:self.action_units]
        prev_state_q =  prev_state[:,self.action_units:2*self.action_units]
        prev_state_p =  prev_state[:,2*self.action_units:3*self.action_units]
        inputs_p = inputs_concate[:,0:self.action_units]
        inputs_v0 = inputs_concate[:,self.action_units:self.action_units+1]


        linear_Kq_=tf.math.minimum(self.linear_Kq, self.bound_slopq )
        linear_Kp_=tf.math.minimum(self.linear_Kp, self.bound_slopp )
        action_q= K.sum(tf.linalg.diag(prev_state_x)*linear_Kq_,axis=2)
        action_p= K.sum(tf.linalg.diag(prev_state_x)*linear_Kp_,axis=2)
        # action=self.max_action-K.relu(self.max_action-action_nonconstrain)+K.relu(-self.max_action-action_nonconstrain)
        new_state_x=prev_state_x-K.dot(action_q, tf.transpose(self.Matrix_X))-K.dot(action_p, tf.transpose(self.Matrix_R))+ K.dot(inputs_p, tf.transpose(self.Matrix_R)) + K.dot(inputs_v0, tf.ones((1,self.action_units)))
        new_state_q = prev_state_q - action_q
        new_state_p = prev_state_p - action_p

        next_state =  tf.concat([new_state_x, new_state_q, new_state_p], axis = 1)


        return [new_state_x,action_q, action_p, new_state_q, new_state_p], [next_state]

# %%
p_inj_diff = np.diff(p_inj, axis=0)

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*3 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

Length_pred_dataset = p_inj_diff.shape[0]-100
column1_idx = np.arange(0,dim_action)
PrintUpdate = 1
for i in range(0,episodes):
    initial_state_q = (1- np.random.uniform(-Q_init_ratio,Q_init_ratio,(Batch_num,action_units)))*(Q_ref.T)
    initial_state_p = (1- np.random.uniform(-P_init_ratio,P_init_ratio,(Batch_num,action_units)))*(P_ref.T)
    initial_state=initial_state_p@Matrix_R.T+initial_state_q@Matrix_X.T

    Input_config = np.zeros((Batch_num,T,dim_action+1))
    for j in range(Batch_num):
       #### time varying p
       t_init_Pm = np.random.randint(0, Length_pred_dataset-T-1)
       Input_config[j,:,:dim_action]=p_inj_diff[t_init_Pm:t_init_Pm+T,:]
       ###### v0
       rand_fault_idx = np.random.randint(0,np.shape(record_fault_trajectory)[0])
       rand_time_idx = np.random.randint(1050,1150)
       rand_bus_idx = np.random.randint(0,np.shape(record_fault_trajectory)[2])
       Input_config[j,:,dim_action] = record_fault_trajectory[rand_fault_idx,0,rand_bus_idx,rand_time_idx:rand_time_idx+T]


    with tf.GradientTape(persistent=True) as tape:
        [voltage,action_q,action_p, record_q, record_p]=modelLinear0(Input_config, np.hstack((initial_state, initial_state_q, initial_state_p)))
        loss_voltage=K.sum(K.sum(K.abs(voltage)))/Batch_num/T/dim_action
        loss_action=0.01*(env.Penalty_action*K.sum(abs(record_q)))/Batch_num/T/dim_action + 0.01*(env.Penalty_action*K.sum(abs(record_p)))/Batch_num/T/dim_action
        loss=loss_voltage+loss_action
    grads = tape.gradient(loss, modelLinear0.variables)
    optimizer.apply_gradients(zip(grads, modelLinear0.variables))
    Loss_record.append(loss)



    if i % (PrintUpdate) == 0:
        print('episode',i, 'Loss',loss)
        print('         Loss_Voltage',loss_voltage, '  loss_action', loss_action)
# Out:
# episode 0 Loss tf.Tensor(15.878176, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(15.491846, shape=(), dtype=float32)   loss_action tf.Tensor(0.3863296, shape=(), dtype=float32)
# episode 1 Loss tf.Tensor(15.476242, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(15.0854435, shape=(), dtype=float32)   loss_action tf.Tensor(0.390799, shape=(), dtype=float32)
# episode 2 Loss tf.Tensor(15.041002, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(14.647262, shape=(), dtype=float32)   loss_action tf.Tensor(0.39374077, shape=(), dtype=float32)
# episode 3 Loss tf.Tensor(14.650449, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(14.253488, shape=(), dtype=float32)   loss_action tf.Tensor(0.39696103, shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2143674348.py in <cell line: 0>()
#      45         loss_action=0.01*(env.Penalty_action*K.sum(abs(record_q)))/Batch_num/T/dim_action + 0.01*(env.Penalty_action*K.sum(abs(record_p)))/Batch_num/T/dim_action
#      46         loss=loss_voltage+loss_action
# ---> 47     grads = tape.gradient(loss, modelLinear0.variables)
#      48     optimizer.apply_gradients(zip(grads, modelLinear0.variables))
#      49     Loss_record.append(loss)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1064                           for x in output_gradients]
#    1065
# -> 1066     flat_grad = imperative_grad.imperative_grad(
#    1067         self._tape,
#    1068         flat_targets,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      65         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#      69       target,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     146       gradient_name_scope += forward_pass_name_scope + "/"
#     147     with ops.name_scope(gradient_name_scope):
# --> 148       return grad_fn(mock_op, *out_grads)
#     149   else:
#     150     return grad_fn(mock_op, *out_grads)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/math_grad.py in _SubGrad(op, grad)
#    1395       x, y, grad
#    1396   ):
# -> 1397     return grad, -grad
#    1398
#    1399   gx = None if 0 in skip_input_indices else grad
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_math_ops.py in neg(x, name)
#    7001   if tld.is_eager:
#    7002     try:
# -> 7003       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    7004         _ctx, "Neg", name, x)
#    7005       return _result
#
# KeyboardInterrupt:

# %%
p_inj.shape
# Out:
# (999, 7)

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*3 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

# %%
plt.plot(Loss_record)
plt.xlabel('episoid')
plt.ylabel('Loss')
# plt.title('Non-Discounted Loss without penalty')
# Out:
# Text(0, 0.5, 'Loss')

# %%
# modelLinear0.save_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_Vulcan_K_250808_n8_t001.weights.h5')
# modelLinear0.load_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_K_250808_t001.weights.h5')
modelLinear0.load_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_Vulcan_K_250808_n8_t001.weights.h5')

# %% [markdown]
# ## Simulation and Comparisons

# %% [markdown]
# ### With trained controller

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
# Q_init_ratio = 0.7
# P_init_ratio = 0.7
# delta_t = 0.001
Q = Q_ref
# # 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# # P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)
linear_coffq = tf.math.minimum(modelLinear0.variables[1], K_bound_q)

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=10000-100
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
# record_v0 = np.diff(record_fault_trajectory[0,0,0,0:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear+1)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/Decentralized_F4.png', bbox_inches='tight', dpi=600)
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %%
TimeRecord=delta_t*np.arange(0,p_inj.shape[0])
fig = plt.figure(figsize=(5,3), dpi=100)

plt.plot(TimeRecord,-p_inj[:,6])
plt.xlabel('time(s)')
plt.ylabel(' Computing load (MW)')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/Computing Load.png', bbox_inches='tight', dpi=600)

# %%
p_inj.shape
# Out:
# (9999, 7)

# %% [markdown]
# ### without control

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)*0
linear_coffq = tf.math.minimum(modelLinear0.variables[1], K_bound_q)*0

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[0,0,0,0:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ 0.7*p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/WoControl.png', bbox_inches='tight', dpi=600)
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %%
fig = plt.figure(figsize=(9,3), dpi=100)

TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,2,2)
plt.plot(TimeRecord,Trajectory_Linear+1)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')
plt.title('Voltage inside data centers without control')
plt.subplot(1,2,1)
plt.plot(TimeRecord,record_fault_trajectory[3,0,3,0:SimulationLength+1])
plt.xlabel('time(s)')
plt.ylabel('V0')
plt.title('Root node')
fig.tight_layout()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/WoControl.png', bbox_inches='tight', dpi=600)

# %% [markdown]
# # Training -q-diff

# %%
class RNNModel(tf.keras.Model):
    def __init__(self, cell):
        super().__init__()
        self.rnn = tf.keras.layers.RNN(cell, return_sequences=True, stateful=True)

    def call(self, inputs, initial_state=None):
        return self.rnn(inputs, initial_state=initial_state)

# %%
# RNN Cell to integrate state transition dynamics
class MinimalRNNCellLinear0(keras.layers.Layer):

    def __init__(self, units,action_units,internal_units,env,batchsize,K_boundq, K_boundp,**kwargs):
        self.units = units
        self.action_units = action_units
        self.state_size = units
        self.internal_units = internal_units
        self.batchsize=batchsize
        self.Matrix_X=tf.constant(env.Matrix_X,dtype=tf.float32)
        self.Matrix_R=tf.constant(env.Matrix_R,dtype=tf.float32)
        self.inv_Matrix_X = tf.constant(env.inv_Matrix_X,dtype=tf.float32)
        self.lambda_max = tf.constant(env.lambda_max,dtype=tf.float32)
        self.max_action=tf.constant(env.max_action,dtype=tf.float32)
        self.bound_slopq = tf.constant(K_boundq.reshape((1,-1)),dtype=tf.float32)
        self.bound_slopp = tf.constant(K_boundp.reshape((1,-1)),dtype=tf.float32)
        self.norm_q=1
        super(MinimalRNNCellLinear0, self).__init__(**kwargs)

    def build(self, input_shape):


        self.linear_Kq= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kq')
        self.built = True

    def call(self, inputs_concate, states):
        # stacked ReLU structure to represent control network
        prev_state = states[0]
        prev_state_x = prev_state[:,0:self.action_units]
        prev_state_q =  prev_state[:,self.action_units:2*self.action_units]
        inputs_p = inputs_concate[:,0:self.action_units]
        inputs_v0 = inputs_concate[:,self.action_units:self.action_units+1]


        linear_Kq_=tf.math.minimum(self.linear_Kq, self.bound_slopq )
        action_nonconstrain= K.sum(tf.linalg.diag(prev_state_x)*linear_Kq_,axis=2)
        action_q=self.max_action-K.relu(self.max_action-action_nonconstrain)+K.relu(-self.max_action-action_nonconstrain)
        new_state_x=prev_state_x-K.dot(action_q, tf.transpose(self.Matrix_X))+ K.dot(inputs_p, tf.transpose(self.Matrix_R)) + K.dot(inputs_v0, tf.ones((1,self.action_units)))
        new_state_q = prev_state_q - action_q

        next_state =  tf.concat([new_state_x, new_state_q], axis = 1)


        return [new_state_x,action_q, new_state_q], [next_state]

# %%
p_inj_diff = np.diff(p_inj, axis=0)

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*2 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

Length_pred_dataset = p_inj_diff.shape[0]-100
column1_idx = np.arange(0,dim_action)
PrintUpdate = 1
for i in range(0,episodes):
    initial_state_q = (1- np.random.uniform(-Q_init_ratio,Q_init_ratio,(Batch_num,action_units)))*(Q_ref.T)
    initial_state_p = (1- np.random.uniform(-P_init_ratio,P_init_ratio,(Batch_num,action_units)))*(P_ref.T)
    initial_state=initial_state_p@Matrix_R.T+initial_state_q@Matrix_X.T

    Input_config = np.zeros((Batch_num,T,dim_action+1))
    for j in range(Batch_num):
       #### time varying p
       t_init_Pm = np.random.randint(0, Length_pred_dataset-T-1)
       Input_config[j,:,:dim_action]=p_inj_diff[t_init_Pm:t_init_Pm+T,:]
       ###### v0
       rand_fault_idx = np.random.randint(0,np.shape(record_fault_trajectory)[0])
       rand_time_idx = np.random.randint(1050,1150)
       rand_bus_idx = np.random.randint(0,np.shape(record_fault_trajectory)[2])
       Input_config[j,:,dim_action] = record_fault_trajectory[rand_fault_idx,0,rand_bus_idx,rand_time_idx:rand_time_idx+T]


    with tf.GradientTape(persistent=True) as tape:
        [voltage,action_q,record_q]=modelLinear0(Input_config, np.hstack((initial_state, initial_state_q)))
        loss_voltage=K.sum(K.sum(K.abs(voltage)))/Batch_num/T/dim_action
        loss_action=0.01*(env.Penalty_action*K.sum(abs(record_q)))/Batch_num/T/dim_action
        loss=loss_voltage+loss_action
    grads = tape.gradient(loss, modelLinear0.variables)
    optimizer.apply_gradients(zip(grads, modelLinear0.variables))
    Loss_record.append(loss)



    if i % (PrintUpdate) == 0:
        print('episode',i, 'Loss',loss)
        print('         Loss_Voltage',loss_voltage, '  loss_action', loss_action)
# Out:
# episode 0 Loss tf.Tensor(14.981677, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(14.7773905, shape=(), dtype=float32)   loss_action tf.Tensor(0.20428626, shape=(), dtype=float32)
# episode 1 Loss tf.Tensor(14.599428, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(14.393462, shape=(), dtype=float32)   loss_action tf.Tensor(0.20596634, shape=(), dtype=float32)
# episode 2 Loss tf.Tensor(14.27889, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(14.070687, shape=(), dtype=float32)   loss_action tf.Tensor(0.20820199, shape=(), dtype=float32)
# episode 3 Loss tf.Tensor(13.942223, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(13.732393, shape=(), dtype=float32)   loss_action tf.Tensor(0.20982955, shape=(), dtype=float32)
# episode 4 Loss tf.Tensor(13.622835, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(13.411407, shape=(), dtype=float32)   loss_action tf.Tensor(0.21142785, shape=(), dtype=float32)
# episode 5 Loss tf.Tensor(13.338716, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(13.125434, shape=(), dtype=float32)   loss_action tf.Tensor(0.21328193, shape=(), dtype=float32)
# episode 6 Loss tf.Tensor(13.0419235, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(12.827294, shape=(), dtype=float32)   loss_action tf.Tensor(0.21462886, shape=(), dtype=float32)
# episode 7 Loss tf.Tensor(12.774678, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(12.558522, shape=(), dtype=float32)   loss_action tf.Tensor(0.21615586, shape=(), dtype=float32)
# episode 8 Loss tf.Tensor(12.555134, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(12.336929, shape=(), dtype=float32)   loss_action tf.Tensor(0.2182048, shape=(), dtype=float32)
# episode 9 Loss tf.Tensor(12.279469, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(12.060439, shape=(), dtype=float32)   loss_action tf.Tensor(0.2190292, shape=(), dtype=float32)
# episode 10 Loss tf.Tensor(12.078287, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(11.857361, shape=(), dtype=float32)   loss_action tf.Tensor(0.22092631, shape=(), dtype=float32)
# episode 11 Loss tf.Tensor(11.857619, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(11.635314, shape=(), dtype=float32)   loss_action tf.Tensor(0.22230561, shape=(), dtype=float32)
# episode 12 Loss tf.Tensor(11.616753, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(11.393825, shape=(), dtype=float32)   loss_action tf.Tensor(0.22292796, shape=(), dtype=float32)
# episode 13 Loss tf.Tensor(11.424953, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(11.200701, shape=(), dtype=float32)   loss_action tf.Tensor(0.22425295, shape=(), dtype=float32)
# episode 14 Loss tf.Tensor(11.223195, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(10.997971, shape=(), dtype=float32)   loss_action tf.Tensor(0.22522484, shape=(), dtype=float32)
# episode 15 Loss tf.Tensor(11.053013, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(10.82638, shape=(), dtype=float32)   loss_action tf.Tensor(0.2266327, shape=(), dtype=float32)
# episode 16 Loss tf.Tensor(10.846497, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(10.619442, shape=(), dtype=float32)   loss_action tf.Tensor(0.22705421, shape=(), dtype=float32)
# episode 17 Loss tf.Tensor(10.676065, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(10.448048, shape=(), dtype=float32)   loss_action tf.Tensor(0.22801778, shape=(), dtype=float32)
# episode 18 Loss tf.Tensor(10.5359955, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(10.306595, shape=(), dtype=float32)   loss_action tf.Tensor(0.22940026, shape=(), dtype=float32)
# episode 19 Loss tf.Tensor(10.366837, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(10.136866, shape=(), dtype=float32)   loss_action tf.Tensor(0.22997051, shape=(), dtype=float32)
# episode 20 Loss tf.Tensor(10.213175, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.982389, shape=(), dtype=float32)   loss_action tf.Tensor(0.23078543, shape=(), dtype=float32)
# episode 21 Loss tf.Tensor(10.059643, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.828296, shape=(), dtype=float32)   loss_action tf.Tensor(0.2313474, shape=(), dtype=float32)
# episode 22 Loss tf.Tensor(9.959972, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.726999, shape=(), dtype=float32)   loss_action tf.Tensor(0.23297279, shape=(), dtype=float32)
# episode 23 Loss tf.Tensor(9.832321, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.598441, shape=(), dtype=float32)   loss_action tf.Tensor(0.2338796, shape=(), dtype=float32)
# episode 24 Loss tf.Tensor(9.678771, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.444765, shape=(), dtype=float32)   loss_action tf.Tensor(0.23400608, shape=(), dtype=float32)
# episode 25 Loss tf.Tensor(9.553221, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.318615, shape=(), dtype=float32)   loss_action tf.Tensor(0.23460576, shape=(), dtype=float32)
# episode 26 Loss tf.Tensor(9.441669, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.206248, shape=(), dtype=float32)   loss_action tf.Tensor(0.23542133, shape=(), dtype=float32)
# episode 27 Loss tf.Tensor(9.326783, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(9.090832, shape=(), dtype=float32)   loss_action tf.Tensor(0.23595129, shape=(), dtype=float32)
# episode 28 Loss tf.Tensor(9.2226, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.985866, shape=(), dtype=float32)   loss_action tf.Tensor(0.23673448, shape=(), dtype=float32)
# episode 29 Loss tf.Tensor(9.10084, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.863837, shape=(), dtype=float32)   loss_action tf.Tensor(0.2370022, shape=(), dtype=float32)
# episode 30 Loss tf.Tensor(9.015807, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.777886, shape=(), dtype=float32)   loss_action tf.Tensor(0.2379203, shape=(), dtype=float32)
# episode 31 Loss tf.Tensor(8.92315, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.68456, shape=(), dtype=float32)   loss_action tf.Tensor(0.23859027, shape=(), dtype=float32)
# episode 32 Loss tf.Tensor(8.811996, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.573336, shape=(), dtype=float32)   loss_action tf.Tensor(0.2386606, shape=(), dtype=float32)
# episode 33 Loss tf.Tensor(8.737762, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.498156, shape=(), dtype=float32)   loss_action tf.Tensor(0.239607, shape=(), dtype=float32)
# episode 34 Loss tf.Tensor(8.634365, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.394611, shape=(), dtype=float32)   loss_action tf.Tensor(0.23975347, shape=(), dtype=float32)
# episode 35 Loss tf.Tensor(8.575438, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.334486, shape=(), dtype=float32)   loss_action tf.Tensor(0.2409516, shape=(), dtype=float32)
# episode 36 Loss tf.Tensor(8.45356, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.213117, shape=(), dtype=float32)   loss_action tf.Tensor(0.24044341, shape=(), dtype=float32)
# episode 37 Loss tf.Tensor(8.387798, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.146529, shape=(), dtype=float32)   loss_action tf.Tensor(0.2412687, shape=(), dtype=float32)
# episode 38 Loss tf.Tensor(8.308029, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(8.066482, shape=(), dtype=float32)   loss_action tf.Tensor(0.24154736, shape=(), dtype=float32)
# episode 39 Loss tf.Tensor(8.241996, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.9997807, shape=(), dtype=float32)   loss_action tf.Tensor(0.24221532, shape=(), dtype=float32)
# episode 40 Loss tf.Tensor(8.167307, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.924714, shape=(), dtype=float32)   loss_action tf.Tensor(0.24259284, shape=(), dtype=float32)
# episode 41 Loss tf.Tensor(8.07799, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.835545, shape=(), dtype=float32)   loss_action tf.Tensor(0.24244478, shape=(), dtype=float32)
# episode 42 Loss tf.Tensor(8.03553, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.7919593, shape=(), dtype=float32)   loss_action tf.Tensor(0.24357086, shape=(), dtype=float32)
# episode 43 Loss tf.Tensor(7.9734135, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.7293234, shape=(), dtype=float32)   loss_action tf.Tensor(0.24408992, shape=(), dtype=float32)
# episode 44 Loss tf.Tensor(7.9164767, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.671851, shape=(), dtype=float32)   loss_action tf.Tensor(0.24462548, shape=(), dtype=float32)
# episode 45 Loss tf.Tensor(7.8329225, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.5884485, shape=(), dtype=float32)   loss_action tf.Tensor(0.2444739, shape=(), dtype=float32)
# episode 46 Loss tf.Tensor(7.7734127, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.528597, shape=(), dtype=float32)   loss_action tf.Tensor(0.24481569, shape=(), dtype=float32)
# episode 47 Loss tf.Tensor(7.7181334, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.4727855, shape=(), dtype=float32)   loss_action tf.Tensor(0.24534811, shape=(), dtype=float32)
# episode 48 Loss tf.Tensor(7.6503186, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.4049077, shape=(), dtype=float32)   loss_action tf.Tensor(0.24541093, shape=(), dtype=float32)
# episode 49 Loss tf.Tensor(7.611505, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.365366, shape=(), dtype=float32)   loss_action tf.Tensor(0.24613884, shape=(), dtype=float32)
# episode 50 Loss tf.Tensor(7.542598, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.2964725, shape=(), dtype=float32)   loss_action tf.Tensor(0.24612544, shape=(), dtype=float32)
# episode 51 Loss tf.Tensor(7.483597, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.237327, shape=(), dtype=float32)   loss_action tf.Tensor(0.24626957, shape=(), dtype=float32)
# episode 52 Loss tf.Tensor(7.432617, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.1860538, shape=(), dtype=float32)   loss_action tf.Tensor(0.24656336, shape=(), dtype=float32)
# episode 53 Loss tf.Tensor(7.39732, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.1499534, shape=(), dtype=float32)   loss_action tf.Tensor(0.24736619, shape=(), dtype=float32)
# episode 54 Loss tf.Tensor(7.3338847, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.086686, shape=(), dtype=float32)   loss_action tf.Tensor(0.24719848, shape=(), dtype=float32)
# episode 55 Loss tf.Tensor(7.288833, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.041225, shape=(), dtype=float32)   loss_action tf.Tensor(0.24760832, shape=(), dtype=float32)
# episode 56 Loss tf.Tensor(7.2485185, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(7.0004015, shape=(), dtype=float32)   loss_action tf.Tensor(0.24811715, shape=(), dtype=float32)
# episode 57 Loss tf.Tensor(7.2070575, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.958522, shape=(), dtype=float32)   loss_action tf.Tensor(0.24853581, shape=(), dtype=float32)
# episode 58 Loss tf.Tensor(7.154815, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.9061832, shape=(), dtype=float32)   loss_action tf.Tensor(0.24863213, shape=(), dtype=float32)
# episode 59 Loss tf.Tensor(7.0978074, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.8493543, shape=(), dtype=float32)   loss_action tf.Tensor(0.24845317, shape=(), dtype=float32)
# episode 60 Loss tf.Tensor(7.052365, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.803714, shape=(), dtype=float32)   loss_action tf.Tensor(0.24865094, shape=(), dtype=float32)
# episode 61 Loss tf.Tensor(7.0204225, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.771111, shape=(), dtype=float32)   loss_action tf.Tensor(0.24931128, shape=(), dtype=float32)
# episode 62 Loss tf.Tensor(6.975943, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.7265596, shape=(), dtype=float32)   loss_action tf.Tensor(0.24938329, shape=(), dtype=float32)
# episode 63 Loss tf.Tensor(6.935711, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.6860194, shape=(), dtype=float32)   loss_action tf.Tensor(0.24969171, shape=(), dtype=float32)
# episode 64 Loss tf.Tensor(6.912862, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.6624064, shape=(), dtype=float32)   loss_action tf.Tensor(0.2504554, shape=(), dtype=float32)
# episode 65 Loss tf.Tensor(6.8562098, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.606127, shape=(), dtype=float32)   loss_action tf.Tensor(0.25008297, shape=(), dtype=float32)
# episode 66 Loss tf.Tensor(6.81902, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.5685906, shape=(), dtype=float32)   loss_action tf.Tensor(0.25042897, shape=(), dtype=float32)
# episode 67 Loss tf.Tensor(6.78157, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.5308847, shape=(), dtype=float32)   loss_action tf.Tensor(0.250685, shape=(), dtype=float32)
# episode 68 Loss tf.Tensor(6.7420373, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.4913, shape=(), dtype=float32)   loss_action tf.Tensor(0.2507372, shape=(), dtype=float32)
# episode 69 Loss tf.Tensor(6.704449, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.4534845, shape=(), dtype=float32)   loss_action tf.Tensor(0.2509647, shape=(), dtype=float32)
# episode 70 Loss tf.Tensor(6.675709, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.424362, shape=(), dtype=float32)   loss_action tf.Tensor(0.25134647, shape=(), dtype=float32)
# episode 71 Loss tf.Tensor(6.6353397, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.3838964, shape=(), dtype=float32)   loss_action tf.Tensor(0.25144345, shape=(), dtype=float32)
# episode 72 Loss tf.Tensor(6.5981946, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.346698, shape=(), dtype=float32)   loss_action tf.Tensor(0.25149697, shape=(), dtype=float32)
# episode 73 Loss tf.Tensor(6.5800366, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.3277926, shape=(), dtype=float32)   loss_action tf.Tensor(0.25224414, shape=(), dtype=float32)
# episode 74 Loss tf.Tensor(6.533427, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.281435, shape=(), dtype=float32)   loss_action tf.Tensor(0.25199184, shape=(), dtype=float32)
# episode 75 Loss tf.Tensor(6.4960113, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.2440825, shape=(), dtype=float32)   loss_action tf.Tensor(0.25192884, shape=(), dtype=float32)
# episode 76 Loss tf.Tensor(6.477349, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.2247014, shape=(), dtype=float32)   loss_action tf.Tensor(0.2526473, shape=(), dtype=float32)
# episode 77 Loss tf.Tensor(6.430349, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.1780176, shape=(), dtype=float32)   loss_action tf.Tensor(0.2523313, shape=(), dtype=float32)
# episode 78 Loss tf.Tensor(6.407994, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.1552515, shape=(), dtype=float32)   loss_action tf.Tensor(0.25274235, shape=(), dtype=float32)
# episode 79 Loss tf.Tensor(6.3913774, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.137879, shape=(), dtype=float32)   loss_action tf.Tensor(0.2534988, shape=(), dtype=float32)
# episode 80 Loss tf.Tensor(6.345695, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.092619, shape=(), dtype=float32)   loss_action tf.Tensor(0.25307605, shape=(), dtype=float32)
# episode 81 Loss tf.Tensor(6.313587, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.0604243, shape=(), dtype=float32)   loss_action tf.Tensor(0.25316307, shape=(), dtype=float32)
# episode 82 Loss tf.Tensor(6.292052, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.038392, shape=(), dtype=float32)   loss_action tf.Tensor(0.25365993, shape=(), dtype=float32)
# episode 83 Loss tf.Tensor(6.256062, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(6.0025682, shape=(), dtype=float32)   loss_action tf.Tensor(0.25349393, shape=(), dtype=float32)
# episode 84 Loss tf.Tensor(6.226937, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.9733243, shape=(), dtype=float32)   loss_action tf.Tensor(0.25361258, shape=(), dtype=float32)
# episode 85 Loss tf.Tensor(6.2139473, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.9595137, shape=(), dtype=float32)   loss_action tf.Tensor(0.25443375, shape=(), dtype=float32)
# episode 86 Loss tf.Tensor(6.179035, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.924731, shape=(), dtype=float32)   loss_action tf.Tensor(0.25430435, shape=(), dtype=float32)
# episode 87 Loss tf.Tensor(6.14321, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.8890758, shape=(), dtype=float32)   loss_action tf.Tensor(0.2541342, shape=(), dtype=float32)
# episode 88 Loss tf.Tensor(6.132307, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.87741, shape=(), dtype=float32)   loss_action tf.Tensor(0.25489697, shape=(), dtype=float32)
# episode 89 Loss tf.Tensor(6.1007147, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.845878, shape=(), dtype=float32)   loss_action tf.Tensor(0.2548366, shape=(), dtype=float32)
# episode 90 Loss tf.Tensor(6.0752296, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.8202205, shape=(), dtype=float32)   loss_action tf.Tensor(0.2550094, shape=(), dtype=float32)
# episode 91 Loss tf.Tensor(6.050731, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.7955117, shape=(), dtype=float32)   loss_action tf.Tensor(0.2552193, shape=(), dtype=float32)
# episode 92 Loss tf.Tensor(6.021366, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.7661867, shape=(), dtype=float32)   loss_action tf.Tensor(0.2551792, shape=(), dtype=float32)
# episode 93 Loss tf.Tensor(6.0074983, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.751753, shape=(), dtype=float32)   loss_action tf.Tensor(0.25574553, shape=(), dtype=float32)
# episode 94 Loss tf.Tensor(5.9667635, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.711477, shape=(), dtype=float32)   loss_action tf.Tensor(0.25528663, shape=(), dtype=float32)
# episode 95 Loss tf.Tensor(5.9521046, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.696328, shape=(), dtype=float32)   loss_action tf.Tensor(0.25577632, shape=(), dtype=float32)
# episode 96 Loss tf.Tensor(5.9247613, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.6689754, shape=(), dtype=float32)   loss_action tf.Tensor(0.25578612, shape=(), dtype=float32)
# episode 97 Loss tf.Tensor(5.8822656, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.6271067, shape=(), dtype=float32)   loss_action tf.Tensor(0.25515872, shape=(), dtype=float32)
# episode 98 Loss tf.Tensor(5.871574, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.615799, shape=(), dtype=float32)   loss_action tf.Tensor(0.25577515, shape=(), dtype=float32)
# episode 99 Loss tf.Tensor(5.852482, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.596408, shape=(), dtype=float32)   loss_action tf.Tensor(0.25607383, shape=(), dtype=float32)
# episode 100 Loss tf.Tensor(5.831837, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.575482, shape=(), dtype=float32)   loss_action tf.Tensor(0.25635535, shape=(), dtype=float32)
# episode 101 Loss tf.Tensor(5.796107, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.5402594, shape=(), dtype=float32)   loss_action tf.Tensor(0.25584728, shape=(), dtype=float32)
# episode 102 Loss tf.Tensor(5.784367, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.528086, shape=(), dtype=float32)   loss_action tf.Tensor(0.256281, shape=(), dtype=float32)
# episode 103 Loss tf.Tensor(5.772113, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.515384, shape=(), dtype=float32)   loss_action tf.Tensor(0.25672877, shape=(), dtype=float32)
# episode 104 Loss tf.Tensor(5.7596083, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.5024366, shape=(), dtype=float32)   loss_action tf.Tensor(0.2571718, shape=(), dtype=float32)
# episode 105 Loss tf.Tensor(5.7231045, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.466571, shape=(), dtype=float32)   loss_action tf.Tensor(0.2565336, shape=(), dtype=float32)
# episode 106 Loss tf.Tensor(5.711122, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.4541883, shape=(), dtype=float32)   loss_action tf.Tensor(0.2569338, shape=(), dtype=float32)
# episode 107 Loss tf.Tensor(5.6862345, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.429452, shape=(), dtype=float32)   loss_action tf.Tensor(0.2567827, shape=(), dtype=float32)
# episode 108 Loss tf.Tensor(5.6691327, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.4121714, shape=(), dtype=float32)   loss_action tf.Tensor(0.25696132, shape=(), dtype=float32)
# episode 109 Loss tf.Tensor(5.6597013, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.402258, shape=(), dtype=float32)   loss_action tf.Tensor(0.2574432, shape=(), dtype=float32)
# episode 110 Loss tf.Tensor(5.644081, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.3863745, shape=(), dtype=float32)   loss_action tf.Tensor(0.25770667, shape=(), dtype=float32)
# episode 111 Loss tf.Tensor(5.6169147, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.359502, shape=(), dtype=float32)   loss_action tf.Tensor(0.25741312, shape=(), dtype=float32)
# episode 112 Loss tf.Tensor(5.607667, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.349783, shape=(), dtype=float32)   loss_action tf.Tensor(0.25788388, shape=(), dtype=float32)
# episode 113 Loss tf.Tensor(5.588983, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.3310113, shape=(), dtype=float32)   loss_action tf.Tensor(0.25797197, shape=(), dtype=float32)
# episode 114 Loss tf.Tensor(5.564176, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.3064075, shape=(), dtype=float32)   loss_action tf.Tensor(0.25776866, shape=(), dtype=float32)
# episode 115 Loss tf.Tensor(5.548256, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.290283, shape=(), dtype=float32)   loss_action tf.Tensor(0.2579725, shape=(), dtype=float32)
# episode 116 Loss tf.Tensor(5.520792, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.2632346, shape=(), dtype=float32)   loss_action tf.Tensor(0.2575574, shape=(), dtype=float32)
# episode 117 Loss tf.Tensor(5.5210705, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.2626987, shape=(), dtype=float32)   loss_action tf.Tensor(0.25837168, shape=(), dtype=float32)
# episode 118 Loss tf.Tensor(5.492071, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.23403, shape=(), dtype=float32)   loss_action tf.Tensor(0.2580415, shape=(), dtype=float32)
# episode 119 Loss tf.Tensor(5.463933, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.206232, shape=(), dtype=float32)   loss_action tf.Tensor(0.2577011, shape=(), dtype=float32)
# episode 120 Loss tf.Tensor(5.4584093, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.2001753, shape=(), dtype=float32)   loss_action tf.Tensor(0.2582342, shape=(), dtype=float32)
# episode 121 Loss tf.Tensor(5.4431705, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.1847973, shape=(), dtype=float32)   loss_action tf.Tensor(0.2583734, shape=(), dtype=float32)
# episode 122 Loss tf.Tensor(5.4320602, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.17334, shape=(), dtype=float32)   loss_action tf.Tensor(0.25872022, shape=(), dtype=float32)
# episode 123 Loss tf.Tensor(5.412857, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.1542172, shape=(), dtype=float32)   loss_action tf.Tensor(0.25863975, shape=(), dtype=float32)
# episode 124 Loss tf.Tensor(5.4038925, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.144878, shape=(), dtype=float32)   loss_action tf.Tensor(0.2590147, shape=(), dtype=float32)
# episode 125 Loss tf.Tensor(5.3693223, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.1110044, shape=(), dtype=float32)   loss_action tf.Tensor(0.25831804, shape=(), dtype=float32)
# episode 126 Loss tf.Tensor(5.35943, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.1007757, shape=(), dtype=float32)   loss_action tf.Tensor(0.258654, shape=(), dtype=float32)
# episode 127 Loss tf.Tensor(5.351834, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.0927005, shape=(), dtype=float32)   loss_action tf.Tensor(0.2591332, shape=(), dtype=float32)
# episode 128 Loss tf.Tensor(5.334736, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.075635, shape=(), dtype=float32)   loss_action tf.Tensor(0.25910097, shape=(), dtype=float32)
# episode 129 Loss tf.Tensor(5.3238974, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.064484, shape=(), dtype=float32)   loss_action tf.Tensor(0.2594133, shape=(), dtype=float32)
# episode 130 Loss tf.Tensor(5.317723, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.057807, shape=(), dtype=float32)   loss_action tf.Tensor(0.2599157, shape=(), dtype=float32)
# episode 131 Loss tf.Tensor(5.2933097, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.0338187, shape=(), dtype=float32)   loss_action tf.Tensor(0.2594908, shape=(), dtype=float32)
# episode 132 Loss tf.Tensor(5.269195, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.0100117, shape=(), dtype=float32)   loss_action tf.Tensor(0.25918335, shape=(), dtype=float32)
# episode 133 Loss tf.Tensor(5.265235, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(5.0054297, shape=(), dtype=float32)   loss_action tf.Tensor(0.25980544, shape=(), dtype=float32)
# episode 134 Loss tf.Tensor(5.241101, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.9816203, shape=(), dtype=float32)   loss_action tf.Tensor(0.25948027, shape=(), dtype=float32)
# episode 135 Loss tf.Tensor(5.2293706, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.969658, shape=(), dtype=float32)   loss_action tf.Tensor(0.25971282, shape=(), dtype=float32)
# episode 136 Loss tf.Tensor(5.204634, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.9453707, shape=(), dtype=float32)   loss_action tf.Tensor(0.25926343, shape=(), dtype=float32)
# episode 137 Loss tf.Tensor(5.2049727, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.9448643, shape=(), dtype=float32)   loss_action tf.Tensor(0.2601083, shape=(), dtype=float32)
# episode 138 Loss tf.Tensor(5.179265, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.9196706, shape=(), dtype=float32)   loss_action tf.Tensor(0.25959462, shape=(), dtype=float32)
# episode 139 Loss tf.Tensor(5.172629, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.912554, shape=(), dtype=float32)   loss_action tf.Tensor(0.2600752, shape=(), dtype=float32)
# episode 140 Loss tf.Tensor(5.1690817, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.9084287, shape=(), dtype=float32)   loss_action tf.Tensor(0.2606529, shape=(), dtype=float32)
# episode 141 Loss tf.Tensor(5.1486225, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.8882294, shape=(), dtype=float32)   loss_action tf.Tensor(0.26039317, shape=(), dtype=float32)
# episode 142 Loss tf.Tensor(5.1361217, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.87553, shape=(), dtype=float32)   loss_action tf.Tensor(0.2605921, shape=(), dtype=float32)
# episode 143 Loss tf.Tensor(5.1178913, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.8574405, shape=(), dtype=float32)   loss_action tf.Tensor(0.2604509, shape=(), dtype=float32)
# episode 144 Loss tf.Tensor(5.1030083, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.8425593, shape=(), dtype=float32)   loss_action tf.Tensor(0.26044884, shape=(), dtype=float32)
# episode 145 Loss tf.Tensor(5.092565, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.8320136, shape=(), dtype=float32)   loss_action tf.Tensor(0.26055136, shape=(), dtype=float32)
# episode 146 Loss tf.Tensor(5.0782065, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.8175583, shape=(), dtype=float32)   loss_action tf.Tensor(0.26064822, shape=(), dtype=float32)
# episode 147 Loss tf.Tensor(5.071293, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.8101892, shape=(), dtype=float32)   loss_action tf.Tensor(0.26110342, shape=(), dtype=float32)
# episode 148 Loss tf.Tensor(5.049507, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.7887783, shape=(), dtype=float32)   loss_action tf.Tensor(0.26072884, shape=(), dtype=float32)
# episode 149 Loss tf.Tensor(5.036492, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.7756886, shape=(), dtype=float32)   loss_action tf.Tensor(0.26080322, shape=(), dtype=float32)
# episode 150 Loss tf.Tensor(5.0266676, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.765661, shape=(), dtype=float32)   loss_action tf.Tensor(0.26100704, shape=(), dtype=float32)
# episode 151 Loss tf.Tensor(5.0192738, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.7579007, shape=(), dtype=float32)   loss_action tf.Tensor(0.26137307, shape=(), dtype=float32)
# episode 152 Loss tf.Tensor(5.0091205, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.7475276, shape=(), dtype=float32)   loss_action tf.Tensor(0.26159275, shape=(), dtype=float32)
# episode 153 Loss tf.Tensor(4.995767, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.734222, shape=(), dtype=float32)   loss_action tf.Tensor(0.26154518, shape=(), dtype=float32)
# episode 154 Loss tf.Tensor(4.9708858, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.709843, shape=(), dtype=float32)   loss_action tf.Tensor(0.26104242, shape=(), dtype=float32)
# episode 155 Loss tf.Tensor(4.961922, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.700629, shape=(), dtype=float32)   loss_action tf.Tensor(0.2612929, shape=(), dtype=float32)
# episode 156 Loss tf.Tensor(4.9493074, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.6879816, shape=(), dtype=float32)   loss_action tf.Tensor(0.261326, shape=(), dtype=float32)
# episode 157 Loss tf.Tensor(4.9481587, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.6862216, shape=(), dtype=float32)   loss_action tf.Tensor(0.26193717, shape=(), dtype=float32)
# episode 158 Loss tf.Tensor(4.9333334, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.6713696, shape=(), dtype=float32)   loss_action tf.Tensor(0.2619639, shape=(), dtype=float32)
# episode 159 Loss tf.Tensor(4.9213076, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.6593046, shape=(), dtype=float32)   loss_action tf.Tensor(0.26200297, shape=(), dtype=float32)
# episode 160 Loss tf.Tensor(4.901969, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.640328, shape=(), dtype=float32)   loss_action tf.Tensor(0.2616409, shape=(), dtype=float32)
# episode 161 Loss tf.Tensor(4.906278, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.643692, shape=(), dtype=float32)   loss_action tf.Tensor(0.26258606, shape=(), dtype=float32)
# episode 162 Loss tf.Tensor(4.870799, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.6093726, shape=(), dtype=float32)   loss_action tf.Tensor(0.26142648, shape=(), dtype=float32)
# episode 163 Loss tf.Tensor(4.8658834, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.6040483, shape=(), dtype=float32)   loss_action tf.Tensor(0.26183528, shape=(), dtype=float32)
# episode 164 Loss tf.Tensor(4.864742, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.6023245, shape=(), dtype=float32)   loss_action tf.Tensor(0.2624172, shape=(), dtype=float32)
# episode 165 Loss tf.Tensor(4.8420544, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.5800877, shape=(), dtype=float32)   loss_action tf.Tensor(0.2619669, shape=(), dtype=float32)
# episode 166 Loss tf.Tensor(4.826641, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.5647764, shape=(), dtype=float32)   loss_action tf.Tensor(0.26186463, shape=(), dtype=float32)
# episode 167 Loss tf.Tensor(4.812265, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.5505037, shape=(), dtype=float32)   loss_action tf.Tensor(0.26176107, shape=(), dtype=float32)
# episode 168 Loss tf.Tensor(4.8258576, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.562826, shape=(), dtype=float32)   loss_action tf.Tensor(0.26303127, shape=(), dtype=float32)
# episode 169 Loss tf.Tensor(4.79268, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.530626, shape=(), dtype=float32)   loss_action tf.Tensor(0.262054, shape=(), dtype=float32)
# episode 170 Loss tf.Tensor(4.773639, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.5119085, shape=(), dtype=float32)   loss_action tf.Tensor(0.26173055, shape=(), dtype=float32)
# episode 171 Loss tf.Tensor(4.7837515, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.5209203, shape=(), dtype=float32)   loss_action tf.Tensor(0.26283133, shape=(), dtype=float32)
# episode 172 Loss tf.Tensor(4.765795, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.5032587, shape=(), dtype=float32)   loss_action tf.Tensor(0.2625367, shape=(), dtype=float32)
# episode 173 Loss tf.Tensor(4.7538, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.4913006, shape=(), dtype=float32)   loss_action tf.Tensor(0.26249954, shape=(), dtype=float32)
# episode 174 Loss tf.Tensor(4.7484803, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.485584, shape=(), dtype=float32)   loss_action tf.Tensor(0.2628965, shape=(), dtype=float32)
# episode 175 Loss tf.Tensor(4.7213635, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.4592247, shape=(), dtype=float32)   loss_action tf.Tensor(0.26213905, shape=(), dtype=float32)
# episode 176 Loss tf.Tensor(4.7264023, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.4634023, shape=(), dtype=float32)   loss_action tf.Tensor(0.26300025, shape=(), dtype=float32)
# episode 177 Loss tf.Tensor(4.710958, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.4481997, shape=(), dtype=float32)   loss_action tf.Tensor(0.26275814, shape=(), dtype=float32)
# episode 178 Loss tf.Tensor(4.700762, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.437861, shape=(), dtype=float32)   loss_action tf.Tensor(0.2629007, shape=(), dtype=float32)
# episode 179 Loss tf.Tensor(4.6879067, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.4251223, shape=(), dtype=float32)   loss_action tf.Tensor(0.2627846, shape=(), dtype=float32)
# episode 180 Loss tf.Tensor(4.6775036, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.4146123, shape=(), dtype=float32)   loss_action tf.Tensor(0.26289132, shape=(), dtype=float32)
# episode 181 Loss tf.Tensor(4.6859555, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.4220333, shape=(), dtype=float32)   loss_action tf.Tensor(0.26392204, shape=(), dtype=float32)
# episode 182 Loss tf.Tensor(4.652154, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.3893094, shape=(), dtype=float32)   loss_action tf.Tensor(0.26284444, shape=(), dtype=float32)
# episode 183 Loss tf.Tensor(4.6458497, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.382845, shape=(), dtype=float32)   loss_action tf.Tensor(0.26300484, shape=(), dtype=float32)
# episode 184 Loss tf.Tensor(4.6467757, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.383141, shape=(), dtype=float32)   loss_action tf.Tensor(0.2636348, shape=(), dtype=float32)
# episode 185 Loss tf.Tensor(4.6218104, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.3589, shape=(), dtype=float32)   loss_action tf.Tensor(0.26291028, shape=(), dtype=float32)
# episode 186 Loss tf.Tensor(4.6175632, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.354311, shape=(), dtype=float32)   loss_action tf.Tensor(0.26325232, shape=(), dtype=float32)
# episode 187 Loss tf.Tensor(4.6225634, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.358474, shape=(), dtype=float32)   loss_action tf.Tensor(0.2640897, shape=(), dtype=float32)
# episode 188 Loss tf.Tensor(4.592986, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.329835, shape=(), dtype=float32)   loss_action tf.Tensor(0.263151, shape=(), dtype=float32)
# episode 189 Loss tf.Tensor(4.596349, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.3324594, shape=(), dtype=float32)   loss_action tf.Tensor(0.26388946, shape=(), dtype=float32)
# episode 190 Loss tf.Tensor(4.5841093, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.3202496, shape=(), dtype=float32)   loss_action tf.Tensor(0.26385978, shape=(), dtype=float32)
# episode 191 Loss tf.Tensor(4.5681806, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.30468, shape=(), dtype=float32)   loss_action tf.Tensor(0.26350078, shape=(), dtype=float32)
# episode 192 Loss tf.Tensor(4.5677443, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.3036194, shape=(), dtype=float32)   loss_action tf.Tensor(0.264125, shape=(), dtype=float32)
# episode 193 Loss tf.Tensor(4.556561, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.2924886, shape=(), dtype=float32)   loss_action tf.Tensor(0.26407257, shape=(), dtype=float32)
# episode 194 Loss tf.Tensor(4.537942, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.274355, shape=(), dtype=float32)   loss_action tf.Tensor(0.26358694, shape=(), dtype=float32)
# episode 195 Loss tf.Tensor(4.5354276, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.271394, shape=(), dtype=float32)   loss_action tf.Tensor(0.26403376, shape=(), dtype=float32)
# episode 196 Loss tf.Tensor(4.5204453, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.256729, shape=(), dtype=float32)   loss_action tf.Tensor(0.2637164, shape=(), dtype=float32)
# episode 197 Loss tf.Tensor(4.521932, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.257442, shape=(), dtype=float32)   loss_action tf.Tensor(0.26449034, shape=(), dtype=float32)
# episode 198 Loss tf.Tensor(4.511054, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.246644, shape=(), dtype=float32)   loss_action tf.Tensor(0.26440993, shape=(), dtype=float32)
# episode 199 Loss tf.Tensor(4.4981303, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.2338877, shape=(), dtype=float32)   loss_action tf.Tensor(0.26424244, shape=(), dtype=float32)
# episode 200 Loss tf.Tensor(4.485153, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.2210393, shape=(), dtype=float32)   loss_action tf.Tensor(0.26411387, shape=(), dtype=float32)
# episode 201 Loss tf.Tensor(4.473905, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.209943, shape=(), dtype=float32)   loss_action tf.Tensor(0.2639623, shape=(), dtype=float32)
# episode 202 Loss tf.Tensor(4.4722137, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.20784, shape=(), dtype=float32)   loss_action tf.Tensor(0.26437384, shape=(), dtype=float32)
# episode 203 Loss tf.Tensor(4.4597874, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.1955857, shape=(), dtype=float32)   loss_action tf.Tensor(0.26420158, shape=(), dtype=float32)
# episode 204 Loss tf.Tensor(4.450305, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.186128, shape=(), dtype=float32)   loss_action tf.Tensor(0.26417693, shape=(), dtype=float32)
# episode 205 Loss tf.Tensor(4.4423027, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.17809, shape=(), dtype=float32)   loss_action tf.Tensor(0.26421237, shape=(), dtype=float32)
# episode 206 Loss tf.Tensor(4.4426584, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.1779094, shape=(), dtype=float32)   loss_action tf.Tensor(0.26474914, shape=(), dtype=float32)
# episode 207 Loss tf.Tensor(4.4306645, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.166132, shape=(), dtype=float32)   loss_action tf.Tensor(0.2645324, shape=(), dtype=float32)
# episode 208 Loss tf.Tensor(4.436315, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.170917, shape=(), dtype=float32)   loss_action tf.Tensor(0.26539811, shape=(), dtype=float32)
# episode 209 Loss tf.Tensor(4.4159994, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.151254, shape=(), dtype=float32)   loss_action tf.Tensor(0.26474518, shape=(), dtype=float32)
# episode 210 Loss tf.Tensor(4.407363, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.1426663, shape=(), dtype=float32)   loss_action tf.Tensor(0.2646968, shape=(), dtype=float32)
# episode 211 Loss tf.Tensor(4.403662, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.1386847, shape=(), dtype=float32)   loss_action tf.Tensor(0.26497743, shape=(), dtype=float32)
# episode 212 Loss tf.Tensor(4.391705, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.126891, shape=(), dtype=float32)   loss_action tf.Tensor(0.264814, shape=(), dtype=float32)
# episode 213 Loss tf.Tensor(4.38621, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.1213064, shape=(), dtype=float32)   loss_action tf.Tensor(0.26490346, shape=(), dtype=float32)
# episode 214 Loss tf.Tensor(4.3788967, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.113955, shape=(), dtype=float32)   loss_action tf.Tensor(0.2649415, shape=(), dtype=float32)
# episode 215 Loss tf.Tensor(4.3697147, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.1046934, shape=(), dtype=float32)   loss_action tf.Tensor(0.26502126, shape=(), dtype=float32)
# episode 216 Loss tf.Tensor(4.3560696, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.0913754, shape=(), dtype=float32)   loss_action tf.Tensor(0.26469445, shape=(), dtype=float32)
# episode 217 Loss tf.Tensor(4.356015, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.090886, shape=(), dtype=float32)   loss_action tf.Tensor(0.26512918, shape=(), dtype=float32)
# episode 218 Loss tf.Tensor(4.3416557, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.076869, shape=(), dtype=float32)   loss_action tf.Tensor(0.26478693, shape=(), dtype=float32)
# episode 219 Loss tf.Tensor(4.3490252, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.0833545, shape=(), dtype=float32)   loss_action tf.Tensor(0.2656708, shape=(), dtype=float32)
# episode 220 Loss tf.Tensor(4.3281627, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.0631948, shape=(), dtype=float32)   loss_action tf.Tensor(0.26496813, shape=(), dtype=float32)
# episode 221 Loss tf.Tensor(4.336982, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.0710626, shape=(), dtype=float32)   loss_action tf.Tensor(0.2659191, shape=(), dtype=float32)
# episode 222 Loss tf.Tensor(4.3205013, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.05505, shape=(), dtype=float32)   loss_action tf.Tensor(0.26545155, shape=(), dtype=float32)
# episode 223 Loss tf.Tensor(4.317386, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.051732, shape=(), dtype=float32)   loss_action tf.Tensor(0.26565388, shape=(), dtype=float32)
# episode 224 Loss tf.Tensor(4.304726, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.039256, shape=(), dtype=float32)   loss_action tf.Tensor(0.26547015, shape=(), dtype=float32)
# episode 225 Loss tf.Tensor(4.3035154, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.037629, shape=(), dtype=float32)   loss_action tf.Tensor(0.26588634, shape=(), dtype=float32)
# episode 226 Loss tf.Tensor(4.2928634, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.027222, shape=(), dtype=float32)   loss_action tf.Tensor(0.26564133, shape=(), dtype=float32)
# episode 227 Loss tf.Tensor(4.291912, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.0258565, shape=(), dtype=float32)   loss_action tf.Tensor(0.2660557, shape=(), dtype=float32)
# episode 228 Loss tf.Tensor(4.272164, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.00673, shape=(), dtype=float32)   loss_action tf.Tensor(0.2654339, shape=(), dtype=float32)
# episode 229 Loss tf.Tensor(4.2691545, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.003549, shape=(), dtype=float32)   loss_action tf.Tensor(0.26560563, shape=(), dtype=float32)
# episode 230 Loss tf.Tensor(4.2607827, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.995212, shape=(), dtype=float32)   loss_action tf.Tensor(0.26557058, shape=(), dtype=float32)
# episode 231 Loss tf.Tensor(4.2540174, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.988288, shape=(), dtype=float32)   loss_action tf.Tensor(0.26572955, shape=(), dtype=float32)
# episode 232 Loss tf.Tensor(4.2479925, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9822328, shape=(), dtype=float32)   loss_action tf.Tensor(0.26575947, shape=(), dtype=float32)
# episode 233 Loss tf.Tensor(4.243471, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9774704, shape=(), dtype=float32)   loss_action tf.Tensor(0.26600057, shape=(), dtype=float32)
# episode 234 Loss tf.Tensor(4.2371836, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9712083, shape=(), dtype=float32)   loss_action tf.Tensor(0.26597503, shape=(), dtype=float32)
# episode 235 Loss tf.Tensor(4.22973, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9636579, shape=(), dtype=float32)   loss_action tf.Tensor(0.2660722, shape=(), dtype=float32)
# episode 236 Loss tf.Tensor(4.224031, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.957913, shape=(), dtype=float32)   loss_action tf.Tensor(0.266118, shape=(), dtype=float32)
# episode 237 Loss tf.Tensor(4.2121377, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.946288, shape=(), dtype=float32)   loss_action tf.Tensor(0.26584977, shape=(), dtype=float32)
# episode 238 Loss tf.Tensor(4.2002363, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9345393, shape=(), dtype=float32)   loss_action tf.Tensor(0.26569682, shape=(), dtype=float32)
# episode 239 Loss tf.Tensor(4.202615, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9364095, shape=(), dtype=float32)   loss_action tf.Tensor(0.26620513, shape=(), dtype=float32)
# episode 240 Loss tf.Tensor(4.207959, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9409661, shape=(), dtype=float32)   loss_action tf.Tensor(0.26699302, shape=(), dtype=float32)
# episode 241 Loss tf.Tensor(4.1872783, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.921014, shape=(), dtype=float32)   loss_action tf.Tensor(0.26626408, shape=(), dtype=float32)
# episode 242 Loss tf.Tensor(4.1786737, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9124956, shape=(), dtype=float32)   loss_action tf.Tensor(0.26617807, shape=(), dtype=float32)
# episode 243 Loss tf.Tensor(4.1779017, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9113684, shape=(), dtype=float32)   loss_action tf.Tensor(0.26653346, shape=(), dtype=float32)
# episode 244 Loss tf.Tensor(4.17407, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.9073367, shape=(), dtype=float32)   loss_action tf.Tensor(0.266733, shape=(), dtype=float32)
# episode 245 Loss tf.Tensor(4.1537557, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.8877466, shape=(), dtype=float32)   loss_action tf.Tensor(0.26600924, shape=(), dtype=float32)
# episode 246 Loss tf.Tensor(4.1649594, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.8979502, shape=(), dtype=float32)   loss_action tf.Tensor(0.26700923, shape=(), dtype=float32)
# episode 247 Loss tf.Tensor(4.14886, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.882375, shape=(), dtype=float32)   loss_action tf.Tensor(0.2664849, shape=(), dtype=float32)
# episode 248 Loss tf.Tensor(4.1396527, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.8732088, shape=(), dtype=float32)   loss_action tf.Tensor(0.26644418, shape=(), dtype=float32)
# episode 249 Loss tf.Tensor(4.129783, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.8635783, shape=(), dtype=float32)   loss_action tf.Tensor(0.26620477, shape=(), dtype=float32)
# episode 250 Loss tf.Tensor(4.122831, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.8565767, shape=(), dtype=float32)   loss_action tf.Tensor(0.26625407, shape=(), dtype=float32)
# episode 251 Loss tf.Tensor(4.1141753, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.8480706, shape=(), dtype=float32)   loss_action tf.Tensor(0.26610473, shape=(), dtype=float32)
# episode 252 Loss tf.Tensor(4.1161895, shape=(), dtype=float32)
# ...
# episode 917 Loss tf.Tensor(2.5724413, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2949288, shape=(), dtype=float32)   loss_action tf.Tensor(0.27751252, shape=(), dtype=float32)
# episode 918 Loss tf.Tensor(2.5633216, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.286671, shape=(), dtype=float32)   loss_action tf.Tensor(0.27665064, shape=(), dtype=float32)
# episode 919 Loss tf.Tensor(2.5660405, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2889524, shape=(), dtype=float32)   loss_action tf.Tensor(0.27708805, shape=(), dtype=float32)
# episode 920 Loss tf.Tensor(2.5662367, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2891047, shape=(), dtype=float32)   loss_action tf.Tensor(0.2771321, shape=(), dtype=float32)
# episode 921 Loss tf.Tensor(2.5626886, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2857504, shape=(), dtype=float32)   loss_action tf.Tensor(0.27693823, shape=(), dtype=float32)
# episode 922 Loss tf.Tensor(2.5605762, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2837927, shape=(), dtype=float32)   loss_action tf.Tensor(0.27678356, shape=(), dtype=float32)
# episode 923 Loss tf.Tensor(2.563945, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.28669, shape=(), dtype=float32)   loss_action tf.Tensor(0.27725503, shape=(), dtype=float32)
# episode 924 Loss tf.Tensor(2.5509863, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2750156, shape=(), dtype=float32)   loss_action tf.Tensor(0.2759706, shape=(), dtype=float32)
# episode 925 Loss tf.Tensor(2.5630333, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2857766, shape=(), dtype=float32)   loss_action tf.Tensor(0.2772567, shape=(), dtype=float32)
# episode 926 Loss tf.Tensor(2.5597596, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2827141, shape=(), dtype=float32)   loss_action tf.Tensor(0.27704546, shape=(), dtype=float32)
# episode 927 Loss tf.Tensor(2.5598252, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2826486, shape=(), dtype=float32)   loss_action tf.Tensor(0.2771766, shape=(), dtype=float32)
# episode 928 Loss tf.Tensor(2.560694, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2832983, shape=(), dtype=float32)   loss_action tf.Tensor(0.27739567, shape=(), dtype=float32)
# episode 929 Loss tf.Tensor(2.55855, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2813559, shape=(), dtype=float32)   loss_action tf.Tensor(0.27719393, shape=(), dtype=float32)
# episode 930 Loss tf.Tensor(2.5537872, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2769268, shape=(), dtype=float32)   loss_action tf.Tensor(0.2768604, shape=(), dtype=float32)
# episode 931 Loss tf.Tensor(2.553937, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2769701, shape=(), dtype=float32)   loss_action tf.Tensor(0.27696687, shape=(), dtype=float32)
# episode 932 Loss tf.Tensor(2.5504825, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2737904, shape=(), dtype=float32)   loss_action tf.Tensor(0.27669224, shape=(), dtype=float32)
# episode 933 Loss tf.Tensor(2.5506647, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2737863, shape=(), dtype=float32)   loss_action tf.Tensor(0.27687836, shape=(), dtype=float32)
# episode 934 Loss tf.Tensor(2.5524879, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2753923, shape=(), dtype=float32)   loss_action tf.Tensor(0.27709544, shape=(), dtype=float32)
# episode 935 Loss tf.Tensor(2.553654, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2764285, shape=(), dtype=float32)   loss_action tf.Tensor(0.27722555, shape=(), dtype=float32)
# episode 936 Loss tf.Tensor(2.552521, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2752512, shape=(), dtype=float32)   loss_action tf.Tensor(0.27726987, shape=(), dtype=float32)
# episode 937 Loss tf.Tensor(2.5433202, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2668328, shape=(), dtype=float32)   loss_action tf.Tensor(0.2764873, shape=(), dtype=float32)
# episode 938 Loss tf.Tensor(2.5463004, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.269423, shape=(), dtype=float32)   loss_action tf.Tensor(0.27687737, shape=(), dtype=float32)
# episode 939 Loss tf.Tensor(2.551287, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2738392, shape=(), dtype=float32)   loss_action tf.Tensor(0.2774476, shape=(), dtype=float32)
# episode 940 Loss tf.Tensor(2.5477567, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2706285, shape=(), dtype=float32)   loss_action tf.Tensor(0.2771282, shape=(), dtype=float32)
# episode 941 Loss tf.Tensor(2.5501032, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2725337, shape=(), dtype=float32)   loss_action tf.Tensor(0.2775696, shape=(), dtype=float32)
# episode 942 Loss tf.Tensor(2.5453355, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.268234, shape=(), dtype=float32)   loss_action tf.Tensor(0.27710155, shape=(), dtype=float32)
# episode 943 Loss tf.Tensor(2.5459588, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2687936, shape=(), dtype=float32)   loss_action tf.Tensor(0.27716526, shape=(), dtype=float32)
# episode 944 Loss tf.Tensor(2.545775, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2684646, shape=(), dtype=float32)   loss_action tf.Tensor(0.27731028, shape=(), dtype=float32)
# episode 945 Loss tf.Tensor(2.5421982, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.265119, shape=(), dtype=float32)   loss_action tf.Tensor(0.27707916, shape=(), dtype=float32)
# episode 946 Loss tf.Tensor(2.5477495, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2700043, shape=(), dtype=float32)   loss_action tf.Tensor(0.2777452, shape=(), dtype=float32)
# episode 947 Loss tf.Tensor(2.542077, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2648015, shape=(), dtype=float32)   loss_action tf.Tensor(0.2772755, shape=(), dtype=float32)
# episode 948 Loss tf.Tensor(2.5472066, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2693803, shape=(), dtype=float32)   loss_action tf.Tensor(0.27782637, shape=(), dtype=float32)
# episode 949 Loss tf.Tensor(2.5404222, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2631865, shape=(), dtype=float32)   loss_action tf.Tensor(0.2772358, shape=(), dtype=float32)
# episode 950 Loss tf.Tensor(2.5433714, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2657163, shape=(), dtype=float32)   loss_action tf.Tensor(0.27765515, shape=(), dtype=float32)
# episode 951 Loss tf.Tensor(2.5408564, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2633398, shape=(), dtype=float32)   loss_action tf.Tensor(0.27751672, shape=(), dtype=float32)
# episode 952 Loss tf.Tensor(2.535131, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2581046, shape=(), dtype=float32)   loss_action tf.Tensor(0.27702633, shape=(), dtype=float32)
# episode 953 Loss tf.Tensor(2.5374546, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2601075, shape=(), dtype=float32)   loss_action tf.Tensor(0.2773471, shape=(), dtype=float32)
# episode 954 Loss tf.Tensor(2.5324526, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2554815, shape=(), dtype=float32)   loss_action tf.Tensor(0.27697116, shape=(), dtype=float32)
# episode 955 Loss tf.Tensor(2.5311804, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2542434, shape=(), dtype=float32)   loss_action tf.Tensor(0.27693707, shape=(), dtype=float32)
# episode 956 Loss tf.Tensor(2.5318363, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2548351, shape=(), dtype=float32)   loss_action tf.Tensor(0.2770012, shape=(), dtype=float32)
# episode 957 Loss tf.Tensor(2.5354862, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2579627, shape=(), dtype=float32)   loss_action tf.Tensor(0.27752352, shape=(), dtype=float32)
# episode 958 Loss tf.Tensor(2.534789, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2572584, shape=(), dtype=float32)   loss_action tf.Tensor(0.2775306, shape=(), dtype=float32)
# episode 959 Loss tf.Tensor(2.535271, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.257608, shape=(), dtype=float32)   loss_action tf.Tensor(0.27766302, shape=(), dtype=float32)
# episode 960 Loss tf.Tensor(2.5365515, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.258687, shape=(), dtype=float32)   loss_action tf.Tensor(0.2778644, shape=(), dtype=float32)
# episode 961 Loss tf.Tensor(2.5267177, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2497785, shape=(), dtype=float32)   loss_action tf.Tensor(0.27693912, shape=(), dtype=float32)
# episode 962 Loss tf.Tensor(2.5283868, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2510965, shape=(), dtype=float32)   loss_action tf.Tensor(0.27729037, shape=(), dtype=float32)
# episode 963 Loss tf.Tensor(2.5320654, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.254384, shape=(), dtype=float32)   loss_action tf.Tensor(0.27768138, shape=(), dtype=float32)
# episode 964 Loss tf.Tensor(2.532538, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2547464, shape=(), dtype=float32)   loss_action tf.Tensor(0.27779147, shape=(), dtype=float32)
# episode 965 Loss tf.Tensor(2.5292156, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2516258, shape=(), dtype=float32)   loss_action tf.Tensor(0.27758983, shape=(), dtype=float32)
# episode 966 Loss tf.Tensor(2.5218134, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2449121, shape=(), dtype=float32)   loss_action tf.Tensor(0.2769013, shape=(), dtype=float32)
# episode 967 Loss tf.Tensor(2.5300293, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2522442, shape=(), dtype=float32)   loss_action tf.Tensor(0.277785, shape=(), dtype=float32)
# episode 968 Loss tf.Tensor(2.520996, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2439961, shape=(), dtype=float32)   loss_action tf.Tensor(0.27699983, shape=(), dtype=float32)
# episode 969 Loss tf.Tensor(2.5262847, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2486243, shape=(), dtype=float32)   loss_action tf.Tensor(0.27766034, shape=(), dtype=float32)
# episode 970 Loss tf.Tensor(2.52477, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2471538, shape=(), dtype=float32)   loss_action tf.Tensor(0.2776162, shape=(), dtype=float32)
# episode 971 Loss tf.Tensor(2.5214202, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2440856, shape=(), dtype=float32)   loss_action tf.Tensor(0.27733472, shape=(), dtype=float32)
# episode 972 Loss tf.Tensor(2.5182567, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2411096, shape=(), dtype=float32)   loss_action tf.Tensor(0.27714717, shape=(), dtype=float32)
# episode 973 Loss tf.Tensor(2.5167646, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2397425, shape=(), dtype=float32)   loss_action tf.Tensor(0.27702218, shape=(), dtype=float32)
# episode 974 Loss tf.Tensor(2.515534, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2385094, shape=(), dtype=float32)   loss_action tf.Tensor(0.2770244, shape=(), dtype=float32)
# episode 975 Loss tf.Tensor(2.5209394, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2433085, shape=(), dtype=float32)   loss_action tf.Tensor(0.27763087, shape=(), dtype=float32)
# episode 976 Loss tf.Tensor(2.5158854, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2386909, shape=(), dtype=float32)   loss_action tf.Tensor(0.2771944, shape=(), dtype=float32)
# episode 977 Loss tf.Tensor(2.5195618, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2418768, shape=(), dtype=float32)   loss_action tf.Tensor(0.27768496, shape=(), dtype=float32)
# episode 978 Loss tf.Tensor(2.5109797, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2340164, shape=(), dtype=float32)   loss_action tf.Tensor(0.27696317, shape=(), dtype=float32)
# episode 979 Loss tf.Tensor(2.5118484, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2347758, shape=(), dtype=float32)   loss_action tf.Tensor(0.27707255, shape=(), dtype=float32)
# episode 980 Loss tf.Tensor(2.5176992, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2398927, shape=(), dtype=float32)   loss_action tf.Tensor(0.27780652, shape=(), dtype=float32)
# episode 981 Loss tf.Tensor(2.5149207, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2373095, shape=(), dtype=float32)   loss_action tf.Tensor(0.27761137, shape=(), dtype=float32)
# episode 982 Loss tf.Tensor(2.509315, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2322023, shape=(), dtype=float32)   loss_action tf.Tensor(0.27711284, shape=(), dtype=float32)
# episode 983 Loss tf.Tensor(2.5132818, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.23568, shape=(), dtype=float32)   loss_action tf.Tensor(0.27760163, shape=(), dtype=float32)
# episode 984 Loss tf.Tensor(2.5117855, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2342093, shape=(), dtype=float32)   loss_action tf.Tensor(0.27757624, shape=(), dtype=float32)
# episode 985 Loss tf.Tensor(2.513408, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2355995, shape=(), dtype=float32)   loss_action tf.Tensor(0.27780834, shape=(), dtype=float32)
# episode 986 Loss tf.Tensor(2.5098972, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.232379, shape=(), dtype=float32)   loss_action tf.Tensor(0.2775184, shape=(), dtype=float32)
# episode 987 Loss tf.Tensor(2.5100613, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2323132, shape=(), dtype=float32)   loss_action tf.Tensor(0.27774805, shape=(), dtype=float32)
# episode 988 Loss tf.Tensor(2.5074582, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2299573, shape=(), dtype=float32)   loss_action tf.Tensor(0.2775009, shape=(), dtype=float32)
# episode 989 Loss tf.Tensor(2.5048716, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2275572, shape=(), dtype=float32)   loss_action tf.Tensor(0.27731442, shape=(), dtype=float32)
# episode 990 Loss tf.Tensor(2.5042713, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.226893, shape=(), dtype=float32)   loss_action tf.Tensor(0.27737838, shape=(), dtype=float32)
# episode 991 Loss tf.Tensor(2.5029209, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2256546, shape=(), dtype=float32)   loss_action tf.Tensor(0.2772663, shape=(), dtype=float32)
# episode 992 Loss tf.Tensor(2.5038977, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2264254, shape=(), dtype=float32)   loss_action tf.Tensor(0.27747238, shape=(), dtype=float32)
# episode 993 Loss tf.Tensor(2.499346, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2222757, shape=(), dtype=float32)   loss_action tf.Tensor(0.27707025, shape=(), dtype=float32)
# episode 994 Loss tf.Tensor(2.5056074, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2277217, shape=(), dtype=float32)   loss_action tf.Tensor(0.27788574, shape=(), dtype=float32)
# episode 995 Loss tf.Tensor(2.5013661, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2238412, shape=(), dtype=float32)   loss_action tf.Tensor(0.27752498, shape=(), dtype=float32)
# episode 996 Loss tf.Tensor(2.5028417, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2251775, shape=(), dtype=float32)   loss_action tf.Tensor(0.2776642, shape=(), dtype=float32)
# episode 997 Loss tf.Tensor(2.501067, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2234623, shape=(), dtype=float32)   loss_action tf.Tensor(0.27760452, shape=(), dtype=float32)
# episode 998 Loss tf.Tensor(2.4965384, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2192512, shape=(), dtype=float32)   loss_action tf.Tensor(0.2772873, shape=(), dtype=float32)
# episode 999 Loss tf.Tensor(2.496645, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2192924, shape=(), dtype=float32)   loss_action tf.Tensor(0.27735245, shape=(), dtype=float32)

# %%
p_inj.shape
# Out:
# (999, 7)

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*3 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

# %%
plt.plot(Loss_record)
plt.xlabel('episoid')
plt.ylabel('Loss')
# plt.title('Non-Discounted Loss without penalty')
# Out:
# Text(0, 0.5, 'Loss')

# %%
modelLinear0.save_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_Vulcan_K_250808_n8_q_t001.weights.h5')
# modelLinear0.load_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_K_250808_t001.weights.h5')
# modelLinear0.load_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_Vulcan_K_250808_n8_t001.weights.h5')

# %% [markdown]
# ## Simulation and Comparisons

# %% [markdown]
# ### With trained controller

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
# Q_init_ratio = 0.7
# P_init_ratio = 0.7
# delta_t = 0.001
Q = Q_ref
# # 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# # P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref
linear_coffq = tf.math.minimum(modelLinear0.variables[0], K_bound_q)

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=10000-100
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Record_uq_Linear.append(Q)
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[3,0,3,0:])
for i in range(SimulationLength):
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_uq_Linear.append(Record_uq_Linear[-1]-uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear+1)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
Record_up_Linear = np.zeros((SimulationLength+1,dim_action))
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/exp_decentralized_F4_q.png', bbox_inches='tight', dpi=600)
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %%
TimeRecord=delta_t*np.arange(0,p_inj.shape[0])
fig = plt.figure(figsize=(5,3), dpi=100)

plt.plot(TimeRecord,-p_inj[:,6])
plt.xlabel('time(s)')
plt.ylabel(' Computing load (MW)')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/Computing Load.png', bbox_inches='tight', dpi=600)

# %%
p_inj.shape
# Out:
# (9999, 7)

# %% [markdown]
# ### without control

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 0.001
Q = 1*Q_ref
# 0*(Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T
P = P_ref
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)*0
linear_coffq = tf.math.minimum(modelLinear0.variables[0], K_bound_q)*0

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=6000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
# record_v0 = np.diff(record_fault_trajectory[0,0,0,0:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]+ p_inj_diff[i]@Matrix_R
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/WoControl.png', bbox_inches='tight', dpi=600)
# Out:
# s [-2.77555756e-17 -2.77555756e-17 -3.46944695e-17 -2.77555756e-17
#  -2.77555756e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -4.16333634e-17 -3.46944695e-17 -3.46944695e-17 -3.46944695e-17
#  -2.77555756e-17]

# %%
fig = plt.figure(figsize=(9,3), dpi=100)

TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,2,2)
plt.plot(TimeRecord,Trajectory_Linear+1)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')
plt.title('Voltage inside data centers without control')
plt.subplot(1,2,1)
plt.plot(TimeRecord,record_fault_trajectory[3,0,3,0:SimulationLength+1])
plt.xlabel('time(s)')
plt.ylabel('V0')
plt.title('Root node')
fig.tight_layout()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/250805 data center/figure/exp_no_control_F4.png', bbox_inches='tight', dpi=600)
