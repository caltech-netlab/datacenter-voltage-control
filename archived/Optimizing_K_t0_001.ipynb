# %% [markdown]
# <a href="https://colab.research.google.com/github/caltech-netlab/datacenter-voltage-control/blob/master/Optimizing_K_t0_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import scipy.io
import random
import math
import scipy.io as sio
import h5py
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# !pip install mat4py
# Out:
# Collecting mat4py
#   Downloading mat4py-0.6.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading mat4py-0.6.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: mat4py
# Successfully installed mat4py-0.6.0

# %%
# A RNN-based Reinforcement Learning Framework for Frequency Control Problem with Stability Guarantee
import collections
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import gym
import tensorflow as tf
import os
import random
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.layers import RNN
import tensorflow.keras.backend as K
import sys
from gym import spaces
from gym.utils import seeding
import copy
from mat4py import loadmat
from tensorflow.keras import layers
from tensorflow import keras
import time
import cvxpy as cp
import pickle
from numpy import linalg as LA
from mat4py import loadmat

# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# # Load data for time-varying voltage

# %%
# from scipy.io import loadmat
# filepath = '/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen_t0.001.mat'

# data = loadmat(filepath)
# print(data.keys())  # Show variable names in the file

# # Access a specific variable
# record_trajectory = data['record_trajectory']
# record_trajectory = np.array(record_trajectory)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'record_trajectory'])

# %%
# f = open("/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen_t0.001.pckl", 'wb')
# pickle.dump([record_trajectory], f)
# f.close()

f = open("/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen_t0.001.pckl", 'rb')
[record_fault_trajectory] = pickle.load(f)
f.close()

# %%
# randomly print 10 cases
plt.ion()
# fig = plt.figure(figsize=(5,4), dpi=100)

for test_idx in range(5):
    fig = plt.figure(figsize=(18,4), dpi=100)

    voltage = record_fault_trajectory[test_idx,0,:,:]
    time = 0.001*np.arange(0,np.shape(voltage)[-1])
    plt.subplot(1,3,1)
    plt.plot(time, record_fault_trajectory[test_idx,0,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('Voltage(p.u.)')

    # freq = record_fault_trajectory[test_idx,2,:,:]
    plt.subplot(1,3,2)
    plt.plot(time, record_fault_trajectory[test_idx,1,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('omega(Hz)')

    plt.subplot(1,3,3)
    plt.plot(time, record_fault_trajectory[test_idx,2,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('Power(p.u.)')


    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()
    plt.pause(0.01)
    plt.clf()

# %% [markdown]
# # Environment Setup

# %% [markdown]
# ### initialize the variables and system matrices

# %%
# Frequency Control Porblem Environment
class Voltage(gym.Env):
    def  __init__(self, Matrix_X,Matrix_R, max_action,dim_action,Penalty_action):
        self.param_gamma=1
        self.Matrix_X = Matrix_X.astype(np.float32)
        self.Matrix_R = Matrix_R.astype(np.float32)
        self.inv_Matrix_X = LA.inv(Matrix_X).astype(np.float32)
        self.lambda_max = np.max(LA.eigvals(Matrix_X))
        self.max_action = max_action.astype(np.float32)
        self.dim_action=dim_action
        self.delta_t = 1
        self.state=[]
        self.Penalty_action=Penalty_action


    def step(self, action):
        # action=K.dot(self.Multiply_V_ref-K.dot(prev_output, self.select_V),tf.linalg.diag(Vector_A))
        # integrate the state transition dynamics

        self.state=(self.state-action@(self.Matrix_X.T)).copy()
        # loss = self.param_gamma*np.sum(abs(self.V_ref.T-self.state@self.select_V))
        return self.state

    def step_varyingP(self, action, Pt):


        self.state=(self.state-action@(self.Matrix_X.T)+Pt@(self.Matrix_R.T)).copy()
        return self.state

    def set_state(self, state_input):
        self.state=state_input


    def reset(self):
        self.state = np.random.uniform(-1,1,(1,self.dim_action)).astype(np.float32)

        return self.state

# %%
# Simulation data load from IEEE 39-bus system
data = loadmat('/content/drive/MyDrive/Colab Notebooks/voltage control/TestCase33.mat')
filename='TestCase'
Matrix_R=data[filename]['R']
Matrix_R=np.asarray(Matrix_R, dtype=np.float32)

Matrix_X=data[filename]['X']
Matrix_X=np.asarray(Matrix_X, dtype=np.float32)

V_ref=data[filename]['V_ref']
V_ref=np.asarray(V_ref, dtype=np.float32)

temp=data[filename]['Q_ref']
Q_ref=np.asarray(temp, dtype=np.float32)

temp=data[filename]['P_ref']
P_ref=np.asarray(temp, dtype=np.float32)

temp=data[filename]['X']
Matrix_X=np.asarray(temp, dtype=np.float32)
Matrix_X=Matrix_X*0.1
Q_ref=Q_ref*10
P_ref=P_ref*10
Matrix_R = Matrix_R*0.1
X = Matrix_X

# %%
V_ref
# Out:
# array(0.99718845, dtype=float32)

# %%
dim_action=np.shape(Matrix_X)[0] #dimension of action space
Penalty_action=0.1
max_action= np.array([[0.04618363, 0.04674364, 0.03820283, 0.02924964, 0.02933332,
        0.02808668, 0.02881535, 0.04165629, 0.02335836, 0.01319888,
        0.04392617, 0.03839902, 0.01095371, 0.03840252, 0.02673872,
        0.02880578, 0.04716627, 0.02909166, 0.01550123, 0.02202384,
        0.01126694, 0.02100154, 0.01310747, 0.04232934, 0.0467296 ,
        0.01062543, 0.02215125, 0.01564784, 0.01676404, 0.01368452,
        0.0293981 , 0.04056301]])*10
# np.random.uniform(low=0.01, high=0.05, size=(1,dim_action))
# V_ref=Matrix_R@P_ref+Matrix_X@Q_ref+np.ones((dim_action,1))
V_ref = np.ones((dim_action,1))
Q_ref = -(LA.inv(Matrix_X))@Matrix_R@P_ref
env = Voltage(Matrix_X,Matrix_R, max_action,dim_action,Penalty_action)

# %%
lambda_max = np.max(LA.eigvals(Matrix_X))
print(LA.eigvals(Matrix_X))
2/lambda_max
# Out:
# [3.4275191e+00 1.1865367e+00 3.8679045e-01 3.5932353e-01 2.1738757e-01
#  1.6381116e-01 1.1451307e-01 7.9195574e-02 4.9670655e-02 4.0017378e-02
#  3.8222149e-02 3.5467807e-02 2.4649292e-02 2.0972826e-02 1.9898353e-02
#  1.8713778e-02 1.7802618e-02 1.5669120e-02 1.3006557e-02 1.2439296e-02
#  1.0556605e-02 1.0098979e-02 8.4837424e-03 6.8230918e-03 6.6868677e-03
#  6.1158007e-03 5.6651193e-03 5.5383639e-03 3.4610531e-03 2.3776738e-03
#  1.8364788e-03 1.6726028e-03]
# np.float32(0.5835124)

# %% [markdown]
# # CVX

# %% [markdown]
# ## Bounds for linear coefficients

# %%
Matrix_X_inv=np.linalg.inv(Matrix_X)

# %%
# weight_bound = np.ones(dim_action)

# K_bound=cp.Variable(dim_action,nonneg =True)
# objective = cp.Maximize(cp.sum(weight_bound*cp.log(K_bound)))
# diag_K_bound = cp.diag(K_bound)
# constraints = [(diag_K_bound -2*Matrix_X_inv)<<0,diag_K_bound>>0]

# prob = cp.Problem(objective, constraints)
# result = prob.solve()
# print('status',prob.status)
# K_bound=np.array(K_bound.value)

# %%
Matrix_X_inv=np.linalg.inv(Matrix_X)
Matrix_R_inv=np.linalg.inv(Matrix_R)

# %%
ratio_q = 0.5
K_bound=cp.Variable(dim_action,nonneg =True)
objective = cp.Maximize(cp.sum(cp.log(K_bound)))
diag_K_bound = cp.diag(K_bound)
constraints = [(diag_K_bound -ratio_q*2*Matrix_X_inv)<<0,diag_K_bound>>0]

prob = cp.Problem(objective, constraints)
result = prob.solve()
print('status',prob.status)
K_bound_q=np.array(K_bound.value)

ratio_p = 1 - ratio_q
K_bound=cp.Variable(dim_action,nonneg =True)
objective = cp.Maximize(cp.sum(cp.log(K_bound)))
diag_K_bound = cp.diag(K_bound)
constraints = [(diag_K_bound -ratio_p*2*Matrix_R_inv)<<0,diag_K_bound>>0]

prob = cp.Problem(objective, constraints)
result = prob.solve()
print('status',prob.status)
K_bound_p=np.array(K_bound.value)

print('K_bound_p', K_bound_p)
print('K_bound_q', K_bound_q)
# Out:
# status optimal
# status optimal
# K_bound_p [33.13205052  2.18645592  1.13989253  0.71534797  0.35978971  0.33612829
#   0.27174666  0.2133651   0.17583967  0.17061247  0.16253843  0.13960123
#   0.13357502  0.1286682   0.12429967  0.11957259  0.11828278 15.17853965
#   2.35379281  1.92837532  1.65622679  1.67080535  1.24842126  1.09967117
#   0.33913391  0.3167263   0.25973565  0.23174487  0.21944893  0.20356251
#   0.20042063  0.19872979]
# K_bound_q [74.81522491  4.91000218  2.60226066  1.66088345  0.60329601  0.43615224
#   0.39523299  0.30786703  0.25295983  0.24936051  0.2436395   0.20503434
#   0.18887919  0.18031748  0.17412578  0.16223709  0.16037872 23.35948177
#   2.88422014  2.20828     1.77388146  3.40482427  2.23567852  1.88261545
#   0.57446335  0.54289475  0.41181229  0.35382671  0.33925188  0.30356288
#   0.29555196  0.28991024]

# %% [markdown]
# ## LQR results for comparison

# %%
from scipy import linalg

# %%
def dlqr(A,B,Q,R):
    """Solve the discrete time lqr controller.


    x[k+1] = A x[k] + B u[k]

    cost = sum x[k].T*Q*x[k] + u[k].T*R*u[k]

    cite: http://www.kostasalexis.com/lqr-control.html
    """
    #ref Bertsekas, p.151

    #first, try to solve the ricatti equation
    X_ = np.matrix(linalg.solve_discrete_are(A, B, Q, R))

    #compute the LQR gain
    K_ = -np.matrix(linalg.inv(B.T@X_@B+R)*(B.T@X_@A))

    eigVals, eigVecs = linalg.eig(A+B@K_)

    return -K_, X_, eigVals

# %%
A_m = np.eye(dim_action)
B_m = np.hstack((Matrix_X, Matrix_R))
Q = np.eye(dim_action)
R = 1*np.eye(dim_action*2)
K_, X_, eigVals = dlqr(A_m,B_m,Q,R)

# %%
np.diag(K_)
# Out:
# array([0.39351821, 0.43446884, 0.43676986, 0.34958304, 0.45749813,
#        0.34246423, 0.48148863, 0.54057536, 0.37539332, 0.29324261,
#        0.33319658, 0.55859959, 0.64321566, 0.5667808 , 0.51504098,
#        0.63699886, 0.50577436, 0.67483459, 0.617381  , 0.7009809 ,
#        0.71404423, 0.54435207, 0.58210166, 0.55915177, 0.43659543,
#        0.41358803, 0.61166319, 0.52726619, 0.4015466 , 0.62150911,
#        0.66863748, 0.7337022 ])

# %% [markdown]
# # Init Simulation

# %%
#linear droop control
def Action_linear(state,linear_coff):
    action_nonconstrain = state*linear_coff
    action=action_nonconstrain
    # env.max_action-tf.nn.relu(env.max_action-action_nonconstrain)+tf.nn.relu(-env.max_action-action_nonconstrain)
    return action
def Action_constraints(action_nonconstrain):
    action=env.max_action-K.relu(env.max_action-action_nonconstrain)+K.relu(-env.max_action-action_nonconstrain)
    return action

# %%
linear_coffp= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
linear_coffq= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
# linear_coffp= K_[0:dim_action].reshape((1,-1))
# linear_coffq= K_[dim_action:].reshape((1,-1))
action_units=dim_action

# %% [markdown]
# ### With V0 after fault

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 1
Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=1000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[0,0,0,1100:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [[-0.00049247 -0.00254432 -0.00427607 -0.00637325 -0.01546296 -0.02440115
#   -0.02550197 -0.02533173 -0.02514099 -0.02516744 -0.02526827 -0.02605657
#   -0.02568533 -0.02553296 -0.02558034 -0.02596489 -0.02608037 -0.00059728
#   -0.00123166 -0.00145457 -0.00146676 -0.0017073  -0.00050807  0.00192461
#   -0.01523629 -0.01483655 -0.01150831 -0.00918699 -0.0084083  -0.00837179
#   -0.00810658 -0.00797632]]

# %% [markdown]
# ### With constant

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
# Q_init_ratio = 0.7
# P_init_ratio = 0.7
# delta_t = 1
# Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
# P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

# s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=1000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 =0* np.diff(record_fault_trajectory[0,0,0,1100:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [[-0.00049247 -0.00254432 -0.00427607 -0.00637325 -0.01546296 -0.02440115
#   -0.02550197 -0.02533173 -0.02514099 -0.02516744 -0.02526827 -0.02605657
#   -0.02568533 -0.02553296 -0.02558034 -0.02596489 -0.02608037 -0.00059728
#   -0.00123166 -0.00145457 -0.00146676 -0.0017073  -0.00050807  0.00192461
#   -0.01523629 -0.01483655 -0.01150831 -0.00918699 -0.0084083  -0.00837179
#   -0.00810658 -0.00797632]]

# %% [markdown]
# # Training

# %%
class RNNModel(tf.keras.Model):
    def __init__(self, cell):
        super().__init__()
        self.rnn = tf.keras.layers.RNN(cell, return_sequences=True, stateful=True)

    def call(self, inputs, initial_state=None):
        return self.rnn(inputs, initial_state=initial_state)

# %%
# RNN Cell to integrate state transition dynamics
class MinimalRNNCellLinear0(keras.layers.Layer):

    def __init__(self, units,action_units,internal_units,env,batchsize,K_boundq, K_boundp,**kwargs):
        self.units = units
        self.action_units = action_units
        self.state_size = units
        self.internal_units = internal_units
        self.batchsize=batchsize
        self.Matrix_X=tf.constant(env.Matrix_X,dtype=tf.float32)
        self.Matrix_R=tf.constant(env.Matrix_R,dtype=tf.float32)
        self.inv_Matrix_X = tf.constant(env.inv_Matrix_X,dtype=tf.float32)
        self.lambda_max = tf.constant(env.lambda_max,dtype=tf.float32)
        self.max_action=tf.constant(env.max_action,dtype=tf.float32)
        self.bound_slopq = tf.constant(K_boundq.reshape((1,-1)),dtype=tf.float32)
        self.bound_slopp = tf.constant(K_boundp.reshape((1,-1)),dtype=tf.float32)
        self.norm_q=1
        super(MinimalRNNCellLinear0, self).__init__(**kwargs)

    def build(self, input_shape):
        self.linear_Kp= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kp')

        self.linear_Kq= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kq')
        self.built = True

    def call(self, inputs_concate, states):
        # stacked ReLU structure to represent control network
        prev_state = states[0]
        prev_state_x = prev_state[:,0:self.action_units]
        prev_state_q =  prev_state[:,self.action_units:2*self.action_units]
        prev_state_p =  prev_state[:,2*self.action_units:3*self.action_units]
        inputs_p = inputs_concate[:,0:self.action_units]
        inputs_v0 = inputs_concate[:,self.action_units:self.action_units+1]


        linear_Kq_=tf.math.minimum(self.linear_Kq, self.bound_slopq )
        linear_Kp_=tf.math.minimum(self.linear_Kp, self.bound_slopp )
        action_q= K.sum(tf.linalg.diag(prev_state_x)*linear_Kq_,axis=2)
        action_p= K.sum(tf.linalg.diag(prev_state_x)*linear_Kp_,axis=2)
        # action=self.max_action-K.relu(self.max_action-action_nonconstrain)+K.relu(-self.max_action-action_nonconstrain)
        new_state_x=prev_state_x-K.dot(action_q, tf.transpose(self.Matrix_X))-K.dot(action_p, tf.transpose(self.Matrix_R))+ K.dot(inputs_p, tf.transpose(self.Matrix_R)) + K.dot(inputs_v0, tf.ones((1,self.action_units)))
        new_state_q = prev_state_q - action_q
        new_state_p = prev_state_p - action_p

        next_state =  tf.concat([new_state_x, new_state_q, new_state_p], axis = 1)


        return [new_state_x,action_q, action_p, new_state_q, new_state_p], [next_state]

# %%
# Gen_idx_Pnode = []
# for i in range(dim_action):
#     row_idx = np.random.randint(0, 13)
#     Gen_idx_Pnode.append(row_idx)

# Gen_idx_Pnode = np.asarray(Gen_idx_Pnode, dtype=np.uint32)

## Mapping time-varying load to different buses

f = open('/content/drive/MyDrive/Colab Notebooks/6. Adaptive Control/Caltech/voltage/data/Gen_idx_Pnode13.pkl', 'rb')
Gen_idx_Pnode= pickle.load(f)
f.close()

# %%
# This is the data for time-varying load
f = open('/content/drive/MyDrive/Colab Notebooks/6. Adaptive Control/Caltech/voltage/data/Caltech_data/record_pred1228n14.pckl', 'rb')

[list_true_test, list_result_test, list_norm_RegD]= pickle.load(f)
f.close()

# %%
magnitute_ratio = 0.3
list_true_test = magnitute_ratio * np.asarray(list_true_test,dtype=np.float32)
list_result_test = magnitute_ratio *np.asarray(list_result_test,dtype=np.float32)
list_true_test[3:6,:]=list_true_test[3:6,:]/10
list_result_test[3:6,:]=list_result_test[3:6,:]/10

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*3 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

Length_pred_dataset = np.array(list_true_test).shape[1]-100
column1_idx = np.arange(0,dim_action)
PrintUpdate = 1
for i in range(0,episodes):
    initial_state_q = (1- np.random.uniform(-Q_init_ratio,Q_init_ratio,(Batch_num,action_units)))*(Q_ref.T)
    initial_state_p = (1- np.random.uniform(-P_init_ratio,P_init_ratio,(Batch_num,action_units)))*(P_ref.T)
    initial_state=initial_state_p@Matrix_R.T+initial_state_q@Matrix_X.T

    Input_config = np.zeros((Batch_num,T,dim_action+1))
    for j in range(Batch_num):
       #### time varying p
       t_init_Pm = np.random.randint(0, Length_pred_dataset-T-1)
       Input_config[j,:,:dim_action]=np.transpose(list_true_test[Gen_idx_Pnode,t_init_Pm:t_init_Pm+T])
       ###### v0
       rand_fault_idx = np.random.randint(0,np.shape(record_fault_trajectory)[0])
       rand_time_idx = np.random.randint(1050,1150)
       rand_bus_idx = np.random.randint(0,np.shape(record_fault_trajectory)[2])
       Input_config[j,:,dim_action] = record_fault_trajectory[rand_fault_idx,0,rand_bus_idx,rand_time_idx:rand_time_idx+T]


    with tf.GradientTape(persistent=True) as tape:
        [voltage,action_q,action_p, record_q, record_p]=modelLinear0(Input_config, np.hstack((initial_state, initial_state_q, initial_state_p)))
        loss_voltage=K.sum(K.sum(K.abs(voltage)))/Batch_num/T/dim_action
        loss_action=0.01*(env.Penalty_action*K.sum(abs(record_q)))/Batch_num/T/dim_action + 0.01*(env.Penalty_action*K.sum(abs(record_p)))/Batch_num/T/dim_action
        loss=loss_voltage+loss_action
    grads = tape.gradient(loss, modelLinear0.variables)
    optimizer.apply_gradients(zip(grads, modelLinear0.variables))
    Loss_record.append(loss)



    if i % (PrintUpdate) == 0:
        print('episode',i, 'Loss',loss)
        print('         Loss_Voltage',loss_voltage, '  loss_action', loss_action)
# Out:
# episode 0 Loss tf.Tensor(4.20697, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.131157, shape=(), dtype=float32)   loss_action tf.Tensor(0.07581347, shape=(), dtype=float32)
# episode 1 Loss tf.Tensor(4.1233053, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(4.0460286, shape=(), dtype=float32)   loss_action tf.Tensor(0.07727663, shape=(), dtype=float32)
# episode 2 Loss tf.Tensor(4.0535655, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.97468, shape=(), dtype=float32)   loss_action tf.Tensor(0.078885436, shape=(), dtype=float32)
# episode 3 Loss tf.Tensor(3.9759622, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.8957381, shape=(), dtype=float32)   loss_action tf.Tensor(0.08022414, shape=(), dtype=float32)
# episode 4 Loss tf.Tensor(3.9007196, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.819215, shape=(), dtype=float32)   loss_action tf.Tensor(0.08150461, shape=(), dtype=float32)
# episode 5 Loss tf.Tensor(3.8355029, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.7526422, shape=(), dtype=float32)   loss_action tf.Tensor(0.08286064, shape=(), dtype=float32)
# episode 6 Loss tf.Tensor(3.776802, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.692518, shape=(), dtype=float32)   loss_action tf.Tensor(0.08428417, shape=(), dtype=float32)
# episode 7 Loss tf.Tensor(3.712226, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.62677, shape=(), dtype=float32)   loss_action tf.Tensor(0.08545582, shape=(), dtype=float32)
# episode 8 Loss tf.Tensor(3.6515155, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.5648785, shape=(), dtype=float32)   loss_action tf.Tensor(0.086637035, shape=(), dtype=float32)
# episode 9 Loss tf.Tensor(3.6006336, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.5127, shape=(), dtype=float32)   loss_action tf.Tensor(0.08793354, shape=(), dtype=float32)
# episode 10 Loss tf.Tensor(3.5517192, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.4625125, shape=(), dtype=float32)   loss_action tf.Tensor(0.08920668, shape=(), dtype=float32)
# episode 11 Loss tf.Tensor(3.4964306, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.406192, shape=(), dtype=float32)   loss_action tf.Tensor(0.09023857, shape=(), dtype=float32)
# episode 12 Loss tf.Tensor(3.459774, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.3681364, shape=(), dtype=float32)   loss_action tf.Tensor(0.091637515, shape=(), dtype=float32)
# episode 13 Loss tf.Tensor(3.414328, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.321578, shape=(), dtype=float32)   loss_action tf.Tensor(0.09274996, shape=(), dtype=float32)
# episode 14 Loss tf.Tensor(3.3799376, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.285836, shape=(), dtype=float32)   loss_action tf.Tensor(0.09410172, shape=(), dtype=float32)
# episode 15 Loss tf.Tensor(3.3326075, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.2376013, shape=(), dtype=float32)   loss_action tf.Tensor(0.09500617, shape=(), dtype=float32)
# episode 16 Loss tf.Tensor(3.293577, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.1975043, shape=(), dtype=float32)   loss_action tf.Tensor(0.09607266, shape=(), dtype=float32)
# episode 17 Loss tf.Tensor(3.2497165, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.1527834, shape=(), dtype=float32)   loss_action tf.Tensor(0.096933015, shape=(), dtype=float32)
# episode 18 Loss tf.Tensor(3.223317, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.1250863, shape=(), dtype=float32)   loss_action tf.Tensor(0.098230496, shape=(), dtype=float32)
# episode 19 Loss tf.Tensor(3.1872463, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.0880594, shape=(), dtype=float32)   loss_action tf.Tensor(0.09918686, shape=(), dtype=float32)
# episode 20 Loss tf.Tensor(3.1557317, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.055518, shape=(), dtype=float32)   loss_action tf.Tensor(0.10021367, shape=(), dtype=float32)
# episode 21 Loss tf.Tensor(3.1227424, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.021605, shape=(), dtype=float32)   loss_action tf.Tensor(0.10113743, shape=(), dtype=float32)
# episode 22 Loss tf.Tensor(3.0928617, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.990754, shape=(), dtype=float32)   loss_action tf.Tensor(0.10210778, shape=(), dtype=float32)
# episode 23 Loss tf.Tensor(3.0549862, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.952225, shape=(), dtype=float32)   loss_action tf.Tensor(0.10276133, shape=(), dtype=float32)
# episode 24 Loss tf.Tensor(3.0273926, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.9236825, shape=(), dtype=float32)   loss_action tf.Tensor(0.10371022, shape=(), dtype=float32)
# episode 25 Loss tf.Tensor(3.0078902, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.9030294, shape=(), dtype=float32)   loss_action tf.Tensor(0.104860835, shape=(), dtype=float32)
# episode 26 Loss tf.Tensor(2.9828837, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.8771067, shape=(), dtype=float32)   loss_action tf.Tensor(0.105776995, shape=(), dtype=float32)
# episode 27 Loss tf.Tensor(2.9546475, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.8480756, shape=(), dtype=float32)   loss_action tf.Tensor(0.10657191, shape=(), dtype=float32)
# episode 28 Loss tf.Tensor(2.9349747, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.8273926, shape=(), dtype=float32)   loss_action tf.Tensor(0.10758215, shape=(), dtype=float32)
# episode 29 Loss tf.Tensor(2.9057148, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.7974823, shape=(), dtype=float32)   loss_action tf.Tensor(0.10823251, shape=(), dtype=float32)
# episode 30 Loss tf.Tensor(2.8819995, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.77297, shape=(), dtype=float32)   loss_action tf.Tensor(0.10902947, shape=(), dtype=float32)
# episode 31 Loss tf.Tensor(2.856878, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.7471576, shape=(), dtype=float32)   loss_action tf.Tensor(0.10972051, shape=(), dtype=float32)
# episode 32 Loss tf.Tensor(2.8379393, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.7273226, shape=(), dtype=float32)   loss_action tf.Tensor(0.11061658, shape=(), dtype=float32)
# episode 33 Loss tf.Tensor(2.826245, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.7145057, shape=(), dtype=float32)   loss_action tf.Tensor(0.11173933, shape=(), dtype=float32)
# episode 34 Loss tf.Tensor(2.8014932, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6891468, shape=(), dtype=float32)   loss_action tf.Tensor(0.11234653, shape=(), dtype=float32)
# episode 35 Loss tf.Tensor(2.7751403, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6622949, shape=(), dtype=float32)   loss_action tf.Tensor(0.1128453, shape=(), dtype=float32)
# episode 36 Loss tf.Tensor(2.7657237, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6517396, shape=(), dtype=float32)   loss_action tf.Tensor(0.11398417, shape=(), dtype=float32)
# episode 37 Loss tf.Tensor(2.743436, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.628868, shape=(), dtype=float32)   loss_action tf.Tensor(0.11456798, shape=(), dtype=float32)
# episode 38 Loss tf.Tensor(2.7259657, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6106553, shape=(), dtype=float32)   loss_action tf.Tensor(0.11531046, shape=(), dtype=float32)
# episode 39 Loss tf.Tensor(2.7108083, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5946712, shape=(), dtype=float32)   loss_action tf.Tensor(0.11613707, shape=(), dtype=float32)
# episode 40 Loss tf.Tensor(2.6946194, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5777533, shape=(), dtype=float32)   loss_action tf.Tensor(0.11686611, shape=(), dtype=float32)
# episode 41 Loss tf.Tensor(2.6722076, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5548916, shape=(), dtype=float32)   loss_action tf.Tensor(0.11731602, shape=(), dtype=float32)
# episode 42 Loss tf.Tensor(2.6578789, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5398033, shape=(), dtype=float32)   loss_action tf.Tensor(0.11807571, shape=(), dtype=float32)
# episode 43 Loss tf.Tensor(2.6381307, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5195525, shape=(), dtype=float32)   loss_action tf.Tensor(0.11857819, shape=(), dtype=float32)
# episode 44 Loss tf.Tensor(2.629717, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5101707, shape=(), dtype=float32)   loss_action tf.Tensor(0.11954643, shape=(), dtype=float32)
# episode 45 Loss tf.Tensor(2.6154325, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4951744, shape=(), dtype=float32)   loss_action tf.Tensor(0.12025806, shape=(), dtype=float32)
# episode 46 Loss tf.Tensor(2.596967, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.476241, shape=(), dtype=float32)   loss_action tf.Tensor(0.120725915, shape=(), dtype=float32)
# episode 47 Loss tf.Tensor(2.5841758, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.462737, shape=(), dtype=float32)   loss_action tf.Tensor(0.12143867, shape=(), dtype=float32)
# episode 48 Loss tf.Tensor(2.5637326, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.441944, shape=(), dtype=float32)   loss_action tf.Tensor(0.12178871, shape=(), dtype=float32)
# episode 49 Loss tf.Tensor(2.5571554, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4344354, shape=(), dtype=float32)   loss_action tf.Tensor(0.12272, shape=(), dtype=float32)
# episode 50 Loss tf.Tensor(2.542826, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4195259, shape=(), dtype=float32)   loss_action tf.Tensor(0.1233, shape=(), dtype=float32)
# episode 51 Loss tf.Tensor(2.5311444, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4071543, shape=(), dtype=float32)   loss_action tf.Tensor(0.123990044, shape=(), dtype=float32)
# episode 52 Loss tf.Tensor(2.519611, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3949494, shape=(), dtype=float32)   loss_action tf.Tensor(0.124661475, shape=(), dtype=float32)
# episode 53 Loss tf.Tensor(2.5088837, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3835402, shape=(), dtype=float32)   loss_action tf.Tensor(0.12534359, shape=(), dtype=float32)
# episode 54 Loss tf.Tensor(2.4918866, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3662035, shape=(), dtype=float32)   loss_action tf.Tensor(0.12568307, shape=(), dtype=float32)
# episode 55 Loss tf.Tensor(2.4796653, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.353398, shape=(), dtype=float32)   loss_action tf.Tensor(0.12626724, shape=(), dtype=float32)
# episode 56 Loss tf.Tensor(2.4710348, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3440435, shape=(), dtype=float32)   loss_action tf.Tensor(0.12699133, shape=(), dtype=float32)
# episode 57 Loss tf.Tensor(2.4542336, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3269134, shape=(), dtype=float32)   loss_action tf.Tensor(0.12732035, shape=(), dtype=float32)
# episode 58 Loss tf.Tensor(2.4483285, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.320211, shape=(), dtype=float32)   loss_action tf.Tensor(0.12811765, shape=(), dtype=float32)
# episode 59 Loss tf.Tensor(2.4342225, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3056853, shape=(), dtype=float32)   loss_action tf.Tensor(0.12853712, shape=(), dtype=float32)
# episode 60 Loss tf.Tensor(2.4232857, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.294211, shape=(), dtype=float32)   loss_action tf.Tensor(0.12907475, shape=(), dtype=float32)
# episode 61 Loss tf.Tensor(2.4121382, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2825527, shape=(), dtype=float32)   loss_action tf.Tensor(0.1295855, shape=(), dtype=float32)
# episode 62 Loss tf.Tensor(2.4035094, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2732568, shape=(), dtype=float32)   loss_action tf.Tensor(0.13025256, shape=(), dtype=float32)
# episode 63 Loss tf.Tensor(2.3935356, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2627642, shape=(), dtype=float32)   loss_action tf.Tensor(0.13077141, shape=(), dtype=float32)
# episode 64 Loss tf.Tensor(2.3817406, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2505198, shape=(), dtype=float32)   loss_action tf.Tensor(0.13122089, shape=(), dtype=float32)
# episode 65 Loss tf.Tensor(2.377288, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2452347, shape=(), dtype=float32)   loss_action tf.Tensor(0.13205332, shape=(), dtype=float32)
# episode 66 Loss tf.Tensor(2.3659244, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2334154, shape=(), dtype=float32)   loss_action tf.Tensor(0.13250905, shape=(), dtype=float32)
# episode 67 Loss tf.Tensor(2.35363, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2207613, shape=(), dtype=float32)   loss_action tf.Tensor(0.13286877, shape=(), dtype=float32)
# episode 68 Loss tf.Tensor(2.3463311, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2128315, shape=(), dtype=float32)   loss_action tf.Tensor(0.13349965, shape=(), dtype=float32)
# episode 69 Loss tf.Tensor(2.3338842, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.200039, shape=(), dtype=float32)   loss_action tf.Tensor(0.1338453, shape=(), dtype=float32)
# episode 70 Loss tf.Tensor(2.322435, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1882288, shape=(), dtype=float32)   loss_action tf.Tensor(0.13420604, shape=(), dtype=float32)
# episode 71 Loss tf.Tensor(2.315075, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1802714, shape=(), dtype=float32)   loss_action tf.Tensor(0.13480349, shape=(), dtype=float32)
# episode 72 Loss tf.Tensor(2.3073394, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1719885, shape=(), dtype=float32)   loss_action tf.Tensor(0.13535094, shape=(), dtype=float32)
# episode 73 Loss tf.Tensor(2.2952154, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1595614, shape=(), dtype=float32)   loss_action tf.Tensor(0.13565394, shape=(), dtype=float32)
# episode 74 Loss tf.Tensor(2.289899, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1535718, shape=(), dtype=float32)   loss_action tf.Tensor(0.1363272, shape=(), dtype=float32)
# episode 75 Loss tf.Tensor(2.281053, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1442568, shape=(), dtype=float32)   loss_action tf.Tensor(0.1367963, shape=(), dtype=float32)
# episode 76 Loss tf.Tensor(2.272855, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1355903, shape=(), dtype=float32)   loss_action tf.Tensor(0.13726468, shape=(), dtype=float32)
# episode 77 Loss tf.Tensor(2.2662778, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.128415, shape=(), dtype=float32)   loss_action tf.Tensor(0.13786262, shape=(), dtype=float32)
# episode 78 Loss tf.Tensor(2.2601454, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.121691, shape=(), dtype=float32)   loss_action tf.Tensor(0.1384545, shape=(), dtype=float32)
# episode 79 Loss tf.Tensor(2.2499008, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1111188, shape=(), dtype=float32)   loss_action tf.Tensor(0.13878192, shape=(), dtype=float32)
# episode 80 Loss tf.Tensor(2.2402804, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1011546, shape=(), dtype=float32)   loss_action tf.Tensor(0.1391258, shape=(), dtype=float32)
# episode 81 Loss tf.Tensor(2.2267165, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.087458, shape=(), dtype=float32)   loss_action tf.Tensor(0.13925858, shape=(), dtype=float32)
# episode 82 Loss tf.Tensor(2.2269876, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0867763, shape=(), dtype=float32)   loss_action tf.Tensor(0.14021143, shape=(), dtype=float32)
# episode 83 Loss tf.Tensor(2.2175934, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.077067, shape=(), dtype=float32)   loss_action tf.Tensor(0.14052664, shape=(), dtype=float32)
# episode 84 Loss tf.Tensor(2.2112982, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0702581, shape=(), dtype=float32)   loss_action tf.Tensor(0.14104018, shape=(), dtype=float32)
# episode 85 Loss tf.Tensor(2.203682, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0621853, shape=(), dtype=float32)   loss_action tf.Tensor(0.1414966, shape=(), dtype=float32)
# episode 86 Loss tf.Tensor(2.1938198, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0520635, shape=(), dtype=float32)   loss_action tf.Tensor(0.14175639, shape=(), dtype=float32)
# episode 87 Loss tf.Tensor(2.1822264, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.040281, shape=(), dtype=float32)   loss_action tf.Tensor(0.14194533, shape=(), dtype=float32)
# episode 88 Loss tf.Tensor(2.1833596, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.040461, shape=(), dtype=float32)   loss_action tf.Tensor(0.1428985, shape=(), dtype=float32)
# episode 89 Loss tf.Tensor(2.1751497, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.031925, shape=(), dtype=float32)   loss_action tf.Tensor(0.14322475, shape=(), dtype=float32)
# episode 90 Loss tf.Tensor(2.1670253, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0234509, shape=(), dtype=float32)   loss_action tf.Tensor(0.14357448, shape=(), dtype=float32)
# episode 91 Loss tf.Tensor(2.156506, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0127065, shape=(), dtype=float32)   loss_action tf.Tensor(0.14379959, shape=(), dtype=float32)
# episode 92 Loss tf.Tensor(2.1540875, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0096202, shape=(), dtype=float32)   loss_action tf.Tensor(0.14446738, shape=(), dtype=float32)
# episode 93 Loss tf.Tensor(2.1470363, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0021687, shape=(), dtype=float32)   loss_action tf.Tensor(0.1448676, shape=(), dtype=float32)
# episode 94 Loss tf.Tensor(2.1350708, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.990086, shape=(), dtype=float32)   loss_action tf.Tensor(0.14498489, shape=(), dtype=float32)
# episode 95 Loss tf.Tensor(2.1346228, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9888623, shape=(), dtype=float32)   loss_action tf.Tensor(0.1457605, shape=(), dtype=float32)
# episode 96 Loss tf.Tensor(2.1263628, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9803067, shape=(), dtype=float32)   loss_action tf.Tensor(0.14605618, shape=(), dtype=float32)
# episode 97 Loss tf.Tensor(2.1156383, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9694825, shape=(), dtype=float32)   loss_action tf.Tensor(0.14615574, shape=(), dtype=float32)
# episode 98 Loss tf.Tensor(2.1181784, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9710141, shape=(), dtype=float32)   loss_action tf.Tensor(0.14716423, shape=(), dtype=float32)
# episode 99 Loss tf.Tensor(2.110601, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.963131, shape=(), dtype=float32)   loss_action tf.Tensor(0.14747003, shape=(), dtype=float32)
# episode 100 Loss tf.Tensor(2.0982475, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9507717, shape=(), dtype=float32)   loss_action tf.Tensor(0.14747575, shape=(), dtype=float32)
# episode 101 Loss tf.Tensor(2.090615, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9429262, shape=(), dtype=float32)   loss_action tf.Tensor(0.1476888, shape=(), dtype=float32)
# episode 102 Loss tf.Tensor(2.0844662, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9365119, shape=(), dtype=float32)   loss_action tf.Tensor(0.14795443, shape=(), dtype=float32)
# episode 103 Loss tf.Tensor(2.0844634, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9357333, shape=(), dtype=float32)   loss_action tf.Tensor(0.14873007, shape=(), dtype=float32)
# episode 104 Loss tf.Tensor(2.0792482, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9301963, shape=(), dtype=float32)   loss_action tf.Tensor(0.1490519, shape=(), dtype=float32)
# episode 105 Loss tf.Tensor(2.0740094, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9245939, shape=(), dtype=float32)   loss_action tf.Tensor(0.1494155, shape=(), dtype=float32)
# episode 106 Loss tf.Tensor(2.0657938, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9162383, shape=(), dtype=float32)   loss_action tf.Tensor(0.14955547, shape=(), dtype=float32)
# episode 107 Loss tf.Tensor(2.0551894, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.905691, shape=(), dtype=float32)   loss_action tf.Tensor(0.14949843, shape=(), dtype=float32)
# episode 108 Loss tf.Tensor(2.0581934, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9077678, shape=(), dtype=float32)   loss_action tf.Tensor(0.15042561, shape=(), dtype=float32)
# episode 109 Loss tf.Tensor(2.051773, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9011028, shape=(), dtype=float32)   loss_action tf.Tensor(0.15067023, shape=(), dtype=float32)
# episode 110 Loss tf.Tensor(2.0444028, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8935456, shape=(), dtype=float32)   loss_action tf.Tensor(0.15085723, shape=(), dtype=float32)
# episode 111 Loss tf.Tensor(2.0397666, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8885443, shape=(), dtype=float32)   loss_action tf.Tensor(0.15122217, shape=(), dtype=float32)
# episode 112 Loss tf.Tensor(2.0331404, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8816992, shape=(), dtype=float32)   loss_action tf.Tensor(0.15144111, shape=(), dtype=float32)
# episode 113 Loss tf.Tensor(2.025251, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8737065, shape=(), dtype=float32)   loss_action tf.Tensor(0.15154436, shape=(), dtype=float32)
# episode 114 Loss tf.Tensor(2.027593, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.875214, shape=(), dtype=float32)   loss_action tf.Tensor(0.15237892, shape=(), dtype=float32)
# episode 115 Loss tf.Tensor(2.024107, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8713232, shape=(), dtype=float32)   loss_action tf.Tensor(0.15278372, shape=(), dtype=float32)
# episode 116 Loss tf.Tensor(2.01886, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8657767, shape=(), dtype=float32)   loss_action tf.Tensor(0.15308353, shape=(), dtype=float32)
# episode 117 Loss tf.Tensor(2.0100713, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8569373, shape=(), dtype=float32)   loss_action tf.Tensor(0.1531339, shape=(), dtype=float32)
# episode 118 Loss tf.Tensor(2.0053666, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8519218, shape=(), dtype=float32)   loss_action tf.Tensor(0.15344483, shape=(), dtype=float32)
# episode 119 Loss tf.Tensor(2.0028226, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8488994, shape=(), dtype=float32)   loss_action tf.Tensor(0.15392327, shape=(), dtype=float32)
# episode 120 Loss tf.Tensor(1.9964205, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8423297, shape=(), dtype=float32)   loss_action tf.Tensor(0.15409073, shape=(), dtype=float32)
# episode 121 Loss tf.Tensor(1.9908365, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8365047, shape=(), dtype=float32)   loss_action tf.Tensor(0.15433183, shape=(), dtype=float32)
# episode 122 Loss tf.Tensor(1.9903831, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8354263, shape=(), dtype=float32)   loss_action tf.Tensor(0.15495685, shape=(), dtype=float32)
# episode 123 Loss tf.Tensor(1.9843309, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8291526, shape=(), dtype=float32)   loss_action tf.Tensor(0.15517832, shape=(), dtype=float32)
# episode 124 Loss tf.Tensor(1.9758706, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8207116, shape=(), dtype=float32)   loss_action tf.Tensor(0.15515906, shape=(), dtype=float32)
# episode 125 Loss tf.Tensor(1.9782109, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.822241, shape=(), dtype=float32)   loss_action tf.Tensor(0.15596995, shape=(), dtype=float32)
# episode 126 Loss tf.Tensor(1.9684243, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8125563, shape=(), dtype=float32)   loss_action tf.Tensor(0.15586802, shape=(), dtype=float32)
# episode 127 Loss tf.Tensor(1.966672, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8102825, shape=(), dtype=float32)   loss_action tf.Tensor(0.15638942, shape=(), dtype=float32)
# episode 128 Loss tf.Tensor(1.962543, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8058308, shape=(), dtype=float32)   loss_action tf.Tensor(0.15671211, shape=(), dtype=float32)
# episode 129 Loss tf.Tensor(1.9607962, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8035704, shape=(), dtype=float32)   loss_action tf.Tensor(0.15722585, shape=(), dtype=float32)
# episode 130 Loss tf.Tensor(1.9496508, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7926695, shape=(), dtype=float32)   loss_action tf.Tensor(0.15698126, shape=(), dtype=float32)
# episode 131 Loss tf.Tensor(1.9476831, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.790245, shape=(), dtype=float32)   loss_action tf.Tensor(0.1574381, shape=(), dtype=float32)
# episode 132 Loss tf.Tensor(1.9467503, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7887354, shape=(), dtype=float32)   loss_action tf.Tensor(0.15801492, shape=(), dtype=float32)
# episode 133 Loss tf.Tensor(1.939676, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7816161, shape=(), dtype=float32)   loss_action tf.Tensor(0.15806001, shape=(), dtype=float32)
# episode 134 Loss tf.Tensor(1.9346598, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7763807, shape=(), dtype=float32)   loss_action tf.Tensor(0.15827918, shape=(), dtype=float32)
# episode 135 Loss tf.Tensor(1.9383442, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7791394, shape=(), dtype=float32)   loss_action tf.Tensor(0.15920481, shape=(), dtype=float32)
# episode 136 Loss tf.Tensor(1.9270453, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7680947, shape=(), dtype=float32)   loss_action tf.Tensor(0.15895063, shape=(), dtype=float32)
# episode 137 Loss tf.Tensor(1.9233246, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7640766, shape=(), dtype=float32)   loss_action tf.Tensor(0.15924796, shape=(), dtype=float32)
# episode 138 Loss tf.Tensor(1.9207658, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7611322, shape=(), dtype=float32)   loss_action tf.Tensor(0.15963349, shape=(), dtype=float32)
# episode 139 Loss tf.Tensor(1.9117382, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7522222, shape=(), dtype=float32)   loss_action tf.Tensor(0.15951596, shape=(), dtype=float32)
# episode 140 Loss tf.Tensor(1.9115676, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7514337, shape=(), dtype=float32)   loss_action tf.Tensor(0.16013381, shape=(), dtype=float32)
# episode 141 Loss tf.Tensor(1.9029934, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7429988, shape=(), dtype=float32)   loss_action tf.Tensor(0.15999457, shape=(), dtype=float32)
# episode 142 Loss tf.Tensor(1.9027655, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7421851, shape=(), dtype=float32)   loss_action tf.Tensor(0.16058046, shape=(), dtype=float32)
# episode 143 Loss tf.Tensor(1.8965037, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7358513, shape=(), dtype=float32)   loss_action tf.Tensor(0.16065234, shape=(), dtype=float32)
# episode 144 Loss tf.Tensor(1.8950905, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7339392, shape=(), dtype=float32)   loss_action tf.Tensor(0.16115126, shape=(), dtype=float32)
# episode 145 Loss tf.Tensor(1.8901278, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7288046, shape=(), dtype=float32)   loss_action tf.Tensor(0.16132323, shape=(), dtype=float32)
# episode 146 Loss tf.Tensor(1.8868915, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7252421, shape=(), dtype=float32)   loss_action tf.Tensor(0.16164938, shape=(), dtype=float32)
# episode 147 Loss tf.Tensor(1.8818716, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7200649, shape=(), dtype=float32)   loss_action tf.Tensor(0.16180673, shape=(), dtype=float32)
# episode 148 Loss tf.Tensor(1.8802046, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7179463, shape=(), dtype=float32)   loss_action tf.Tensor(0.16225825, shape=(), dtype=float32)
# episode 149 Loss tf.Tensor(1.8843615, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7211633, shape=(), dtype=float32)   loss_action tf.Tensor(0.16319819, shape=(), dtype=float32)
# episode 150 Loss tf.Tensor(1.8715717, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.708883, shape=(), dtype=float32)   loss_action tf.Tensor(0.16268861, shape=(), dtype=float32)
# episode 151 Loss tf.Tensor(1.8718073, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7085147, shape=(), dtype=float32)   loss_action tf.Tensor(0.1632927, shape=(), dtype=float32)
# episode 152 Loss tf.Tensor(1.8650184, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7017447, shape=(), dtype=float32)   loss_action tf.Tensor(0.16327375, shape=(), dtype=float32)
# episode 153 Loss tf.Tensor(1.8636733, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6999189, shape=(), dtype=float32)   loss_action tf.Tensor(0.16375451, shape=(), dtype=float32)
# episode 154 Loss tf.Tensor(1.8549367, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6913737, shape=(), dtype=float32)   loss_action tf.Tensor(0.16356298, shape=(), dtype=float32)
# episode 155 Loss tf.Tensor(1.8532866, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6892915, shape=(), dtype=float32)   loss_action tf.Tensor(0.16399515, shape=(), dtype=float32)
# episode 156 Loss tf.Tensor(1.85108, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6867263, shape=(), dtype=float32)   loss_action tf.Tensor(0.16435361, shape=(), dtype=float32)
# episode 157 Loss tf.Tensor(1.8488803, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.684154, shape=(), dtype=float32)   loss_action tf.Tensor(0.16472632, shape=(), dtype=float32)
# episode 158 Loss tf.Tensor(1.8432617, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.678431, shape=(), dtype=float32)   loss_action tf.Tensor(0.16483071, shape=(), dtype=float32)
# episode 159 Loss tf.Tensor(1.8383232, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.673365, shape=(), dtype=float32)   loss_action tf.Tensor(0.1649582, shape=(), dtype=float32)
# episode 160 Loss tf.Tensor(1.8360107, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6706854, shape=(), dtype=float32)   loss_action tf.Tensor(0.16532528, shape=(), dtype=float32)
# episode 161 Loss tf.Tensor(1.8345137, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6687735, shape=(), dtype=float32)   loss_action tf.Tensor(0.16574013, shape=(), dtype=float32)
# episode 162 Loss tf.Tensor(1.8337667, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6675981, shape=(), dtype=float32)   loss_action tf.Tensor(0.16616851, shape=(), dtype=float32)
# episode 163 Loss tf.Tensor(1.8301744, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6637268, shape=(), dtype=float32)   loss_action tf.Tensor(0.16644761, shape=(), dtype=float32)
# episode 164 Loss tf.Tensor(1.823108, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6567376, shape=(), dtype=float32)   loss_action tf.Tensor(0.16637044, shape=(), dtype=float32)
# episode 165 Loss tf.Tensor(1.8167388, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6503944, shape=(), dtype=float32)   loss_action tf.Tensor(0.16634445, shape=(), dtype=float32)
# episode 166 Loss tf.Tensor(1.8167863, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6498865, shape=(), dtype=float32)   loss_action tf.Tensor(0.16689986, shape=(), dtype=float32)
# episode 167 Loss tf.Tensor(1.8176442, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6501426, shape=(), dtype=float32)   loss_action tf.Tensor(0.16750166, shape=(), dtype=float32)
# episode 168 Loss tf.Tensor(1.808549, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6413227, shape=(), dtype=float32)   loss_action tf.Tensor(0.16722636, shape=(), dtype=float32)
# episode 169 Loss tf.Tensor(1.8085513, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6407609, shape=(), dtype=float32)   loss_action tf.Tensor(0.16779035, shape=(), dtype=float32)
# episode 170 Loss tf.Tensor(1.8067008, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6385612, shape=(), dtype=float32)   loss_action tf.Tensor(0.16813962, shape=(), dtype=float32)
# episode 171 Loss tf.Tensor(1.8012681, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6330626, shape=(), dtype=float32)   loss_action tf.Tensor(0.1682055, shape=(), dtype=float32)
# episode 172 Loss tf.Tensor(1.799459, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6308951, shape=(), dtype=float32)   loss_action tf.Tensor(0.16856378, shape=(), dtype=float32)
# episode 173 Loss tf.Tensor(1.7952408, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6265559, shape=(), dtype=float32)   loss_action tf.Tensor(0.16868483, shape=(), dtype=float32)
# episode 174 Loss tf.Tensor(1.7903072, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6215233, shape=(), dtype=float32)   loss_action tf.Tensor(0.16878395, shape=(), dtype=float32)
# episode 175 Loss tf.Tensor(1.7867076, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6177481, shape=(), dtype=float32)   loss_action tf.Tensor(0.16895947, shape=(), dtype=float32)
# episode 176 Loss tf.Tensor(1.7811716, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6121691, shape=(), dtype=float32)   loss_action tf.Tensor(0.16900235, shape=(), dtype=float32)
# episode 177 Loss tf.Tensor(1.7840031, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6142697, shape=(), dtype=float32)   loss_action tf.Tensor(0.16973343, shape=(), dtype=float32)
# episode 178 Loss tf.Tensor(1.7816715, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6116104, shape=(), dtype=float32)   loss_action tf.Tensor(0.17006117, shape=(), dtype=float32)
# episode 179 Loss tf.Tensor(1.7794526, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.609066, shape=(), dtype=float32)   loss_action tf.Tensor(0.1703866, shape=(), dtype=float32)
# episode 180 Loss tf.Tensor(1.77293, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6026354, shape=(), dtype=float32)   loss_action tf.Tensor(0.17029463, shape=(), dtype=float32)
# episode 181 Loss tf.Tensor(1.7677778, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.597425, shape=(), dtype=float32)   loss_action tf.Tensor(0.17035282, shape=(), dtype=float32)
# episode 182 Loss tf.Tensor(1.765676, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5950272, shape=(), dtype=float32)   loss_action tf.Tensor(0.17064881, shape=(), dtype=float32)
# episode 183 Loss tf.Tensor(1.7629504, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5920334, shape=(), dtype=float32)   loss_action tf.Tensor(0.1709171, shape=(), dtype=float32)
# episode 184 Loss tf.Tensor(1.7640963, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5925957, shape=(), dtype=float32)   loss_action tf.Tensor(0.17150053, shape=(), dtype=float32)
# episode 185 Loss tf.Tensor(1.7558259, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5846, shape=(), dtype=float32)   loss_action tf.Tensor(0.17122588, shape=(), dtype=float32)
# episode 186 Loss tf.Tensor(1.7537756, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.58224, shape=(), dtype=float32)   loss_action tf.Tensor(0.17153563, shape=(), dtype=float32)
# episode 187 Loss tf.Tensor(1.7501727, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5784736, shape=(), dtype=float32)   loss_action tf.Tensor(0.17169921, shape=(), dtype=float32)
# episode 188 Loss tf.Tensor(1.7508843, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5786213, shape=(), dtype=float32)   loss_action tf.Tensor(0.17226306, shape=(), dtype=float32)
# episode 189 Loss tf.Tensor(1.7491547, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5765506, shape=(), dtype=float32)   loss_action tf.Tensor(0.17260408, shape=(), dtype=float32)
# episode 190 Loss tf.Tensor(1.7443007, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.571694, shape=(), dtype=float32)   loss_action tf.Tensor(0.17260674, shape=(), dtype=float32)
# episode 191 Loss tf.Tensor(1.7413898, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.56855, shape=(), dtype=float32)   loss_action tf.Tensor(0.1728397, shape=(), dtype=float32)
# episode 192 Loss tf.Tensor(1.737351, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5644226, shape=(), dtype=float32)   loss_action tf.Tensor(0.1729284, shape=(), dtype=float32)
# episode 193 Loss tf.Tensor(1.7383991, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.564869, shape=(), dtype=float32)   loss_action tf.Tensor(0.17353007, shape=(), dtype=float32)
# episode 194 Loss tf.Tensor(1.7316997, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5583215, shape=(), dtype=float32)   loss_action tf.Tensor(0.17337826, shape=(), dtype=float32)
# episode 195 Loss tf.Tensor(1.7279524, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5544707, shape=(), dtype=float32)   loss_action tf.Tensor(0.17348167, shape=(), dtype=float32)
# episode 196 Loss tf.Tensor(1.7240086, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5504266, shape=(), dtype=float32)   loss_action tf.Tensor(0.17358197, shape=(), dtype=float32)
# episode 197 Loss tf.Tensor(1.7224759, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5485759, shape=(), dtype=float32)   loss_action tf.Tensor(0.17389996, shape=(), dtype=float32)
# episode 198 Loss tf.Tensor(1.719728, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5455862, shape=(), dtype=float32)   loss_action tf.Tensor(0.17414182, shape=(), dtype=float32)
# episode 199 Loss tf.Tensor(1.7196473, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5450468, shape=(), dtype=float32)   loss_action tf.Tensor(0.17460045, shape=(), dtype=float32)
# episode 200 Loss tf.Tensor(1.7157882, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5410885, shape=(), dtype=float32)   loss_action tf.Tensor(0.17469981, shape=(), dtype=float32)
# episode 201 Loss tf.Tensor(1.7142137, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5392345, shape=(), dtype=float32)   loss_action tf.Tensor(0.17497924, shape=(), dtype=float32)
# episode 202 Loss tf.Tensor(1.7095592, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5345871, shape=(), dtype=float32)   loss_action tf.Tensor(0.17497212, shape=(), dtype=float32)
# episode 203 Loss tf.Tensor(1.7073076, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5321523, shape=(), dtype=float32)   loss_action tf.Tensor(0.17515534, shape=(), dtype=float32)
# episode 204 Loss tf.Tensor(1.7100554, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5342262, shape=(), dtype=float32)   loss_action tf.Tensor(0.17582911, shape=(), dtype=float32)
# episode 205 Loss tf.Tensor(1.7013783, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5259645, shape=(), dtype=float32)   loss_action tf.Tensor(0.17541383, shape=(), dtype=float32)
# episode 206 Loss tf.Tensor(1.6986138, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5230775, shape=(), dtype=float32)   loss_action tf.Tensor(0.1755363, shape=(), dtype=float32)
# episode 207 Loss tf.Tensor(1.6971198, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5213199, shape=(), dtype=float32)   loss_action tf.Tensor(0.17579997, shape=(), dtype=float32)
# episode 208 Loss tf.Tensor(1.698851, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5224591, shape=(), dtype=float32)   loss_action tf.Tensor(0.17639187, shape=(), dtype=float32)
# episode 209 Loss tf.Tensor(1.6906081, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5146463, shape=(), dtype=float32)   loss_action tf.Tensor(0.17596185, shape=(), dtype=float32)
# episode 210 Loss tf.Tensor(1.6899209, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5135925, shape=(), dtype=float32)   loss_action tf.Tensor(0.17632839, shape=(), dtype=float32)
# episode 211 Loss tf.Tensor(1.6881137, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5115503, shape=(), dtype=float32)   loss_action tf.Tensor(0.17656332, shape=(), dtype=float32)
# episode 212 Loss tf.Tensor(1.6860781, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5092965, shape=(), dtype=float32)   loss_action tf.Tensor(0.17678156, shape=(), dtype=float32)
# episode 213 Loss tf.Tensor(1.6879463, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5105885, shape=(), dtype=float32)   loss_action tf.Tensor(0.17735782, shape=(), dtype=float32)
# episode 214 Loss tf.Tensor(1.687932, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5101266, shape=(), dtype=float32)   loss_action tf.Tensor(0.17780542, shape=(), dtype=float32)
# episode 215 Loss tf.Tensor(1.6827954, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5051293, shape=(), dtype=float32)   loss_action tf.Tensor(0.17766604, shape=(), dtype=float32)
# episode 216 Loss tf.Tensor(1.6794767, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5017571, shape=(), dtype=float32)   loss_action tf.Tensor(0.1777196, shape=(), dtype=float32)
# episode 217 Loss tf.Tensor(1.6787975, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5007222, shape=(), dtype=float32)   loss_action tf.Tensor(0.1780753, shape=(), dtype=float32)
# episode 218 Loss tf.Tensor(1.6759019, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4977399, shape=(), dtype=float32)   loss_action tf.Tensor(0.17816192, shape=(), dtype=float32)
# episode 219 Loss tf.Tensor(1.6699171, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4919323, shape=(), dtype=float32)   loss_action tf.Tensor(0.17798486, shape=(), dtype=float32)
# episode 220 Loss tf.Tensor(1.6705062, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.492063, shape=(), dtype=float32)   loss_action tf.Tensor(0.17844325, shape=(), dtype=float32)
# episode 221 Loss tf.Tensor(1.6669372, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.488456, shape=(), dtype=float32)   loss_action tf.Tensor(0.17848125, shape=(), dtype=float32)
# episode 222 Loss tf.Tensor(1.666145, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.48734, shape=(), dtype=float32)   loss_action tf.Tensor(0.17880498, shape=(), dtype=float32)
# episode 223 Loss tf.Tensor(1.6644068, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4853898, shape=(), dtype=float32)   loss_action tf.Tensor(0.17901699, shape=(), dtype=float32)
# episode 224 Loss tf.Tensor(1.6624109, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4831678, shape=(), dtype=float32)   loss_action tf.Tensor(0.17924306, shape=(), dtype=float32)
# episode 225 Loss tf.Tensor(1.659733, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4803807, shape=(), dtype=float32)   loss_action tf.Tensor(0.1793524, shape=(), dtype=float32)
# episode 226 Loss tf.Tensor(1.660203, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4804132, shape=(), dtype=float32)   loss_action tf.Tensor(0.17978978, shape=(), dtype=float32)
# episode 227 Loss tf.Tensor(1.6553636, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4756787, shape=(), dtype=float32)   loss_action tf.Tensor(0.17968485, shape=(), dtype=float32)
# episode 228 Loss tf.Tensor(1.6543118, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.474338, shape=(), dtype=float32)   loss_action tf.Tensor(0.1799737, shape=(), dtype=float32)
# episode 229 Loss tf.Tensor(1.6515723, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4715112, shape=(), dtype=float32)   loss_action tf.Tensor(0.18006113, shape=(), dtype=float32)
# episode 230 Loss tf.Tensor(1.6523432, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4718121, shape=(), dtype=float32)   loss_action tf.Tensor(0.18053104, shape=(), dtype=float32)
# episode 231 Loss tf.Tensor(1.6463197, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4659847, shape=(), dtype=float32)   loss_action tf.Tensor(0.18033502, shape=(), dtype=float32)
# episode 232 Loss tf.Tensor(1.6466615, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4659575, shape=(), dtype=float32)   loss_action tf.Tensor(0.18070404, shape=(), dtype=float32)
# episode 233 Loss tf.Tensor(1.6420358, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4614292, shape=(), dtype=float32)   loss_action tf.Tensor(0.18060663, shape=(), dtype=float32)
# episode 234 Loss tf.Tensor(1.6401567, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4593463, shape=(), dtype=float32)   loss_action tf.Tensor(0.18081047, shape=(), dtype=float32)
# episode 235 Loss tf.Tensor(1.6376001, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4566278, shape=(), dtype=float32)   loss_action tf.Tensor(0.18097225, shape=(), dtype=float32)
# episode 236 Loss tf.Tensor(1.6371293, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4558513, shape=(), dtype=float32)   loss_action tf.Tensor(0.18127805, shape=(), dtype=float32)
# episode 237 Loss tf.Tensor(1.6341133, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4528058, shape=(), dtype=float32)   loss_action tf.Tensor(0.18130758, shape=(), dtype=float32)
# episode 238 Loss tf.Tensor(1.6357231, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.453829, shape=(), dtype=float32)   loss_action tf.Tensor(0.18189412, shape=(), dtype=float32)
# episode 239 Loss tf.Tensor(1.6296558, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4480662, shape=(), dtype=float32)   loss_action tf.Tensor(0.1815896, shape=(), dtype=float32)
# episode 240 Loss tf.Tensor(1.6275891, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4458344, shape=(), dtype=float32)   loss_action tf.Tensor(0.18175474, shape=(), dtype=float32)
# episode 241 Loss tf.Tensor(1.6258017, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4438454, shape=(), dtype=float32)   loss_action tf.Tensor(0.18195629, shape=(), dtype=float32)
# episode 242 Loss tf.Tensor(1.6270158, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4445505, shape=(), dtype=float32)   loss_action tf.Tensor(0.18246531, shape=(), dtype=float32)
# episode 243 Loss tf.Tensor(1.6219585, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4396459, shape=(), dtype=float32)   loss_action tf.Tensor(0.18231264, shape=(), dtype=float32)
# episode 244 Loss tf.Tensor(1.618741, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4364059, shape=(), dtype=float32)   loss_action tf.Tensor(0.1823352, shape=(), dtype=float32)
# episode 245 Loss tf.Tensor(1.6208316, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4378744, shape=(), dtype=float32)   loss_action tf.Tensor(0.18295717, shape=(), dtype=float32)
# episode 246 Loss tf.Tensor(1.6173269, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4344263, shape=(), dtype=float32)   loss_action tf.Tensor(0.18290058, shape=(), dtype=float32)
# episode 247 Loss tf.Tensor(1.6189108, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4354264, shape=(), dtype=float32)   loss_action tf.Tensor(0.1834845, shape=(), dtype=float32)
# episode 248 Loss tf.Tensor(1.6141634, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4308307, shape=(), dtype=float32)   loss_action tf.Tensor(0.1833327, shape=(), dtype=float32)
# episode 249 Loss tf.Tensor(1.61239, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4288722, shape=(), dtype=float32)   loss_action tf.Tensor(0.18351787, shape=(), dtype=float32)
# episode 250 Loss tf.Tensor(1.6129544, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4290147, shape=(), dtype=float32)   loss_action tf.Tensor(0.18393967, shape=(), dtype=float32)
# ...
# episode 917 Loss tf.Tensor(1.1388137, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.90607643, shape=(), dtype=float32)   loss_action tf.Tensor(0.23273727, shape=(), dtype=float32)
# episode 918 Loss tf.Tensor(1.1400759, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.90695757, shape=(), dtype=float32)   loss_action tf.Tensor(0.23311836, shape=(), dtype=float32)
# episode 919 Loss tf.Tensor(1.1386151, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9057066, shape=(), dtype=float32)   loss_action tf.Tensor(0.23290853, shape=(), dtype=float32)
# episode 920 Loss tf.Tensor(1.138391, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9054659, shape=(), dtype=float32)   loss_action tf.Tensor(0.23292512, shape=(), dtype=float32)
# episode 921 Loss tf.Tensor(1.1406484, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9072067, shape=(), dtype=float32)   loss_action tf.Tensor(0.23344159, shape=(), dtype=float32)
# episode 922 Loss tf.Tensor(1.1373012, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.90443337, shape=(), dtype=float32)   loss_action tf.Tensor(0.23286782, shape=(), dtype=float32)
# episode 923 Loss tf.Tensor(1.1371949, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9042468, shape=(), dtype=float32)   loss_action tf.Tensor(0.23294812, shape=(), dtype=float32)
# episode 924 Loss tf.Tensor(1.1361239, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.90331155, shape=(), dtype=float32)   loss_action tf.Tensor(0.23281237, shape=(), dtype=float32)
# episode 925 Loss tf.Tensor(1.1396768, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9060656, shape=(), dtype=float32)   loss_action tf.Tensor(0.2336112, shape=(), dtype=float32)
# episode 926 Loss tf.Tensor(1.1332633, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.90087026, shape=(), dtype=float32)   loss_action tf.Tensor(0.23239306, shape=(), dtype=float32)
# episode 927 Loss tf.Tensor(1.13467, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.90187854, shape=(), dtype=float32)   loss_action tf.Tensor(0.2327915, shape=(), dtype=float32)
# episode 928 Loss tf.Tensor(1.1358862, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9027808, shape=(), dtype=float32)   loss_action tf.Tensor(0.23310538, shape=(), dtype=float32)
# episode 929 Loss tf.Tensor(1.1348118, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9018019, shape=(), dtype=float32)   loss_action tf.Tensor(0.23300985, shape=(), dtype=float32)
# episode 930 Loss tf.Tensor(1.1355703, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9023058, shape=(), dtype=float32)   loss_action tf.Tensor(0.23326445, shape=(), dtype=float32)
# episode 931 Loss tf.Tensor(1.1378028, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9040439, shape=(), dtype=float32)   loss_action tf.Tensor(0.2337589, shape=(), dtype=float32)
# episode 932 Loss tf.Tensor(1.1323885, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89959264, shape=(), dtype=float32)   loss_action tf.Tensor(0.23279585, shape=(), dtype=float32)
# episode 933 Loss tf.Tensor(1.1333668, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9002686, shape=(), dtype=float32)   loss_action tf.Tensor(0.23309816, shape=(), dtype=float32)
# episode 934 Loss tf.Tensor(1.1353707, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9018331, shape=(), dtype=float32)   loss_action tf.Tensor(0.23353767, shape=(), dtype=float32)
# episode 935 Loss tf.Tensor(1.1338621, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9005457, shape=(), dtype=float32)   loss_action tf.Tensor(0.23331645, shape=(), dtype=float32)
# episode 936 Loss tf.Tensor(1.1333411, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.9000329, shape=(), dtype=float32)   loss_action tf.Tensor(0.2333082, shape=(), dtype=float32)
# episode 937 Loss tf.Tensor(1.1346827, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.90105486, shape=(), dtype=float32)   loss_action tf.Tensor(0.2336278, shape=(), dtype=float32)
# episode 938 Loss tf.Tensor(1.1321381, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89891547, shape=(), dtype=float32)   loss_action tf.Tensor(0.2332227, shape=(), dtype=float32)
# episode 939 Loss tf.Tensor(1.1320902, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8988067, shape=(), dtype=float32)   loss_action tf.Tensor(0.23328353, shape=(), dtype=float32)
# episode 940 Loss tf.Tensor(1.1340748, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.900313, shape=(), dtype=float32)   loss_action tf.Tensor(0.23376179, shape=(), dtype=float32)
# episode 941 Loss tf.Tensor(1.1329036, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89928085, shape=(), dtype=float32)   loss_action tf.Tensor(0.23362267, shape=(), dtype=float32)
# episode 942 Loss tf.Tensor(1.1337905, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8999814, shape=(), dtype=float32)   loss_action tf.Tensor(0.23380907, shape=(), dtype=float32)
# episode 943 Loss tf.Tensor(1.1323762, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8986977, shape=(), dtype=float32)   loss_action tf.Tensor(0.23367858, shape=(), dtype=float32)
# episode 944 Loss tf.Tensor(1.133811, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89981425, shape=(), dtype=float32)   loss_action tf.Tensor(0.23399672, shape=(), dtype=float32)
# episode 945 Loss tf.Tensor(1.1308279, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89735883, shape=(), dtype=float32)   loss_action tf.Tensor(0.23346901, shape=(), dtype=float32)
# episode 946 Loss tf.Tensor(1.1317809, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8979483, shape=(), dtype=float32)   loss_action tf.Tensor(0.23383251, shape=(), dtype=float32)
# episode 947 Loss tf.Tensor(1.131409, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89763063, shape=(), dtype=float32)   loss_action tf.Tensor(0.23377845, shape=(), dtype=float32)
# episode 948 Loss tf.Tensor(1.1325535, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8984361, shape=(), dtype=float32)   loss_action tf.Tensor(0.23411731, shape=(), dtype=float32)
# episode 949 Loss tf.Tensor(1.1315109, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8975004, shape=(), dtype=float32)   loss_action tf.Tensor(0.23401049, shape=(), dtype=float32)
# episode 950 Loss tf.Tensor(1.1307025, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8968133, shape=(), dtype=float32)   loss_action tf.Tensor(0.23388918, shape=(), dtype=float32)
# episode 951 Loss tf.Tensor(1.1320567, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8978116, shape=(), dtype=float32)   loss_action tf.Tensor(0.23424518, shape=(), dtype=float32)
# episode 952 Loss tf.Tensor(1.1317123, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89743114, shape=(), dtype=float32)   loss_action tf.Tensor(0.23428121, shape=(), dtype=float32)
# episode 953 Loss tf.Tensor(1.1307886, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8965947, shape=(), dtype=float32)   loss_action tf.Tensor(0.23419389, shape=(), dtype=float32)
# episode 954 Loss tf.Tensor(1.1287836, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89494157, shape=(), dtype=float32)   loss_action tf.Tensor(0.23384199, shape=(), dtype=float32)
# episode 955 Loss tf.Tensor(1.1297266, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89558905, shape=(), dtype=float32)   loss_action tf.Tensor(0.23413754, shape=(), dtype=float32)
# episode 956 Loss tf.Tensor(1.1293349, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89519954, shape=(), dtype=float32)   loss_action tf.Tensor(0.23413533, shape=(), dtype=float32)
# episode 957 Loss tf.Tensor(1.1296027, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8953092, shape=(), dtype=float32)   loss_action tf.Tensor(0.2342934, shape=(), dtype=float32)
# episode 958 Loss tf.Tensor(1.1278919, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89392436, shape=(), dtype=float32)   loss_action tf.Tensor(0.23396753, shape=(), dtype=float32)
# episode 959 Loss tf.Tensor(1.128815, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8945299, shape=(), dtype=float32)   loss_action tf.Tensor(0.23428522, shape=(), dtype=float32)
# episode 960 Loss tf.Tensor(1.1277639, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89360994, shape=(), dtype=float32)   loss_action tf.Tensor(0.23415393, shape=(), dtype=float32)
# episode 961 Loss tf.Tensor(1.1282529, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8939414, shape=(), dtype=float32)   loss_action tf.Tensor(0.23431149, shape=(), dtype=float32)
# episode 962 Loss tf.Tensor(1.1289746, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89441574, shape=(), dtype=float32)   loss_action tf.Tensor(0.23455884, shape=(), dtype=float32)
# episode 963 Loss tf.Tensor(1.1281781, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8936836, shape=(), dtype=float32)   loss_action tf.Tensor(0.23449457, shape=(), dtype=float32)
# episode 964 Loss tf.Tensor(1.1277553, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89329004, shape=(), dtype=float32)   loss_action tf.Tensor(0.23446523, shape=(), dtype=float32)
# episode 965 Loss tf.Tensor(1.1284348, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89369863, shape=(), dtype=float32)   loss_action tf.Tensor(0.23473614, shape=(), dtype=float32)
# episode 966 Loss tf.Tensor(1.12709, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89257187, shape=(), dtype=float32)   loss_action tf.Tensor(0.23451808, shape=(), dtype=float32)
# episode 967 Loss tf.Tensor(1.1250286, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89085734, shape=(), dtype=float32)   loss_action tf.Tensor(0.2341713, shape=(), dtype=float32)
# episode 968 Loss tf.Tensor(1.1261178, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89164853, shape=(), dtype=float32)   loss_action tf.Tensor(0.23446932, shape=(), dtype=float32)
# episode 969 Loss tf.Tensor(1.1248047, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89051497, shape=(), dtype=float32)   loss_action tf.Tensor(0.2342898, shape=(), dtype=float32)
# episode 970 Loss tf.Tensor(1.1257279, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8911362, shape=(), dtype=float32)   loss_action tf.Tensor(0.23459172, shape=(), dtype=float32)
# episode 971 Loss tf.Tensor(1.1260104, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.89131355, shape=(), dtype=float32)   loss_action tf.Tensor(0.2346969, shape=(), dtype=float32)
# episode 972 Loss tf.Tensor(1.1257982, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8910331, shape=(), dtype=float32)   loss_action tf.Tensor(0.23476505, shape=(), dtype=float32)
# episode 973 Loss tf.Tensor(1.1237098, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88930434, shape=(), dtype=float32)   loss_action tf.Tensor(0.23440544, shape=(), dtype=float32)
# episode 974 Loss tf.Tensor(1.1218237, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88775325, shape=(), dtype=float32)   loss_action tf.Tensor(0.23407042, shape=(), dtype=float32)
# episode 975 Loss tf.Tensor(1.123579, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8890602, shape=(), dtype=float32)   loss_action tf.Tensor(0.23451877, shape=(), dtype=float32)
# episode 976 Loss tf.Tensor(1.1231495, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88864547, shape=(), dtype=float32)   loss_action tf.Tensor(0.23450407, shape=(), dtype=float32)
# episode 977 Loss tf.Tensor(1.1246296, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88975203, shape=(), dtype=float32)   loss_action tf.Tensor(0.23487762, shape=(), dtype=float32)
# episode 978 Loss tf.Tensor(1.122709, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8881395, shape=(), dtype=float32)   loss_action tf.Tensor(0.23456949, shape=(), dtype=float32)
# episode 979 Loss tf.Tensor(1.123213, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8884179, shape=(), dtype=float32)   loss_action tf.Tensor(0.23479518, shape=(), dtype=float32)
# episode 980 Loss tf.Tensor(1.123045, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88822746, shape=(), dtype=float32)   loss_action tf.Tensor(0.23481755, shape=(), dtype=float32)
# episode 981 Loss tf.Tensor(1.1219202, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88729036, shape=(), dtype=float32)   loss_action tf.Tensor(0.2346299, shape=(), dtype=float32)
# episode 982 Loss tf.Tensor(1.1214882, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8868183, shape=(), dtype=float32)   loss_action tf.Tensor(0.23466995, shape=(), dtype=float32)
# episode 983 Loss tf.Tensor(1.1256251, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8899753, shape=(), dtype=float32)   loss_action tf.Tensor(0.23564988, shape=(), dtype=float32)
# episode 984 Loss tf.Tensor(1.1191828, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8848116, shape=(), dtype=float32)   loss_action tf.Tensor(0.23437124, shape=(), dtype=float32)
# episode 985 Loss tf.Tensor(1.1217521, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8868052, shape=(), dtype=float32)   loss_action tf.Tensor(0.23494695, shape=(), dtype=float32)
# episode 986 Loss tf.Tensor(1.1206782, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8858316, shape=(), dtype=float32)   loss_action tf.Tensor(0.23484653, shape=(), dtype=float32)
# episode 987 Loss tf.Tensor(1.1223449, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8870895, shape=(), dtype=float32)   loss_action tf.Tensor(0.23525536, shape=(), dtype=float32)
# episode 988 Loss tf.Tensor(1.1215229, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88638955, shape=(), dtype=float32)   loss_action tf.Tensor(0.23513341, shape=(), dtype=float32)
# episode 989 Loss tf.Tensor(1.1210799, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8859266, shape=(), dtype=float32)   loss_action tf.Tensor(0.23515338, shape=(), dtype=float32)
# episode 990 Loss tf.Tensor(1.1184936, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88375956, shape=(), dtype=float32)   loss_action tf.Tensor(0.23473406, shape=(), dtype=float32)
# episode 991 Loss tf.Tensor(1.1208613, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8856019, shape=(), dtype=float32)   loss_action tf.Tensor(0.23525941, shape=(), dtype=float32)
# episode 992 Loss tf.Tensor(1.1191792, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8841689, shape=(), dtype=float32)   loss_action tf.Tensor(0.23501036, shape=(), dtype=float32)
# episode 993 Loss tf.Tensor(1.1213456, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8857973, shape=(), dtype=float32)   loss_action tf.Tensor(0.23554832, shape=(), dtype=float32)
# episode 994 Loss tf.Tensor(1.121003, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8853981, shape=(), dtype=float32)   loss_action tf.Tensor(0.23560494, shape=(), dtype=float32)
# episode 995 Loss tf.Tensor(1.1215773, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8858251, shape=(), dtype=float32)   loss_action tf.Tensor(0.23575221, shape=(), dtype=float32)
# episode 996 Loss tf.Tensor(1.1192626, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.883878, shape=(), dtype=float32)   loss_action tf.Tensor(0.23538455, shape=(), dtype=float32)
# episode 997 Loss tf.Tensor(1.1213886, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88549393, shape=(), dtype=float32)   loss_action tf.Tensor(0.23589465, shape=(), dtype=float32)
# episode 998 Loss tf.Tensor(1.1185287, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8831362, shape=(), dtype=float32)   loss_action tf.Tensor(0.23539254, shape=(), dtype=float32)
# episode 999 Loss tf.Tensor(1.1170053, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.88180405, shape=(), dtype=float32)   loss_action tf.Tensor(0.23520127, shape=(), dtype=float32)

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*3 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

# %%
plt.plot(Loss_record)
plt.xlabel('episoid')
plt.ylabel('Loss')
# plt.title('Non-Discounted Loss without penalty')
# Out:
# Text(0, 0.5, 'Loss')

# %%
modelLinear0.save_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_K_250808_t001.weights.h5')
# modelLinear0.load_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_K_250808_t001.weights.h5')

# %% [markdown]
# # Simulation and Comparisons

# %% [markdown]
# ## With trained controller

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)
linear_coffq = tf.math.minimum(modelLinear0.variables[1], K_bound_q)

Q_init_ratio = 0.6
P_init_ratio = 0.6
delta_t = 1
Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=1000
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[0,0,0,1100:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
fig.suptitle("With Linear Incremental Control")
# plt.title('With Linear Incremental Control')
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [[-0.00014165 -0.00047144 -0.00108773 -0.00169358 -0.00311501 -0.00382889
#   -0.00318835 -0.00063512  0.00197209  0.00200532  0.00211732  0.00143825
#    0.00091424  0.00029483 -0.00025982 -0.00041976 -0.00049472 -0.0001253
#   -0.00062501 -0.0007296  -0.00087738  0.00029309  0.00123516  0.00206427
#   -0.00315005 -0.00313347 -0.0016422  -0.00062095 -0.00011318  0.00015474
#    0.00044236  0.00048975]]

# %% [markdown]
# ## without control

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)*0
linear_coffq = tf.math.minimum(modelLinear0.variables[1], K_bound_q)*0


init_state=s_concate.copy()
s=init_state.copy()
# SimulationLength=20
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[0,0,0,1100:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
fig.suptitle("Without Control")

TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')

fig.tight_layout()
# Out:
# s [[-0.00014165 -0.00047144 -0.00108773 -0.00169358 -0.00311501 -0.00382889
#   -0.00318835 -0.00063512  0.00197209  0.00200532  0.00211732  0.00143825
#    0.00091424  0.00029483 -0.00025982 -0.00041976 -0.00049472 -0.0001253
#   -0.00062501 -0.0007296  -0.00087738  0.00029309  0.00123516  0.00206427
#   -0.00315005 -0.00313347 -0.0016422  -0.00062095 -0.00011318  0.00015474
#    0.00044236  0.00048975]]
